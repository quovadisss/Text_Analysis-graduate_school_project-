# %% [markdown]
# # 크롤링(crawling) 이란?

# %% [markdown]
# Web상에 존재하는 Contents를 수집하는 작업
# 1. HTML 페이지를 가져와서, HTML/CSS등을 파싱하고, 필요한 데이터만 추출하는 기법
# 2. Open API(Rest API)를 제공하는 서비스에 Open API를 호출해서, 받은 데이터 중 필요한 데이터만 추출하는 기법
# 3. Selenium등 브라우저를 프로그래밍으로 조작해서, 필요한 데이터만 추출하는 기법

# %% [markdown]
# BeautifulSoup 라이브러리
# - HTML의 태그를 파싱해서 필요한 데이터만 추출하는 함수를 제공하는 라이브러리

# %% [markdown]
# find() : 가장 먼저 검색되는 태그 반환
# find_all() : 전체 태그 반환

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('http://v.media.daum.net/v/20170615203441266')

# %%
print(res.content)
# Out:
# b'<!doctype html>\n<html lang="ko">\n <head> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=Edge"> \n  <meta name="referrer" content="always"> \n  <title>\xec\x9e\x94\xea\xb8\x88\xeb\x8c\x80\xec\xb6\x9c\xec\x97\x90\xeb\x8f\x84 DTI \xea\xb7\x9c\xec\xa0\x9c \xec\xa0\x81\xec\x9a\xa9 \xea\xb2\x80\xed\x86\xa0 | Daum \xeb\x89\xb4\xec\x8a\xa4</title> \n  <link rel="shortcut icon" href="//m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico"> \n  <style>\n@charset "utf-8";@font-face{font-family:\'Nanum Myeongjo\';font-style:normal;font-weight:400;src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot);src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot?#iefix) format(\'embedded-opentype\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff2) format(\'woff2\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff) format(\'woff\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.ttf) format(\'truetype\')}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,textarea,button{margin:0;padding:0}fieldset,img{border:0 none}dl,ul,ol,menu,li{list-style:none}blockquote,q{quotes:none}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none}input,select,textarea,button{vertical-align:middle}input::-ms-clear{display:none}button{border:0 none;background-color:transparent;cursor:pointer}button::-moz-focus-inner{padding:0;border:0}body{min-width:980px;background:#fff}body,th,td,input,select,textarea,button{font-size:14px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,\'Malgun Gothic\',\'\xeb\xa7\x91\xec\x9d\x80 \xea\xb3\xa0\xeb\x94\x95\',dotum,\'\xeb\x8f\x8b\xec\x9b\x80\',sans-serif;color:#333;letter-spacing:-0.05em}a{color:#333;text-decoration:none}a:active,a:hover{text-decoration:underline}a:hover{color:#1e88e5}a:active{background-color:transparent}address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}.os_mac strong{font-weight:normal;font-family:AppleSDGothicNeo-Regular,sans-serif}html{overflow-y:scroll}#kakaoIndex{overflow:hidden;position:absolute;left:-9999px;width:0;height:1px;margin:0;padding:0}.ir_pm{display:block;overflow:hidden;font-size:0;line-height:0;text-indent:-9999px}.ir_wa{display:block;overflow:hidden;position:relative;z-index:-1;width:100%;height:100%}.screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}.show{display:block}.hide{display:none}.txt_newsview{display:block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/txt_newsview_190618.png) 0 0 no-repeat;text-indent:-9999px;background-size:140px 750px}.ico_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview_190327.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:350px 350px}.ico_newsview2{background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview2_180510.png) 0 0 no-repeat;background-size:50px 440px}.num_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/num_newsview.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:18px 600px}.link_cont,.link_thumb,.tit_g,.tit_thumb,.desc_thumb,.info_thumb{display:block}.link_thumb{position:relative}.link_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:\'\'}.link_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;transition:background .2s,opacity .2s;content:\'\'}.link_thumb:hover:after{background:#508dee;opacity:.45}.link_cont .wrap_thumb{display:block;position:relative}.link_cont .wrap_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-inde ...

# %%
soup = BeautifulSoup(res.content, 'html.parser')

# %%
soup.body
# Out:
# <body>
# <div id="kakaoIndex">
# <a href="#kakaoBody">본문 바로가기</a>
# <a href="#kakaoGnb">메뉴 바로가기</a>
# </div>
# <div class="newsview_media" id="kakaoWrap">
# <!-- 2018-09-20 영어,인도네시아어 번역일 경우, lang_type1 클래스 추가 -->
# <!-- 2018-09-20 중국어, 일본어 번역일 경우, lang_type2 클래스 추가 -->
# <!-- 2018-09-11-v2  2018-09-20 베트남어 번역일 때 lang_type3 클래스 추가 -->
# <div class="#gnb #default hcg_media_pc_kakaoHead" id="kakaoHead" role="banner">
# <div class="head_media">
# <h1> <a class="link_daum" href="https://www.daum.net/"> <img alt="Daum" class="thumb_g" height="19" src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45"/> </a> <a href="https://media.daum.net/" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a> </h1>
# <strong class="screen_out">관련서비스</strong>
# <ul id="kakaoRelServices">
# <li><a class="link_services link_services1" href="https://media.daum.net/entertain/"><span class="ir_wa">연예</span></a></li>
# <li><a class="link_services link_services2" href="https://sports.media.daum.net/sports/"><span class="ir_wa">스포츠</span></a></li>
# </ul>
# <h2 class="screen_out">검색</h2>
# <div class="search_news" id="search_news">
# <form action="https://search.daum.net/search" id="kakaoSearch" method="get" name="kakaoSearch">
# <fieldset class="fld_inside">
# <legend class="screen_out">검색어 입력폼</legend>
# <div class="box_searchbar">
# <label class="lab_search" for="qVal">통합검색</label>
# <input name="nil_profile" type="hidden" value="search"/>
# <input name="nil_src" type="hidden" value="media"/>
# <input name="DA" type="hidden" value="23A"/>
# <input name="rtmaxcoll" type="hidden" value="NNS"/>
# <input autocomplete="off" class="tf_keyword" id="qVal" name="q" spellcheck="false" title="검색어 입력" type="text" value=""/>
# <button class="btn_search" id="kakaoBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </fieldset>
# <div class="wrap_suggestBox" id="wrap_suggestBox">
# <div class="suggestBox box_sub" id="suggestBox">
# <div class="baseBox bg" style="display: none"></div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div id="kakaoGnb" role="navigation">
# <div class="inner_gnb">
# <h2 class="screen_out">뉴스 메인메뉴</h2>
# <ul class="gnb_comm" data-category="economic">
# <li class="home"><a class="link_gnb link_gnb1" href="https://media.daum.net/"><span class="ir_wa">홈</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="society"><a class="link_gnb link_gnb2" href="https://media.daum.net/society/"><span class="ir_wa">사회</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <!-- 현재페이지에 on클래스 추가  -->
# <li class="politics"><a class="link_gnb link_gnb3" href="https://media.daum.net/politics/"><span class="ir_wa">정치</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="economic"><a class="link_gnb link_gnb4" href="https://media.daum.net/economic/"><span class="ir_wa">경제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="foreign"><a class="link_gnb link_gnb5" href="https://media.daum.net/foreign/"><span class="ir_wa">국제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="culture"><a class="link_gnb link_gnb6" href="https://media.daum.net/culture/"><span class="ir_wa">문화</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="digital"><a class="link_gnb link_gnb7" href="https://media.daum.net/digital/"><span class="ir_wa">IT</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="popular"><a class="link_gnb link_gnb8" href="https://media.daum.net/ranking/popular/"><span class="ir_wa">랭킹</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="series"><a class="link_gnb link_gnb9" href="https://media.daum.net/series/"><span class="ir_wa">연재</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="photo"><a class="link_gnb link_gnb10" href="https://media.daum.net/photo/"><span class="ir_wa">포토</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="tv"><a class="link_gnb link_gnb11" href="https://media.daum.net/tv/"><span class="ir_wa">TV</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# </ul>
# <div class="gnb_etc">
# <ul class="gnb_with">
# <li><a class="link_gnb link_gnb1" href="https://media.daum.net/1boon/"><span class="ir_wa">1boon</span></a></li>
# <li><a class="link_gnb link_gnb2" href="//gallery.v.daum.net/p/home"><span class="ir_wa">사진전</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# </ul>
# <div class="gnb_weather hc_news_pc_kakaoHead_gnbWeather">
# <strong class="screen_out">날씨 정보</strong>
# <div id="gnb_weather">
# <ul class="list_weather" data-nightyn="N">
# <!-- 69px씩 이동합니다 / 밤일 경우, type_night 클래스 추가 -->
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=서울%20날씨"> <span class="ico_weather ico_weather1">서울</span> <span class="txt_weather">서울 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=수원%20날씨"> <span class="ico_weather ico_weather1">수원</span> <span class="txt_weather">수원 <span class="num_heat">2</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=인천%20날씨"> <span class="ico_weather ico_weather1">인천</span> <span class="txt_weather">인천 <span class="num_heat">1</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대구%20날씨"> <span class="ico_weather ico_weather1">대구</span> <span class="txt_weather">대구 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대전%20날씨"> <span class="ico_weather ico_weather1">대전</span> <span class="txt_weather">대전 <span class="num_heat">3</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=광주%20날씨"> <span class="ico_weather ico_weather1">광주</span> <span class="txt_weather">광주 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=부산%20날씨"> <span class="ico_weather ico_weather1">부산</span> <span class="txt_weather">부산 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울산%20날씨"> <span class="ico_weather ico_weather1">울산</span> <span class="txt_weather">울산 <span class="num_heat">5</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울릉/독도%20날씨"> <span class="ico_weather ico_weather3">울릉/독도</span> <span class="txt_weather">울릉/독도 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=춘천%20날씨"> <span class="ico_weather ico_weather1">춘천</span> <span class="txt_weather">춘천 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=강릉%20날씨"> <span class="ico_weather ico_weather1">강릉</span> <span class="txt_weather">강릉 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=백령%20날씨"> <span class="ico_weather ico_weather2">백령</span> <span class="txt_weather">백령 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=청주%20날씨"> <span class="ico_weather ico_weather1">청주</span> <span class="txt_weather">청주 <span class="num_heat">2</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=전주%20날씨"> <span class="ico_weather ico_weather2">전주</span> <span class="txt_weather">전주 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=목포%20날씨"> <span class="ico_weather ico_weather2">목포</span> <span class="txt_weather">목포 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=여수%20날씨"> <span class="ico_weather ico_weather1">여수</span> <span class="txt_weather">여수 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=제주%20날씨"> <span class="ico_weather ico_weather3">제주</span> <span class="txt_weather">제주 <span class="num_heat">11</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=안동%20날씨"> <span class="ico_weather ico_weather1">안동</span> <span class="txt_weather">안동 <span class="num_heat">3</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=창원%20날씨"> <span class="ico_weather ico_weather1">창원</span> <span class="txt_weather">창원 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bar_progress" id="barProgress"></div>
# </div>
# <hr class="hide hcg_media_pc_kakaoHead"/>
# <div class="cont_view" id="kakaoContent" role="main">
# <h2 class="screen_out" id="kakaoBody">경제</h2>
# <div class="hcg_media_pc_cSub" id="cSub">
# <div class="head_view">
# <em class="info_cp"> <a class="link_cp #body #cplogo" href="http://www.hankookilbo.com" target="_blank"> <img alt="한국일보" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_hankooki.gif"/> </a> </em>
# <h3 class="tit_view" data-translation="">잔금대출에도 DTI 규제 적용 검토</h3>
# <span class="info_view"> <span class="txt_info">김동욱</span> <span class="txt_info">입력 2017.06.15. 20:34</span> <span class="txt_info">수정 2017.06.15. 21:31</span> <button class="emph_g2 link_cmt" id="alexCounter">댓글 <span class="alex-count-area">0</span>개</button> </span>
# <div class="util_view">
# <!-- 2018-08-31-v2 버튼 순서 변경 / 자동요약 - TTS - 번역 - 공유 - 글씨크기 - 인쇄 순 -->
# <!-- 자동요약 -->
# <div class="btn_util util_summary">
# <!-- btn_summary 클릭시, layer_open 클래스 추가 -->
# <button aria-expanded="false" class="btn_summary #btn_summary" type="button"><span class="ico_newsview">자동요약</span></button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_summary">
# <p>금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다.</p>
# <p>지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다.</p>
# <p>앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다.</p>
# <span class="info_summary"><span class="ico_newsview"></span>기사 제목과 주요 문장을 기반으로 자동요약한 결과입니다. 전체 맥락을 이해하기 위해서는 본문 보기를 권장합니다.</span>
# </div>
# </div>
# </div>
# <!-- TTS -->
# <div class="btn_util tts_btn hc_news_pc_cSub_tts">
# <button aria-expanded="false" class="btn_set btn_tts" type="button"> <span class="ico_newsview ico_speak">음성 기사 듣기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_tts">
# <strong class="screen_out">음성 기사 옵션 조절 레이어</strong>
# <ul class="list_set list_tts">
# <li> <input class="screen_out" id="ttsGenderMale" name="ttsGender" type="radio" value="Male"/> <label class="lab_set" for="ttsGenderMale"><span class="ico_newsview"></span>남성</label> </li>
# <li> <input class="screen_out" id="ttsGenderFemale" name="ttsGender" type="radio" value="Female"/> <label class="lab_set" for="ttsGenderFemale"><span class="ico_newsview"></span>여성</label> </li>
# </ul>
# <ul class="list_set list_tts list_ttsspeed">
# <li> <input class="screen_out" id="ttsSpeedSlow" name="ttsSpeed" type="radio" value="slow"/> <label class="lab_set" for="ttsSpeedSlow"><span class="ico_newsview"></span>느림</label> </li>
# <li> <input class="screen_out" id="ttsSpeedNormal" name="ttsSpeed" type="radio" value="normal"/> <label class="lab_set" for="ttsSpeedNormal"><span class="ico_newsview"></span>보통</label> </li>
# <li> <input class="screen_out" id="ttsSpeedFast" name="ttsSpeed" type="radio" value="fast"/> <label class="lab_set" for="ttsSpeedFast"><span class="ico_newsview"></span>빠름</label> </li>
# </ul>
# </div>
# </div>
# <audio id="ttsPlayer" preload="none" style="display:none"></audio>
# </div>
# <!-- 번역 -->
# <div class="btn_util translate_btn hc_news_pc_cSub_translateButtons">
# <!-- 활성화시 aria-expanded="true" / 비활성화시 aria-expanded="false" 추가 -->
# <button aria-expanded="false" class="btn_set btn_translate #util #translate #set" type="button"><span class="ico_newsview">번역 설정</span></button>
# <div class="wrap_translatelayer">
# <div class="layer_util layer_translate">
# <strong class="tit_translate">번역<span class="ico_newsview">beta</span>
# <!-- 2018-09-04 추가--></strong>
# <p class="desc_translate txt_newsview">Translated by <a class="link_kakaoi #util #translate #kakaoi_link" href="https://kakao.ai/" target="_blank">kakao i</a></p>
# <strong class="screen_out">번역할 언어 선택</strong>
# <ul class="list_lang">
# <li> <button class="btn_lang btn_en #util #translate #lang_en" name="en"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">English</strong> </button> </li>
# <li> <button class="btn_lang btn_ch #util #translate #lang_cn" name="cn" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">简体中文</strong> </button> </li>
# <li> <button class="btn_lang btn_jp #util #translate #lang_jp" name="jp" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">日本語</strong> </button> </li>
# <li> <button class="btn_lang btn_ind #util #translate #lang_id" name="id" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">Bahasa Indonesia</strong> </button> </li>
# <li> <button class="btn_lang btn_viet #util #translate #lang_vi" name="vi" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">tiếng Việt</strong> </button> </li>
# <li> <button class="btn_lang btn_ko #util #translate #lang_kr" name="kr" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">한국어</strong> </button> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="hc_translator" style="display:none;"></div>
# <!-- 공유 -->
# <div class="btn_util share_btn hc_news_pc_cSub_shareButtons">
# <button aria-expanded="false" class="btn_set btn_share" id="rSocialShareButton"> <span class="ico_newsview">공유</span> </button>
# <div id="rSocialShareLayerContainer"></div>
# </div>
# <!-- 글씨크기 -->
# <div class="font_btn btn_util hc_news_pc_cSub_fontSizeController">
# <button aria-expanded="false" class="btn_set btn_font" type="button"> <span class="ico_newsview ico_font">글씨크기 조절하기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_font">
# <strong class="screen_out">글자 크기 조절 레이어</strong>
# <ul class="list_set list_font">
# <li> <input class="screen_out" id="inpFont17" name="inpFont" type="radio" value="17"/> <label class="lab_set lab_size0" for="inpFont17"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont18" name="inpFont" type="radio" value="18"/> <label class="lab_set lab_size1" for="inpFont18"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont19" name="inpFont" type="radio" value="19"/> <label class="lab_set lab_size2" for="inpFont19"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">보통 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont20" name="inpFont" type="radio" value="20"/> <label class="lab_set lab_size3" for="inpFont20"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">큰 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont21" name="inpFont" type="radio" value="21"/> <label class="lab_set lab_size4" for="inpFont21"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 큰 폰트</span> </label> </li>
# </ul>
# </div>
# </div>
# <!-- // font 팝업 레이어 -->
# </div>
# <!-- 인쇄 -->
# <div class="btn_util hc_news_pc_cSub_printButton">
# <button class="btn_print" type="button"> <span class="ico_newsview">인쇄하기 새창열림</span> </button>
# </div>
# </div>
# </div>
# </div>
# <div id="cMain">
# <div class="hcg_media_pc_mArticle" id="mArticle">
# <!-- 바꿔치기 -->
# <!-- 언론중재법 -->
# <!-- 번역 안내 -->
# <div class="status_view" id="translateNotice" style="display:none;">
# <span class="notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</span>
# <span class="notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</span>
# <span class="notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</span>
# <span class="notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</span>
# <span class="notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</span>
# </div>
# <div class="news_view" style="font-size:17px">
# <div class="article_view" data-translation-body="" id="harmonyContainer">
# <section dmcf-sid="ndxAvoEFLc">
# <p dmcf-pid="nzrJ5KB3Cc" dmcf-ptype="general">내주 부동산 종합대책 발표</p>
# <p dmcf-pid="ncFbmYUgSc" dmcf-ptype="general">집값 상승 노린 투기 분양 차단</p>
# <p dmcf-pid="naDeB8j0HH" dmcf-ptype="general">LTVㆍDTI 규제 다시 강화할 듯</p>
# <p dmcf-pid="ngfl6lJwwk" dmcf-ptype="general">저소득 실수요자 피해 우려도</p>
# <figure class="figure_frm origin_fig" dmcf-pid="nYQ8LWIMpD" dmcf-ptype="figure">
# <p class="link_figure"><img class="thumb_g_article" dmcf-mid="nkjJSoPdyb" dmcf-mtype="image" height="236" src="https://t1.daumcdn.net/news/201706/15/hankooki/20170615044256378kzbd.jpg" width="330"/></p>
# </figure>
# <p dmcf-pid="n8guDAko3Z" dmcf-ptype="general">금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다. 지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다. 앞으로 잔금대출에 DTI가 적용되면 소득 없는 사람이 입주 뒤 집값 상승을 노리고 분양시장에 뛰어드는 게 사실상 불가능해진다. </p>
# <p dmcf-pid="nYPaCCRO1q" dmcf-ptype="general">금융당국 고위관계자는 15일 “잔금대출에도 DTI를 적용하는 방안을 검토 중”이라며 “다만 아직 최종 결론이 난 건 아니다”고 말했다. 정부는 내주 이 같은 내용을 포함한 부동산 종합 대책을 발표할 예정이다. </p>
# <p dmcf-pid="naZLBbSgoZ" dmcf-ptype="general">정부가 잔금대출 DTI 적용 카드를 꺼내는 건, 집단대출을 잡지 않고선 과열된 주택시장을 진정시키기 어렵다는 판단에서다. 실제 정부는 지난해 잔금대출도 대출 초기부터 원리금을 함께 갚도록 하는 여신심사 가이드라인을 도입했지만 이렇다 할 효과를 거두지 못했다. 오히려 정부 대책에도 불구, 집단대출 증가액은 매달 늘어나는 추세인데 지난달엔 2조원으로 올 들어 최고치를 기록했다. </p>
# <p dmcf-pid="nhAfneUtnA" dmcf-ptype="general">아파트 분양 집단대출은 중도금과 잔금대출로 구분된다. 계약금 10%를 내면 입주 전까지 집값의 60%를 중도금 대출로 받을 수 있다. 중도금 대출은 건설사 보증으로 이뤄져 소득심사를 안 거친다. 잔금대출은 건설사가 아닌 집을 담보로 이뤄지는 대출이다. LTV 규제만 적용돼 소득이 없어도 집값의 70%까지 대출이 가능하다. 때문에 지금은 잔금대출로 집값의 70%를 대출받아 기존 중도금 대출을 갚고 나머지 20%만 본인 돈으로 충당하면 집을 살 수 있다.</p>
# <p dmcf-pid="nCcfu6DK1b" dmcf-ptype="general">앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다. 입주 뒤 집값 상승을 노리는 투기수요를 확실히 걸러낼 초강력 대책이 될 수 있다. 하지만 부작용도 우려된다. 소득이 낮은 사회초년생 등은 청약통장을 갖고도 분양시장에 진입하는 게 어려워지기 때문이다. </p>
# <p dmcf-pid="nzh7QZekII" dmcf-ptype="general">이에 따라 잔금대출에 DTI를 적용하는 것 역시 지역 등에 따라 선별적으로 이뤄질 가능성이 높다. 현재 당국은 신규 분양 물량부터 규제를 적용할지 아니면 기존 분양 물량까지 규제 범위를 확대할지를 놓고 시뮬레이션을 하고 있다. </p>
# <p dmcf-pid="nihh22vlmu" dmcf-ptype="general">아울러 당국은 지난 2년간 완화됐던 LTV와 DTI를 다시 강화할 것으로 보인다. 현재 LTV(은행 기준)는 기존 50~60%에서 70%, DTI는 50~60%에서 60%로 완화돼 있는 상태다. 당국은 일괄적인 조이기보다 지역ㆍ집값 수준별로 기준을 다르게 적용하는 방식을 모색할 것으로 보인다.</p>
# <p dmcf-pid="naJ5HNfuMQ" dmcf-ptype="general">김동욱 기자 kdw1280@hankookilbo.com</p>
# </section>
# </div>
# </div>
# <div class="foot_view">
# <div class="wrap_brunch hc_news_pc_mArticle_brunchAuthor" style="display:none;">
# </div>
# <div class="relate_tag hc_news_pc_mArticle_relatedTags">
# <strong class="screen_out">관련 태그</strong>
# </div>
# <div class="relate_series hc_news_pc_mArticle_series" style="display:none;">
# <strong class="tit_series"><em class="tag_series">연재</em><span class="title_series"></span></strong>
# <!-- MCCP-856 연재 영역 수정 -->
# <ul class="list_series">
# </ul>
# <!-- //MCCP-856 연재 영역 수정 -->
# <a class="link_more #body #series_more" href="#none">더보기</a>
# </div>
# <div class="copyright_view">
# <span class="txt_copyright">ⓒ한국일보 www.hankookilbo.com (무단복제 및 전재, 재배포를 금지합니다)</span>
# <div class="btn_empathy hc_news_pc_mArticle_empathyButton">
# <link href="//m1.daumcdn.net/svc/original/U03/cssjs/uoclike/common/uoclike.min-20150408-2.css" rel="stylesheet" type="text/css"/>
# <div class="btn_empathy_pc" id="likeButton">
# </div>
# </div>
# </div>
# <!-- 언론사 관련기사(주요뉴스) -->
# <div class="cp_view">
# <strong class="tit_cp">한국일보 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
# <ul class="list_relate">
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045" target="_blank">실제와 너무 다른 '서울로 7017' 홍보 이미지</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22" target="_blank">[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851" target="_blank">공승연 "여진구 오빠 같아..잘생기면 오빠"</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c" target="_blank">지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">“라떼는 말이야…” 달라진 입시 풍경</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">2020학년도 수능 보는 연예인들</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">수능 출제위원장 “국어, 초고난도 문항 없다”</a></li>
# </ul>
# </div>
# <div id="alex-scroll-area"></div>
# <div class="recomm_ad hc_news_pc_mArticle_recommend_ad" id="daum-ad-root">
# </div>
# <div class="cmt_news cmt_view">
# <div class="alex-area" data-base-url="//comment.daum.net" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-initial-limit="3" data-is-mobile="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-max-length="300" data-page-limit="10" data-post-id="@20170615203441266" data-show-mask-alert="true" data-sort="R" data-use-attachment="false" data-use-emoticon="true" data-use-live-comment-mode="notify" data-use-my="true" data-use-official="true" data-use-reply="true" data-use-social-share="true" id="alex-area">
# </div>
# </div>
# </div>
# </div>
# <div class="hcg_media_pc_mAside" id="mAside">
# <div class="hc_news_pc_cSub_bnr_130" style="position:relative">
# <div class="bnr_130">
# <ins class="daum_ddn_area" data-ad-height="250" data-ad-type="P" data-ad-unit="05d90" data-ad-width="130" id="RIGHT_SPACE_BANNER" name="RIGHT_SPACE_BANNER"></ins>
# </div>
# </div>
# <!-- //130 배너 -->
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideTopAd" data-ad-height="250" data-ad-type="D" data-ad-unit="05d24" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# <div class="hc_news_pc_mAside_popular_news"></div>
# <div class="aside_g aside_phototv hc_news_pc_mAside_phototv">
# <h3 class="txt_newsview">포토&amp;TV</h3>
# <div class="cont_aside">
# <ul class="list_phototv">
# <li> <a class="link_cont" href="https://gallery.v.daum.net/p/viewer/896465/20191114102117837"> <span class="wrap_thumb"> <img alt="[머니S포토] 2020 수능, 기도하는 수험생" class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/moneyweek/20191114102117870nzub.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_photo">포토</span> </span> </span> <strong class="tit_thumb">[머니S포토] 2020 수능, 기도하는 수험생</strong> </a> </li>
# <li> <a class="link_cont" href="https://v.daum.net/v/20191114101823717?s=tv_news"> <span class="wrap_thumb"> <img alt='[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"' class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/sbscnbc/20191114101823962mwag.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_vod">영상</span> </span> </span> <strong class="tit_thumb">[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"</strong> </a> </li>
# </ul>
# </div>
# </div>
# <div class="aside_g aside_search hc_news_pc_mAside_realtimeSearch">
# <h3 class="txt_newsview">실시간 이슈</h3>
# <ul class="tab_aside tab_media" id="search_rank_tab_heads">
# <li><a class="link_tab link_tab1" href="#search_rank_total">전체</a>
# <div class="cont_aside" id="search_rank_total">
# <strong class="screen_out">전체</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9C%A0%EB%A6%AC+%EC%98%A4%EB%B9%A0&amp;DA=23H&amp;rtmaxcoll=1TH">유리 오빠</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%8B%9C%EA%B0%84%ED%91%9C&amp;DA=23H&amp;rtmaxcoll=1TH">수능 시간표</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23H&amp;rtmaxcoll=1TH">흑사병</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">김경란</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EA%B5%AD%EC%96%B4&amp;DA=23H&amp;rtmaxcoll=1TH">수능 국어</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%9D%80%ED%98%9C&amp;DA=23H&amp;rtmaxcoll=1TH">박은혜</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%A1%B0%EA%B5%AD&amp;DA=23H&amp;rtmaxcoll=1TH">조국</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%B8%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">호란</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%8B%9C%ED%98%84&amp;DA=23H&amp;rtmaxcoll=1TH">시현</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EB%81%BC%EC%A4%8D%EC%87%BC&amp;DA=23H&amp;rtmaxcoll=1TH">한끼줍쇼</a> </strong> </li>
# </ol>
# </div> </li>
# <li class="on"><a class="link_tab link_tab2" href="#search_rank_news">뉴스</a>
# <div class="cont_aside" id="search_rank_news">
# <strong class="screen_out">뉴스</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%A4%91%EA%B5%AD+%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">중국 흑사병</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EA%B5%AD%EB%B0%A9%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">국방과학연구소</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=2020%EC%88%98%EB%8A%A5&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">2020수능</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%A3%BC%EC%8B%9D+%EA%B0%9C%EC%9E%A5%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">주식 개장시간</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B2%A0&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">아베</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%EB%84%A4%EC%B9%98%EC%95%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">베네치아</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%9D%80%ED%96%89+%EC%98%81%EC%97%85%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">은행 영업시간</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EC%88%98&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">김경수</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%B6%9C%EA%B7%BC%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">수능 출근시간</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%84%9C%EB%B6%80%EA%B0%84%EC%84%A0%EB%8F%84%EB%A1%9C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">서부간선도로</a> </strong> </li>
# </ol>
# </div> </li>
# <li><a class="link_tab link_tab3" href="#search_rank_entertain">연예</a>
# <div class="cont_aside" id="search_rank_entertain">
# <strong class="screen_out">연예</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9E%A5%EC%A0%95%EC%9C%A4+%EC%9E%91%EA%B0%80&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">장정윤 작가</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B9%84%EC%98%A4%EB%B8%8C%EC%9C%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">비오브유</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EC%A0%95%EC%A4%80%EC%98%81&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">정준영</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EB%AF%BC%ED%99%98+%EC%9C%A8%ED%9D%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최민환 율희</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%97%B0%EC%88%98&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박연수</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EC%A2%85%ED%9B%88&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최종훈</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%A5%98%EC%A7%84&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">류진</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%BD%EB%A6%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">경리</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%98%81%EC%84%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박영선</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%9A%B0%EB%A6%AC+%EB%8B%A4%EC%8B%9C+%EC%82%AC%EB%9E%91%ED%95%A0+%EC%88%98+%EC%9E%88%EC%9D%84%EA%B9%8C&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">우리 다시 사랑할 수 있을까</a> </strong> </li>
# </ol>
# </div> </li>
# <li><a class="link_tab link_tab4" href="#search_rank_sports">스포츠</a>
# <div class="cont_aside" id="search_rank_sports">
# <strong class="screen_out">스포츠</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EB%94%94%EA%B7%B8%EB%A1%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">디그롬</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%ED%8A%B8%EB%82%A8+%EC%B6%95%EA%B5%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">베트남 축구</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%B0%EA%B5%AC%EC%84%A0%EC%88%98+%EC%9D%B4%EB%8B%A4%ED%98%84&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">배구선수 이다현</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%84%EB%8C%80%EA%B1%B4%EC%84%A4+%EB%A7%88%EC%95%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">현대건설 마야</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EA%B5%AD+%EB%A0%88%EB%B0%94%EB%85%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">한국 레바논</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%82%AC%EC%9D%B4%EC%98%81%EC%83%81+%EB%B0%9C%ED%91%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">사이영상 발표</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%91%90%EB%B0%94%EC%9D%B4%EC%BB%B5&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">두바이컵</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%8C%EB%A6%BF+%EC%BD%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">게릿 콜</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B8%8C%EB%9D%BC%ED%95%A8&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">아브라함</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%8C%EB%9E%9C%EB%8D%94&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">벌랜더</a> </strong> </li>
# </ol>
# </div> </li>
# </ul>
# </div>
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideBottomAd" data-ad-height="250" data-ad-type="D" data-ad-unit="0QH44" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# </div>
# </div>
# <div class="hcg_media_pc_cEtc" id="cEtc">
# <div class="realtime_view">
# <div class="inner_realtime">
# <div class="realtime_news hc_news_pc_cEtc_realtime_news_201904">
# <h3 class="txt_newsview">이 시각 추천뉴스</h3>
# <ul class="list_realtime"></ul>
# </div>
# <div class="realtime_aside" id="realtime_aside">
# <div class="aside_g aside_issue hc_news_pc_cEtc_realtimeIssue">
# <h3 class="txt_newsview">실시간 주요이슈</h3>
# <span class="info_aside">2019.11.14. 10:21 기준</span>
# <div class="cont_aside">
# <ul class="list_issue">
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1636831"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/14/Edaily/20191114101621310dwka.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1636831">2020 대학수학능력시험</a> </strong>
# </div> </li>
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1655045"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/10/NEWS1/20191110060012287qmyk.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1655045">유승준 판결 논란</a> </strong>
# </div> </li>
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1707294"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/14/NEWS1/20191114101926748gsry.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1707294">지소미아 종료</a> </strong>
# </div> </li>
# </ul>
# </div>
# </div>
# <div class="shopad_news aside_g aside_shopping hc_news_pc_cEtc_shopping" id="daum-sfocus-root"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- // kakaoContent -->
# <hr class="hide"/>
# <div class="hcg_media_pc_translation_status">
# <!-- 번역중 -->
# <div class="translate_layer" id="translatingLayer">
# <!-- 레이어 열리면 display:block; 스타일 추가 -->
# <div class="inner_translate_layer">
# <div class="layer_body">
# <strong class="tit_translate"> 번역중 <span class="eng_tit">Now in translation</span> </strong>
# </div>
# </div>
# </div>
# <!-- 번역 오류 -->
# <div class="translate_layer" id="translateErrorLayer">
# <!-- 레이어 열리면 display:block; 스타일 추가 -->
# <div class="inner_translate_layer inner_error_layer">
# <div class="layer_body">
# <span class="ico_newsview ico_error"></span>
# <strong class="tit_translate"> 잠시 후 다시 시도해 주세요 <span class="eng_tit">Please try again in a moment</span> </strong>
# </div>
# </div>
# </div>
# </div>
# <!-- 번역상태 레이어 -->
# <div class="footer_comm hcg_media_pc_kakaoFoot" id="kakaoFoot" role="contentinfo">
# <div class="inner_foot">
# <div class="direct_link">
# <h2 class="tit_direct">바로가기</h2>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/">뉴스홈</a>
# <a class="link_txt" href="http://media.daum.net/society/">사회</a>
# <a class="link_txt" href="http://media.daum.net/politics/">정치</a>
# <a class="link_txt" href="http://media.daum.net/economic/">경제</a>
# <a class="link_txt" href="http://media.daum.net/foreign/">국제</a>
# <a class="link_txt" href="http://media.daum.net/culture/">문화</a>
# <a class="link_txt" href="http://media.daum.net/digital/">IT</a>
# <a class="link_txt" href="http://media.daum.net/photo/">포토</a>
# <a class="link_txt" href="http://media.daum.net/tv/">TV</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/issue/">이슈</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/cp/">언론사별 뉴스</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/newsbox/">배열이력</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/breakingnews/">전체뉴스</a>
# <a class="link_txt" href="http://media.daum.net/ranking/popular/">랭킹</a>
# <a class="link_txt" href="http://media.daum.net/series/">연재</a>
# <a class="link_txt" href="http://media.daum.net/1boon/">1boon</a>
# </div>
# <button class="btn_fold" type="button"><span class="ico_news">바로가기 링크 더보기/접기</span></button>
# </div>
# <h2 class="screen_out">서비스 이용정보</h2>
# <div class="footer_link">
# <a class="link_info" href="//media.daum.net/info/intro.html">다음뉴스 소개</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//media.daum.net/info/notice/">공지사항</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//news.daum.net/info/bbsrule">게시물 운영원칙</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="http://policy.daum.net/info/info">서비스 약관/정책</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//with.kakao.com/media">뉴스제휴</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//business.kakao.com/">비즈니스</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//cs.daum.net/redbell/top.html">권리침해신고</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//cs.daum.net/faq/63.html">다음뉴스 고객센터</a>
# </div>
# <div class="footer_link">
# <a class="link_info" href="//news.daum.net/info/newscenter24">24시간 뉴스센터</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//news.daum.net/info/edit">서비스원칙</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//media.daum.net/info/correct/">바로잡습니다</a>
# <span class="txt_dot"> ・ </span>
# <span class="link_info">기사배열책임자 : 손정아</span>
# <span class="txt_dot"> ・ </span>
# <span class="link_info">청소년보호책임자 : 권대열</span>
# </div>
# <div class="info_copyright">
# <strong class="info_warn">위 내용에 대한 저작권 및 법적 책임은 자료제공사 또는 <br/>글쓴이에 있으며, Kakao의 입장과 다를 수 있습니다.</strong>
# <small class="txt_copyright">Copyright © <strong class="txt_kakao"><a class="link_kakao" href="http://www.kakaocorp.com/">Kakao Corp.</a></strong> All rights reserved.</small>
# </div>
# </div>
# </div>
# <div id="wrapMinidaum"></div>
# </div>
# <div class="hcg_media_pc_last_js">
# <div class="hc_gallery_icon_on_image"></div>
# </div>
# <script src="//t1.daumcdn.net/harmony_static/view_cloud/2019/07/01/183439/media/common_pc.js" type="text/javascript"></script>
# <script>
#       document.domain = 'daum.net';
#       window.docId = 'nkhSoinQsa';
#       window.newsId = '20170615203441266';
#       window.serviceId = 'news';
#       window.title = '잔금대출에도 DTI 규제 적용 검토';
#       window.uccStatus = true;
#       window.realMode = 'true' == 'true' ? true : false;
#       window.isDaumApp = 'false' == 'true' ? true : false;
#       window.layoutId = 'media_pc';
#       window.cpId = '49';
#       window.mc2Connect = new Mc2.Mc2ConnectV2({
#         contentId: 'news,' + window.newsId,
#         clusterType: 'author,issuecluster,series,planning,tv,video',
#         clusterSize: 1,
#         contentsType: 'news',
#         contentsCount: 5
#       });
#     </script>
# <script>
#             $(".layer_summary p").addClass("desc_news");
#           </script>
# <script>
#             var ttsPlayerSrcMap = {};
#           </script>
# <script>
#             ttsPlayerSrcMap.slow_Male = "http://k-v1.kakaocdn.net/dn/NOgW7/btqgKWvtqGv/CQTdjDUR8uSGZXdMgPZ7A1/original.m4a";
#             ttsPlayerSrcMap.normal_Male = "http://k-v1.kakaocdn.net/dn/cXPoNE/btqgLdpZ1XH/0kIcLNoARmcaqkhk2SHU4K/original.m4a";
#             ttsPlayerSrcMap.fast_Male = "http://k-v1.kakaocdn.net/dn/b66M8d/btqgLjKgomG/D2ix5CwksQaIhaKc9AfHL1/original.m4a";
#             ttsPlayerSrcMap.slow_Female = "http://k-v1.kakaocdn.net/dn/9mKZv/btqgLi5D021/JsjWeBVKUi4p9QRJq2yB40/original.m4a";
#             ttsPlayerSrcMap.normal_Female = "http://k-v1.kakaocdn.net/dn/l2fEG/btqgLdXP5vd/SuJrPdCJIMDyKW75c5vnk1/original.m4a";
#             ttsPlayerSrcMap.fast_Female = "http://k-v1.kakaocdn.net/dn/bn9fI7/btqgLkColIa/XkhP2boJTxpSGpaZ0Nnsjk/original.m4a";
#           </script>
# <script>
#               var dmcfLanguage = 'ko';
#           	</script>
# <script src="//t1.daumcdn.net/daumtop_deco/socialshare/socialshare_nocss_pc-2.3.1.js"></script>
# <script src="//t1.daumcdn.net/section/uoclike/20180727165723/uoclike.js"></script>
# <script>
#         (function(){
#           window.excludeCorejs = true;
#           window.alexConfig = {
#             label: {emptyImage: '//i1.daumcdn.net/img-section/enter2013/liveviewer/pc_emot_co.gif'}
#           };
#
#              })();
#       </script>
# <script src="//comment.daum.net/js/latest/alex.single.min.js"></script>
# <script type="text/javascript">
#         // tiara 설정
#
#       $(function(){
#         window._tiq = 'undefined' !== typeof window._tiq ? window._tiq : [];
#             _tiq.push(['__clickOn']);
#             _tiq.push(['__setConfig', 'enableButton', true]);
#             _tiq.push(['__setPageName', 'newsview']);
#       		 _tiq.push(['__setSection', 'economic']);
#
#         //tiara 컨텐츠 통계
#         var __TiaraObj = __TiaraObj || {};
#         if ('undefined' === typeof __TiaraObj.startTime) {
#             __TiaraObj.startTime = new Date();
#         }
#
#         _tiq.push(['__setConfig', {enableScroll:true}]);
#         _tiq.push(['__trackPageview']);
#
#
#         var ua = navigator.userAgent.toLowerCase();
#         var isIOS = /iP[ao]d|iPhone/i.test(ua);
# 		var contentInfo = {
#                 "c_id": "20170615203441266",
#                 "type": "article",
#                 "harmony_consumer_id": "media",
#                 "c_title": "잔금대출에도 DTI 규제 적용 검토",
#                 "default_category_id": "1041",
#                 "category": "economic",
#                 "author": "김동욱",
#                 "author_id": "kdw1280@hankookilbo.com",
#                 "cp": "한국일보",
#                 "cp_id": "49",
#                 "regdate": "2017-06-15 20:34:40", // 등록일
#                 "plink": "https://news.v.daum.net/v/20170615203441266",
#                 "image": "https://t1.daumcdn.net/news/201706/15/hankooki/20170615044256378kzbd.jpg", // 대표 이미지
#                 "media":  "pcweb"
#             };
#         var durationSender = function() {
#             _tiq.push(['__content', 't_content', contentInfo]);
#         };
#         durationSender();
#
#         var pageScrollStaytimeFn = function() {
#             _tiq.push(['__content', 't_content_ex', {
#                 "data_type":"usage",
#                 "meta": contentInfo
#             }]);
#             removeEvent(isIOS ? "pagehide" : "beforeunload", pageScrollStaytimeFn);
#         }
#         var addEvent = function (evt, fn) {
#             window.addEventListener
#                     ? window.addEventListener(evt, fn, false)
#                     : window.attachEvent('on' + evt, fn);
#         };
#
#         var removeEvent = function(evt, fn) {
#             window.removeEventListener
#                 ? window.removeEventListener(evt, fn, false)
#                 : window.detachEvent('on' + evt, fn);
#         };
#
#         addEvent(isIOS ? "pagehide" : "beforeunload", pageScrollStaytimeFn);
#
#         // s2graph insert
#         _s2Imps = 'undefined' !== typeof _s2Imps ? _s2Imps : [];
# ...
#
# (0,eval("(function(elements){\nvar TAB_HEADS \x3d $(\x22#search_rank_tab_heads \x3e li \x3e a\x22).each(function() {\n  this.tabId \x3d this.hash.substring(1);\n  this.tab \x3d $(\x27#\x27 +  this.tabId);\n  $(this).on(\x27mouseover focus\x27, function (ev) {\n    var selection \x3d this.tabId;\n\n    ev.originalEvent.preventDefault();\n    TAB_HEADS.each(function () {\n      if (this.tabId \x3d\x3d\x3d selection) {\n        $(this).parent().addClass(\x27on\x27);\n        this.tab.css(\x27display\x27, \x27block\x27);\n      } else {\n        $(this).parent().removeClass(\x27on\x27);\n        this.tab.css(\x27display\x27, \x27none\x27);\n      }\n    });\n  });\n  $(this).on(\x27click\x27, function (ev) {\n    var e \x3d ev.originalEvent || ev;\n    e.preventDefault();\n  });\n});\n})(document.querySelectorAll(\x22.hc_news_pc_mAside_realtimeSearch\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_cEtc\x22));"));
#
# (0,eval("(function(elements){\n(function($){\n\t\x27use strict\x27;\n\tvar summaryButton \x3d $(\x27.btn_summary\x27);\n\tvar summaryLayer \x3d $(\x27.util_summary\x27);\n\tvar shareButtonsLayer \x3d $(\x27#shareButtons\x27);\n\tvar summaryLayerStatus \x3d false;\n\n\tsummaryButton.on(\x27click\x27, function (ev) {\n\t\tsummaryLayerStatus \x3d !summaryLayerStatus;\n\n\t\tif (summaryLayerStatus) {\n\t\t\tshowLayer();\n\t\t} else {\n\t\t\thideLayer();\n\t\t}\n\t});\n\t\n\tsummaryLayer.focusin(function(event) {\n\t\tshowLayer();\n    });\n\tsummaryLayer.focusout(function(event) {\n\t\thideLayer();\n    });\n\n\tfunction showLayer () {\n\t\tsummaryLayer.addClass(\x27layer_open\x27);\n\t\tsummaryButton.attr(\x27aria-expanded\x27, true);\n\t\t$(window).on(\x27click\x27, checkLayer);\n\t}\n\n\tfunction hideLayer () {\n\t\tsummaryLayerStatus \x3d false;\n\t\tsummaryLayer.removeClass(\x27layer_open\x27);\n\t\tsummaryButton.attr(\x27aria-expanded\x27, false);\n\t}\n\n\tfunction checkLayer (ev) {\n\t\t\tif (summaryButton[0] \x3d\x3d ev.target || summaryButton[0].childNodes[0] \x3d\x3d ev.target) return false;\n\t\t\thideLayer();\n\t\t\t$(window).off(\x27click\x27, checkLayer);\n\t}\n})(jQuery);\n})(document.querySelectorAll(\x22.hcg_media_pc_cSub\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_head\x22));"));
#
# (0,eval("(function(elements){\n$(\x22.direct_link .btn_fold\x22).click(function() { \n\t$(\x22.direct_link\x22).toggleClass(\x22direct_open\x22);\n});\n\n})(document.querySelectorAll(\x22.hcg_media_pc_kakaoFoot\x22));"));
#
# (0,eval("(function(elements){\nvar kakaoWrap \x3d document.getElementById(\x27kakaoWrap\x27);\nvar categoryName \x3d $(elements).find(\x22.gnb_comm\x22).data(\x22category\x22);\ncategoryName \x3d window.layoutId \x3d\x3d \x27tvNews_pc\x27 ? \x27tv\x27 : categoryName;\n\n$(elements).find(\x22.gnb_comm li\x22).each(function() {\n  var $this \x3d $(this);\n  if($this.hasClass(categoryName)) {\n    $this.addClass(\x22on\x22).find(\x22.inner_bar\x22).css(\x22width\x22, \x22100%\x22);\n  }\n});\n\n//\uac80\uc0c9 suggest\n$.ajax({url:\x22https://s1.daumcdn.net/svc/original/U03/cssjs/pcSuggest/suggest-1.2.14.min.js\x22, cache:true, dataType:\x22script\x22}).done(function(){\n  var suggestInstance \x3d new suggest.Suggest(document.getElementById(\x22search_news\x22), {\n    inputEl: \x27qVal\x27,\n    suggestBoxEl: \x27suggestBox\x27,\n    autoFocus: \x27NORMAL\x27,\n    suggestLimit: 10,\n    isReverse: false,\n    searchURL: \x27https://search.daum.net/search\x27,\n    APIServer: {\n      host: \x27https://apihub.daum.net/suggest/v2/pc.json\x27,\n      queries: {\n        \x27mod\x27: \x27json\x27,\n        \x27code\x27: \x27utf_in_out\x27,\n        \x27appkey\x27 : \x279c97934ebab4c7e024c3a6e450ec195c\x27\n      }\n    }\n  });\n\n  // \ucd94\ucc9c \uac80\uc0c9\uc5b4 \ub9c8\uc6b0\uc2a4 \ud074\ub9ad\uc2dc \uac80\uc0c9\uc73c\ub85c \ubcf4\ub0b8\ub2e4.\n  suggestInstance.on(\x27click-item\x27, function () {\n    var $kakaoSearch \x3d $(\x27#kakaoSearch\x27);\n    $kakaoSearch.find(\x22input[name\x3d\x27DA\x27]\x22).val(\x2723B\x27);\n    $kakaoSearch.submit();\n  });\n\n  var queryInput \x3d $(\x22#qVal\x22);\n  queryInput.on(\x22focus\x22, function (e) {\n    e \x26\x26 e.preventDefault();\n    if (queryInput.val().length \x3e\x3d 0) {\n      queryInput.parent().addClass(\x22search_on\x22);\n    }\n  });\n  queryInput.on(\x22focusout\x22, function (e) {\n    e \x26\x26 e.preventDefault();\n    if (queryInput.val().length \x3d\x3d 0) {\n      queryInput.parent().removeClass(\x22search_on\x22);\n    }\n  });\n});\n\n})(document.querySelectorAll(\x22.hcg_media_pc_kakaoHead\x22));"));
#
# (0,eval("(function(elements){\n$(function(){\n    // click code\n    var click_codes \x3d [];\n    // GNB \n    click_codes.push({\n        \x22code\x22: \x22#logo\x22 , \x22selector\x22: \x22#kakaoHead \x3e div.head_media \x3e h1 \x3e a.link_daum\x22\n    });\n  \tclick_codes.push({\n        \x22code\x22: \x22#logo\x22 , \x22selector\x22: \x22.img_logo\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_news\x22 , \x22selector\x22: \x22#kakaoServiceLogo\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_enter\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(1) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_sports\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(2) \x3e a\x22\n    });\n  \tclick_codes.push({\n        \x22code\x22: \x22#gnb #default #service_lab\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(3) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #search\x22 , \x22selector\x22: \x22#kakaoBtnSearch\x22\n    });\n\n    click_codes.push({\n        \x22code\x22: \x22#media_home\x22 , \x22selector\x22: \x22.home \x3e a\x22\n    });\t\n    click_codes.push({\n        \x22code\x22: \x22#media_society\x22 , \x22selector\x22: \x22.society \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_politics\x22 , \x22selector\x22: \x22.politics \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_economic\x22 , \x22selector\x22: \x22.economic \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_foreign\x22 , \x22selector\x22: \x22.foreign \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_culture\x22 , \x22selector\x22: \x22.culture \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_digital\x22 , \x22selector\x22: \x22.digital \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_popular\x22 , \x22selector\x22: \x22.popular \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_series\x22 , \x22selector\x22: \x22.series \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_photo\x22 , \x22selector\x22: \x22.photo \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_tv\x22 , \x22selector\x22: \x22.tv \x3e a\x22\n    });\n\n    // \uc678\ubd80 \uc11c\ube44\uc2a4 \ub9c1\ud06c\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #media_1boon\x22 , \x22selector\x22: \x22#kakaoGnb \x3e div \x3e div \x3e ul \x3e li:nth-child(1) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #media_funding\x22 , \x22selector\x22: \x22#kakaoGnb \x3e div \x3e div \x3e ul \x3e li:nth-child(2) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #widget_weather\x22 , \x22selector\x22: \x22#gnb_weather \x3e ul \x3e li \x3e a\x22\n    });\n\n    // \uae30\ub2a5 \uc601\uc5ed\n    click_codes.push({\n        \x22code\x22: \x22#util #widget_comment\x22 , \x22selector\x22: \x22#cSub .link_cmt\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #btn_summary\x22 , \x22selector\x22: \x22button.btn_summary\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #btn_share\x22 , \x22selector\x22: \x22button.btn_share\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #facebook\x22 , \x22selector\x22: \x22a.link_fb\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #kakaostory\x22 , \x22selector\x22: \x22a.link_ks\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #twitter\x22 , \x22selector\x22: \x22a.link_tw\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #mail\x22 , \x22selector\x22: \x22a.link_mail\x22\n    });\n    click_codes.push( ...
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_mArticle\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_mAside\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_translation_status\x22));"));
#
#
#
#
#
#
#
# (0,eval("(function(){ \n//\ubbf8\ub2c8\ub2e4\uc74c\n$(function(){\n  window.minidaum_options \x3d { \n    enableLogoutRetun: true\n  }\n\n  $.ajax({url:\x22https://go.daum.net/minidaum_pc.daum\x22,cache:\x22true\x22,dataType:\x22script\x22});\n});\n\n// \uad11\uace0\n$(function(){\n  var channel \x3d \x27harmony\x27;\n  var cp \x3d window.cpId + \x27_pc_media_news\x27;\n  $(\x27.daum_ddn_area\x27).attr(\x27data-ad-param-channel\x27, channel).attr(\x27data-ad-param-cp\x27, cp);\n  $.ajax({\n    url: \x22//t1.daumcdn.net/adfit/static/ad.min.js\x22,\n    cache: true,\n    dataType: \x22script\x22\n  });\n});\n\n// floating GNB \x26 Wing\n$(function () {\n  var $window \x3d $(window),\n      $cMain \x3d $(\x22#cMain\x22),\n      $kakaoWrap \x3d $(\x22#kakaoWrap\x22),\n      $kakaoGnb \x3d $(\x22#kakaoGnb\x22),\n      headHeight \x3d $(\x22#wrapMinidaum\x22).outerHeight() + $(\x22.head_media\x22).outerHeight(),\n      $mArticle \x3d $(\x22#mArticle\x22),\n      $mAside \x3d $(\x22#mAside\x22),\n      adFirst \x3d $(\x22.aside_ad:first\x22),\n      adLast \x3d $(\x22.aside_ad:last\x22),\n      cmNews \x3d $(\x22.cmt_news\x22),\n      $barProgress \x3d $(\x22#barProgress\x22),\n      // \ub0a0\uac1c \ud53d\uc2a4\ub4dc\uc778 \uacbd\uc6b0 left \uc704\uce58\ub97c \uc9c0\uc815\ud558\uae30 \uc704\ud574 \ud558\ub2e8 \uc2e4\uc2dc\uac04 \uac80\uc0c9\uc5b4\uc758 left \uac12\uc744 \uc774\uc6a9. \ub9cc\uc57d \uc5c6\uc73c\uba74 \uacc4\uc0b0\uc744 \ud55c\ub2e4.\n      realtimeAsideEl \x3d document.getElementById(\x27realtime_aside\x27);\n\n\n  var floatGnb \x3d function () {\n    if ($window.scrollTop() \x3e headHeight) {\n      var scrollPercent \x3d 100 * $window.scrollTop() / ($(document).height() - $window.height());\n      $kakaoWrap.addClass(\x22header_fixed\x22);\n      $barProgress.width(parseInt(scrollPercent, 10) + \x22%\x22);\n    } else {\n      $kakaoWrap.removeClass(\x22header_fixed\x22);\n    }\n  };\n\n  var floatWing \x3d function () {\n    var cMainWidth \x3d $cMain.width(),\n        mArticleWidth \x3d $mArticle.width(),\n        mAsideWidth \x3d $mAside.width(),\n        aSideGap \x3d cMainWidth - mArticleWidth - mAsideWidth,\n        leftOfRealtimeAside \x3d realtimeAsideEl ? (realtimeAsideEl.getBoundingClientRect().left \x3c 880 ? realtimeAsideEl.getBoundingClientRect().left + $(window).scrollLeft() : realtimeAsideEl.getBoundingClientRect().left ) :  mArticleWidth + aSideGap + parseInt($cMain.css(\x22marginLeft\x22), 10) - $window.scrollLeft(),\n        topPosition \x3d $window.scrollTop() - 8 - ($cMain.position().top + adFirst.height());\n\n    if($(\x22#mArticle\x22).outerHeight() \x3c $(\x22#mAside\x22).outerHeight())\n      return;\n\n    $(\x22.cmt_view\x22).css(\x22min-height\x22, \x22250px\x22);\n    if (topPosition \x3e 0) {\n      var articleHeight \x3d $mArticle.outerHeight() - cmNews.outerHeight();\n      var wingHeight \x3d $mAside.outerHeight() - adLast.outerHeight();\n      if (articleHeight \x3e (wingHeight + topPosition + 8)) {\n        $mAside.css({\n          \x22position\x22 : \x22fixed\x22,\n          \x22top\x22 : $kakaoGnb.height() - adFirst.outerHeight() - 74,\n          \x22left\x22 : parseInt(leftOfRealtimeAside, 10)\n        });\n      } else {\n        $mAside.css({\n          \x22position\x22 : \x22relative\x22,\n          \x22top\x22 : articleHeight - wingHeight,\n          \x22left\x22 : \x22inherit\x22\n        });\n      }\n    } else {\n      $mAside.css({\n        \x22position\x22 : \x22static\x22,\n        \x22top\x22 : \x22inherit\x22,\n        \x22left\x22 : \x22inherit\x22\n      });\n    }\n  };\n\n  $(window).on(\x22scroll\x22, function () {\n    floatGnb();\n    floatWing();\n  });\n\n  $(window).on(\x22resize\x22, function() {\n    floatWing();\n  });\n\n  floatGnb();\n  floatWing();\n\n});\n\n})();"));
#
# </script>
# </body>

# %%
type(soup.body)
# Out:
# bs4.element.Tag

# %%
div = soup.body.find_all('div', class_='newsview_media')
div
# Out:
# [<div class="newsview_media" id="kakaoWrap">
#  <!-- 2018-09-20 영어,인도네시아어 번역일 경우, lang_type1 클래스 추가 -->
#  <!-- 2018-09-20 중국어, 일본어 번역일 경우, lang_type2 클래스 추가 -->
#  <!-- 2018-09-11-v2  2018-09-20 베트남어 번역일 때 lang_type3 클래스 추가 -->
#  <div class="#gnb #default hcg_media_pc_kakaoHead" id="kakaoHead" role="banner">
#  <div class="head_media">
#  <h1> <a class="link_daum" href="https://www.daum.net/"> <img alt="Daum" class="thumb_g" height="19" src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45"/> </a> <a href="https://media.daum.net/" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a> </h1>
#  <strong class="screen_out">관련서비스</strong>
#  <ul id="kakaoRelServices">
#  <li><a class="link_services link_services1" href="https://media.daum.net/entertain/"><span class="ir_wa">연예</span></a></li>
#  <li><a class="link_services link_services2" href="https://sports.media.daum.net/sports/"><span class="ir_wa">스포츠</span></a></li>
#  </ul>
#  <h2 class="screen_out">검색</h2>
#  <div class="search_news" id="search_news">
#  <form action="https://search.daum.net/search" id="kakaoSearch" method="get" name="kakaoSearch">
#  <fieldset class="fld_inside">
#  <legend class="screen_out">검색어 입력폼</legend>
#  <div class="box_searchbar">
#  <label class="lab_search" for="qVal">통합검색</label>
#  <input name="nil_profile" type="hidden" value="search"/>
#  <input name="nil_src" type="hidden" value="media"/>
#  <input name="DA" type="hidden" value="23A"/>
#  <input name="rtmaxcoll" type="hidden" value="NNS"/>
#  <input autocomplete="off" class="tf_keyword" id="qVal" name="q" spellcheck="false" title="검색어 입력" type="text" value=""/>
#  <button class="btn_search" id="kakaoBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
#  </div>
#  </fieldset>
#  <div class="wrap_suggestBox" id="wrap_suggestBox">
#  <div class="suggestBox box_sub" id="suggestBox">
#  <div class="baseBox bg" style="display: none"></div>
#  </div>
#  </div>
#  </form>
#  </div>
#  </div>
#  <div id="kakaoGnb" role="navigation">
#  <div class="inner_gnb">
#  <h2 class="screen_out">뉴스 메인메뉴</h2>
#  <ul class="gnb_comm" data-category="economic">
#  <li class="home"><a class="link_gnb link_gnb1" href="https://media.daum.net/"><span class="ir_wa">홈</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="society"><a class="link_gnb link_gnb2" href="https://media.daum.net/society/"><span class="ir_wa">사회</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <!-- 현재페이지에 on클래스 추가  -->
#  <li class="politics"><a class="link_gnb link_gnb3" href="https://media.daum.net/politics/"><span class="ir_wa">정치</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="economic"><a class="link_gnb link_gnb4" href="https://media.daum.net/economic/"><span class="ir_wa">경제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="foreign"><a class="link_gnb link_gnb5" href="https://media.daum.net/foreign/"><span class="ir_wa">국제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="culture"><a class="link_gnb link_gnb6" href="https://media.daum.net/culture/"><span class="ir_wa">문화</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="digital"><a class="link_gnb link_gnb7" href="https://media.daum.net/digital/"><span class="ir_wa">IT</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="popular"><a class="link_gnb link_gnb8" href="https://media.daum.net/ranking/popular/"><span class="ir_wa">랭킹</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="series"><a class="link_gnb link_gnb9" href="https://media.daum.net/series/"><span class="ir_wa">연재</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="photo"><a class="link_gnb link_gnb10" href="https://media.daum.net/photo/"><span class="ir_wa">포토</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  <li class="tv"><a class="link_gnb link_gnb11" href="https://media.daum.net/tv/"><span class="ir_wa">TV</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  </ul>
#  <div class="gnb_etc">
#  <ul class="gnb_with">
#  <li><a class="link_gnb link_gnb1" href="https://media.daum.net/1boon/"><span class="ir_wa">1boon</span></a></li>
#  <li><a class="link_gnb link_gnb2" href="//gallery.v.daum.net/p/home"><span class="ir_wa">사진전</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#  </ul>
#  <div class="gnb_weather hc_news_pc_kakaoHead_gnbWeather">
#  <strong class="screen_out">날씨 정보</strong>
#  <div id="gnb_weather">
#  <ul class="list_weather" data-nightyn="N">
#  <!-- 69px씩 이동합니다 / 밤일 경우, type_night 클래스 추가 -->
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=서울%20날씨"> <span class="ico_weather ico_weather1">서울</span> <span class="txt_weather">서울 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=수원%20날씨"> <span class="ico_weather ico_weather1">수원</span> <span class="txt_weather">수원 <span class="num_heat">2</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=인천%20날씨"> <span class="ico_weather ico_weather1">인천</span> <span class="txt_weather">인천 <span class="num_heat">1</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대구%20날씨"> <span class="ico_weather ico_weather1">대구</span> <span class="txt_weather">대구 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대전%20날씨"> <span class="ico_weather ico_weather1">대전</span> <span class="txt_weather">대전 <span class="num_heat">3</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=광주%20날씨"> <span class="ico_weather ico_weather1">광주</span> <span class="txt_weather">광주 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=부산%20날씨"> <span class="ico_weather ico_weather1">부산</span> <span class="txt_weather">부산 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울산%20날씨"> <span class="ico_weather ico_weather1">울산</span> <span class="txt_weather">울산 <span class="num_heat">5</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울릉/독도%20날씨"> <span class="ico_weather ico_weather3">울릉/독도</span> <span class="txt_weather">울릉/독도 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=춘천%20날씨"> <span class="ico_weather ico_weather1">춘천</span> <span class="txt_weather">춘천 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=강릉%20날씨"> <span class="ico_weather ico_weather1">강릉</span> <span class="txt_weather">강릉 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=백령%20날씨"> <span class="ico_weather ico_weather2">백령</span> <span class="txt_weather">백령 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=청주%20날씨"> <span class="ico_weather ico_weather1">청주</span> <span class="txt_weather">청주 <span class="num_heat">2</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=전주%20날씨"> <span class="ico_weather ico_weather2">전주</span> <span class="txt_weather">전주 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=목포%20날씨"> <span class="ico_weather ico_weather2">목포</span> <span class="txt_weather">목포 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=여수%20날씨"> <span class="ico_weather ico_weather1">여수</span> <span class="txt_weather">여수 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=제주%20날씨"> <span class="ico_weather ico_weather3">제주</span> <span class="txt_weather">제주 <span class="num_heat">11</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=안동%20날씨"> <span class="ico_weather ico_weather1">안동</span> <span class="txt_weather">안동 <span class="num_heat">3</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=창원%20날씨"> <span class="ico_weather ico_weather1">창원</span> <span class="txt_weather">창원 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="bar_progress" id="barProgress"></div>
#  </div>
#  <hr class="hide hcg_media_pc_kakaoHead"/>
#  <div class="cont_view" id="kakaoContent" role="main">
#  <h2 class="screen_out" id="kakaoBody">경제</h2>
#  <div class="hcg_media_pc_cSub" id="cSub">
#  <div class="head_view">
#  <em class="info_cp"> <a class="link_cp #body #cplogo" href="http://www.hankookilbo.com" target="_blank"> <img alt="한국일보" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_hankooki.gif"/> </a> </em>
#  <h3 class="tit_view" data-translation="">잔금대출에도 DTI 규제 적용 검토</h3>
#  <span class="info_view"> <span class="txt_info">김동욱</span> <span class="txt_info">입력 2017.06.15. 20:34</span> <span class="txt_info">수정 2017.06.15. 21:31</span> <button class="emph_g2 link_cmt" id="alexCounter">댓글 <span class="alex-count-area">0</span>개</button> </span>
#  <div class="util_view">
#  <!-- 2018-08-31-v2 버튼 순서 변경 / 자동요약 - TTS - 번역 - 공유 - 글씨크기 - 인쇄 순 -->
#  <!-- 자동요약 -->
#  <div class="btn_util util_summary">
#  <!-- btn_summary 클릭시, layer_open 클래스 추가 -->
#  <button aria-expanded="false" class="btn_summary #btn_summary" type="button"><span class="ico_newsview">자동요약</span></button>
#  <div class="wrap_setlayer">
#  <div class="layer_util layer_summary">
#  <p>금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다.</p>
#  <p>지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다.</p>
#  <p>앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다.</p>
#  <span class="info_summary"><span class="ico_newsview"></span>기사 제목과 주요 문장을 기반으로 자동요약한 결과입니다. 전체 맥락을 이해하기 위해서는 본문 보기를 권장합니다.</span>
#  </div>
#  </div>
#  </div>
#  <!-- TTS -->
#  <div class="btn_util tts_btn hc_news_pc_cSub_tts">
#  <button aria-expanded="false" class="btn_set btn_tts" type="button"> <span class="ico_newsview ico_speak">음성 기사 듣기</span> </button>
#  <div class="wrap_setlayer">
#  <div class="layer_util layer_set layer_tts">
#  <strong class="screen_out">음성 기사 옵션 조절 레이어</strong>
#  <ul class="list_set list_tts">
#  <li> <input class="screen_out" id="ttsGenderMale" name="ttsGender" type="radio" value="Male"/> <label class="lab_set" for="ttsGenderMale"><span class="ico_newsview"></span>남성</label> </li>
#  <li> <input class="screen_out" id="ttsGenderFemale" name="ttsGender" type="radio" value="Female"/> <label class="lab_set" for="ttsGenderFemale"><span class="ico_newsview"></span>여성</label> </li>
#  </ul>
#  <ul class="list_set list_tts list_ttsspeed">
#  <li> <input class="screen_out" id="ttsSpeedSlow" name="ttsSpeed" type="radio" value="slow"/> <label class="lab_set" for="ttsSpeedSlow"><span class="ico_newsview"></span>느림</label> </li>
#  <li> <input class="screen_out" id="ttsSpeedNormal" name="ttsSpeed" type="radio" value="normal"/> <label class="lab_set" for="ttsSpeedNormal"><span class="ico_newsview"></span>보통</label> </li>
#  <li> <input class="screen_out" id="ttsSpeedFast" name="ttsSpeed" type="radio" value="fast"/> <label class="lab_set" for="ttsSpeedFast"><span class="ico_newsview"></span>빠름</label> </li>
#  </ul>
#  </div>
#  </div>
#  <audio id="ttsPlayer" preload="none" style="display:none"></audio>
#  </div>
#  <!-- 번역 -->
#  <div class="btn_util translate_btn hc_news_pc_cSub_translateButtons">
#  <!-- 활성화시 aria-expanded="true" / 비활성화시 aria-expanded="false" 추가 -->
#  <button aria-expanded="false" class="btn_set btn_translate #util #translate #set" type="button"><span class="ico_newsview">번역 설정</span></button>
#  <div class="wrap_translatelayer">
#  <div class="layer_util layer_translate">
#  <strong class="tit_translate">번역<span class="ico_newsview">beta</span>
#  <!-- 2018-09-04 추가--></strong>
#  <p class="desc_translate txt_newsview">Translated by <a class="link_kakaoi #util #translate #kakaoi_link" href="https://kakao.ai/" target="_blank">kakao i</a></p>
#  <strong class="screen_out">번역할 언어 선택</strong>
#  <ul class="list_lang">
#  <li> <button class="btn_lang btn_en #util #translate #lang_en" name="en"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">English</strong> </button> </li>
#  <li> <button class="btn_lang btn_ch #util #translate #lang_cn" name="cn" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">简体中文</strong> </button> </li>
#  <li> <button class="btn_lang btn_jp #util #translate #lang_jp" name="jp" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">日本語</strong> </button> </li>
#  <li> <button class="btn_lang btn_ind #util #translate #lang_id" name="id" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">Bahasa Indonesia</strong> </button> </li>
#  <li> <button class="btn_lang btn_viet #util #translate #lang_vi" name="vi" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">tiếng Việt</strong> </button> </li>
#  <li> <button class="btn_lang btn_ko #util #translate #lang_kr" name="kr" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">한국어</strong> </button> </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="hc_translator" style="display:none;"></div>
#  <!-- 공유 -->
#  <div class="btn_util share_btn hc_news_pc_cSub_shareButtons">
#  <button aria-expanded="false" class="btn_set btn_share" id="rSocialShareButton"> <span class="ico_newsview">공유</span> </button>
#  <div id="rSocialShareLayerContainer"></div>
#  </div>
#  <!-- 글씨크기 -->
#  <div class="font_btn btn_util hc_news_pc_cSub_fontSizeController">
#  <button aria-expanded="false" class="btn_set btn_font" type="button"> <span class="ico_newsview ico_font">글씨크기 조절하기</span> </button>
#  <div class="wrap_setlayer">
#  <div class="layer_util layer_set layer_font">
#  <strong class="screen_out">글자 크기 조절 레이어</strong>
#  <ul class="list_set list_font">
#  <li> <input class="screen_out" id="inpFont17" name="inpFont" type="radio" value="17"/> <label class="lab_set lab_size0" for="inpFont17"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 작은 폰트</span> </label> </li>
#  <li> <input class="screen_out" id="inpFont18" name="inpFont" type="radio" value="18"/> <label class="lab_set lab_size1" for="inpFont18"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">작은 폰트</span> </label> </li>
#  <li> <input class="screen_out" id="inpFont19" name="inpFont" type="radio" value="19"/> <label class="lab_set lab_size2" for="inpFont19"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">보통 폰트</span> </label> </li>
#  <li> <input class="screen_out" id="inpFont20" name="inpFont" type="radio" value="20"/> <label class="lab_set lab_size3" for="inpFont20"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">큰 폰트</span> </label> </li>
#  <li> <input class="screen_out" id="inpFont21" name="inpFont" type="radio" value="21"/> <label class="lab_set lab_size4" for="inpFont21"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 큰 폰트</span> </label> </li>
#  </ul>
#  </div>
#  </div>
#  <!-- // font 팝업 레이어 -->
#  </div>
#  <!-- 인쇄 -->
#  <div class="btn_util hc_news_pc_cSub_printButton">
#  <button class="btn_print" type="button"> <span class="ico_newsview">인쇄하기 새창열림</span> </button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div id="cMain">
#  <div class="hcg_media_pc_mArticle" id="mArticle">
#  <!-- 바꿔치기 -->
#  <!-- 언론중재법 -->
#  <!-- 번역 안내 -->
#  <div class="status_view" id="translateNotice" style="display:none;">
#  <span class="notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</span>
#  <span class="notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</span>
#  <span class="notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</span>
#  <span class="notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</span>
#  <span class="notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</span>
#  </div>
#  <div class="news_view" style="font-size:17px">
#  <div class="article_view" data-translation-body="" id="harmonyContainer">
#  <section dmcf-sid="ndxAvoEFLc">
#  <p dmcf-pid="nzrJ5KB3Cc" dmcf-ptype="general">내주 부동산 종합대책 발표</p>
#  <p dmcf-pid="ncFbmYUgSc" dmcf-ptype="general">집값 상승 노린 투기 분양 차단</p>
#  <p dmcf-pid="naDeB8j0HH" dmcf-ptype="general">LTVㆍDTI 규제 다시 강화할 듯</p>
#  <p dmcf-pid="ngfl6lJwwk" dmcf-ptype="general">저소득 실수요자 피해 우려도</p>
#  <figure class="figure_frm origin_fig" dmcf-pid="nYQ8LWIMpD" dmcf-ptype="figure">
#  <p class="link_figure"><img class="thumb_g_article" dmcf-mid="nkjJSoPdyb" dmcf-mtype="image" height="236" src="https://t1.daumcdn.net/news/201706/15/hankooki/20170615044256378kzbd.jpg" width="330"/></p>
#  </figure>
#  <p dmcf-pid="n8guDAko3Z" dmcf-ptype="general">금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다. 지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다. 앞으로 잔금대출에 DTI가 적용되면 소득 없는 사람이 입주 뒤 집값 상승을 노리고 분양시장에 뛰어드는 게 사실상 불가능해진다. </p>
#  <p dmcf-pid="nYPaCCRO1q" dmcf-ptype="general">금융당국 고위관계자는 15일 “잔금대출에도 DTI를 적용하는 방안을 검토 중”이라며 “다만 아직 최종 결론이 난 건 아니다”고 말했다. 정부는 내주 이 같은 내용을 포함한 부동산 종합 대책을 발표할 예정이다. </p>
#  <p dmcf-pid="naZLBbSgoZ" dmcf-ptype="general">정부가 잔금대출 DTI 적용 카드를 꺼내는 건, 집단대출을 잡지 않고선 과열된 주택시장을 진정시키기 어렵다는 판단에서다. 실제 정부는 지난해 잔금대출도 대출 초기부터 원리금을 함께 갚도록 하는 여신심사 가이드라인을 도입했지만 이렇다 할 효과를 거두지 못했다. 오히려 정부 대책에도 불구, 집단대출 증가액은 매달 늘어나는 추세인데 지난달엔 2조원으로 올 들어 최고치를 기록했다. </p>
#  <p dmcf-pid="nhAfneUtnA" dmcf-ptype="general">아파트 분양 집단대출은 중도금과 잔금대출로 구분된다. 계약금 10%를 내면 입주 전까지 집값의 60%를 중도금 대출로 받을 수 있다. 중도금 대출은 건설사 보증으로 이뤄져 소득심사를 안 거친다. 잔금대출은 건설사가 아닌 집을 담보로 이뤄지는 대출이다. LTV 규제만 적용돼 소득이 없어도 집값의 70%까지 대출이 가능하다. 때문에 지금은 잔금대출로 집값의 70%를 대출받아 기존 중도금 대출을 갚고 나머지 20%만 본인 돈으로 충당하면 집을 살 수 있다.</p>
#  <p dmcf-pid="nCcfu6DK1b" dmcf-ptype="general">앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다. 입주 뒤 집값 상승을 노리는 투기수요를 확실히 걸러낼 초강력 대책이 될 수 있다. 하지만 부작용도 우려된다. 소득이 낮은 사회초년생 등은 청약통장을 갖고도 분양시장에 진입하는 게 어려워지기 때문이다. </p>
#  <p dmcf-pid="nzh7QZekII" dmcf-ptype="general">이에 따라 잔금대출에 DTI를 적용하는 것 역시 지역 등에 따라 선별적으로 이뤄질 가능성이 높다. 현재 당국은 신규 분양 물량부터 규제를 적용할지 아니면 기존 분양 물량까지 규제 범위를 확대할지를 놓고 시뮬레이션을 하고 있다. </p>
#  <p dmcf-pid="nihh22vlmu" dmcf-ptype="general">아울러 당국은 지난 2년간 완화됐던 LTV와 DTI를 다시 강화할 것으로 보인다. 현재 LTV(은행 기준)는 기존 50~60%에서 70%, DTI는 50~60%에서 60%로 완화돼 있는 상태다. 당국은 일괄적인 조이기보다 지역ㆍ집값 수준별로 기준을 다르게 적용하는 방식을 모색할 것으로 보인다.</p>
#  <p dmcf-pid="naJ5HNfuMQ" dmcf-ptype="general">김동욱 기자 kdw1280@hankookilbo.com</p>
#  </section>
#  </div>
#  </div>
#  <div class="foot_view">
#  <div class="wrap_brunch hc_news_pc_mArticle_brunchAuthor" style="display:none;">
#  </div>
#  <div class="relate_tag hc_news_pc_mArticle_relatedTags">
#  <strong class="screen_out">관련 태그</strong>
#  </div>
#  <div class="relate_series hc_news_pc_mArticle_series" style="display:none;">
#  <strong class="tit_series"><em class="tag_series">연재</em><span class="title_series"></span></strong>
#  <!-- MCCP-856 연재 영역 수정 -->
#  <ul class="list_series">
#  </ul>
#  <!-- //MCCP-856 연재 영역 수정 -->
#  <a class="link_more #body #series_more" href="#none">더보기</a>
#  </div>
#  <div class="copyright_view">
#  <span class="txt_copyright">ⓒ한국일보 www.hankookilbo.com (무단복제 및 전재, 재배포를 금지합니다)</span>
#  <div class="btn_empathy hc_news_pc_mArticle_empathyButton">
#  <link href="//m1.daumcdn.net/svc/original/U03/cssjs/uoclike/common/uoclike.min-20150408-2.css" rel="stylesheet" type="text/css"/>
#  <div class="btn_empathy_pc" id="likeButton">
#  </div>
#  </div>
#  </div>
#  <!-- 언론사 관련기사(주요뉴스) -->
#  <div class="cp_view">
#  <strong class="tit_cp">한국일보 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
#  <ul class="list_relate">
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045" target="_blank">실제와 너무 다른 '서울로 7017' 홍보 이미지</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22" target="_blank">[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851" target="_blank">공승연 "여진구 오빠 같아..잘생기면 오빠"</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c" target="_blank">지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">“라떼는 말이야…” 달라진 입시 풍경</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">2020학년도 수능 보는 연예인들</a></li>
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">수능 출제위원장 “국어, 초고난도 문항 없다”</a></li>
#  </ul>
#  </div>
#  <div id="alex-scroll-area"></div>
#  <div class="recomm_ad hc_news_pc_mArticle_recommend_ad" id="daum-ad-root">
#  </div>
#  <div class="cmt_news cmt_view">
#  <div class="alex-area" data-base-url="//comment.daum.net" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-initial-limit="3" data-is-mobile="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-max-length="300" data-page-limit="10" data-post-id="@20170615203441266" data-show-mask-alert="true" data-sort="R" data-use-attachment="false" data-use-emoticon="true" data-use-live-comment-mode="notify" data-use-my="true" data-use-official="true" data-use-reply="true" data-use-social-share="true" id="alex-area">
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="hcg_media_pc_mAside" id="mAside">
#  <div class="hc_news_pc_cSub_bnr_130" style="position:relative">
#  <div class="bnr_130">
#  <ins class="daum_ddn_area" data-ad-height="250" data-ad-type="P" data-ad-unit="05d90" data-ad-width="130" id="RIGHT_SPACE_BANNER" name="RIGHT_SPACE_BANNER"></ins>
#  </div>
#  </div>
#  <!-- //130 배너 -->
#  <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideTopAd" data-ad-height="250" data-ad-type="D" data-ad-unit="05d24" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
#  <div class="hc_news_pc_mAside_popular_news"></div>
#  <div class="aside_g aside_phototv hc_news_pc_mAside_phototv">
#  <h3 class="txt_newsview">포토&amp;TV</h3>
#  <div class="cont_aside">
#  <ul class="list_phototv">
#  <li> <a class="link_cont" href="https://gallery.v.daum.net/p/viewer/896465/20191114102117837"> <span class="wrap_thumb"> <img alt="[머니S포토] 2020 수능, 기도하는 수험생" class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/moneyweek/20191114102117870nzub.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_photo">포토</span> </span> </span> <strong class="tit_thumb">[머니S포토] 2020 수능, 기도하는 수험생</strong> </a> </li>
#  <li> <a class="link_cont" href="https://v.daum.net/v/20191114101823717?s=tv_news"> <span class="wrap_thumb"> <img alt='[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"' class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/sbscnbc/20191114101823962mwag.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_vod">영상</span> </span> </span> <strong class="tit_thumb">[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"</strong> </a> </li>
#  </ul>
#  </div>
#  </div>
#  <div class="aside_g aside_search hc_news_pc_mAside_realtimeSearch">
#  <h3 class="txt_newsview">실시간 이슈</h3>
#  <ul class="tab_aside tab_media" id="search_rank_tab_heads">
#  <li><a class="link_tab link_tab1" href="#search_rank_total">전체</a>
#  <div class="cont_aside" id="search_rank_total">
#  <strong class="screen_out">전체</strong>
#  <ol class="list_ranking #right #search_keyword">
#  <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9C%A0%EB%A6%AC+%EC%98%A4%EB%B9%A0&amp;DA=23H&amp;rtmaxcoll=1TH">유리 오빠</a> </strong> </li>
#  <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%8B%9C%EA%B0%84%ED%91%9C&amp;DA=23H&amp;rtmaxcoll=1TH">수능 시간표</a> </strong> </li>
#  <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23H&amp;rtmaxcoll=1TH">흑사병</a> </strong> </li>
#  <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">김경란</a> </strong> </li>
#  <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EA%B5%AD%EC%96%B4&amp;DA=23H&amp;rtmaxcoll=1TH">수능 국어</a> </strong> </li>
#  </ol>
#  <ol class="list_ranking #right #search_keyword">
#  <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%9D%80%ED%98%9C&amp;DA=23H&amp;rtmaxcoll=1TH">박은혜</a> </strong> </li>
#  <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%A1%B0%EA%B5%AD&amp;DA=23H&amp;rtmaxcoll=1TH">조국</a> </strong> </li>
#  <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%B8%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">호란</a> </strong> </li>
#  <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%8B%9C%ED%98%84&amp;DA=23H&amp;rtmaxcoll=1TH">시현</a> </strong> </li>
#  <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EB%81%BC%EC%A4%8D%EC%87%BC&amp;DA=23H&amp;rtmaxcoll=1TH">한끼줍쇼</a> </strong> </li>
#  </ol>
#  </div> </li>
#  <li class="on"><a class="link_tab link_tab2" href="#search_rank_news">뉴스</a>
#  <div class="cont_aside" id="search_rank_news">
#  <strong class="screen_out">뉴스</strong>
#  <ol class="list_ranking #right #search_keyword">
#  <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%A4%91%EA%B5%AD+%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">중국 흑사병</a> </strong> </li>
#  <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EA%B5%AD%EB%B0%A9%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">국방과학연구소</a> </strong> </li>
#  <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=2020%EC%88%98%EB%8A%A5&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">2020수능</a> </strong> </li>
#  <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%A3%BC%EC%8B%9D+%EA%B0%9C%EC%9E%A5%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">주식 개장시간</a> </strong> </li>
#  <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B2%A0&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">아베</a> </strong> </li>
#  </ol>
#  <ol class="list_ranking #right #search_keyword">
#  <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%EB%84%A4%EC%B9%98%EC%95%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">베네치아</a> </strong> </li>
#  <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%9D%80%ED%96%89+%EC%98%81%EC%97%85%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">은행 영업시간</a> </strong> </li>
#  <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EC%88%98&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">김경수</a> </strong> </li>
#  <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%B6%9C%EA%B7%BC%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">수능 출근시간</a> </strong> </li>
#  <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%84%9C%EB%B6%80%EA%B0%84%EC%84%A0%EB%8F%84%EB%A1%9C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">서부간선도로</a> </strong> </li>
#  </ol>
#  </div> </li>
#  <li><a class="link_tab link_tab3" href="#search_rank_entertain">연예</a>
#  <div class="cont_aside" id="search_rank_entertain">
#  <strong class="screen_out">연예</strong>
#  <ol class="list_ranking #right #search_keyword">
#  <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9E%A5%EC%A0%95%EC%9C%A4+%EC%9E%91%EA%B0%80&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">장정윤 작가</a> </strong> </li>
#  <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B9%84%EC%98%A4%EB%B8%8C%EC%9C%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">비오브유</a> </strong> </li>
#  <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EC%A0%95%EC%A4%80%EC%98%81&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">정준영</a> </strong> </li>
#  <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EB%AF%BC%ED%99%98+%EC%9C%A8%ED%9D%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최민환 율희</a> </strong> </li>
#  <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%97%B0%EC%88%98&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박연수</a> </strong> </li>
#  </ol>
#  <ol class="list_ranking #right #search_keyword">
#  <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EC%A2%85%ED%9B%88&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최종훈</a> </strong> </li>
#  <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%A5%98%EC%A7%84&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">류진</a> </strong> </li>
#  <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%BD%EB%A6%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">경리</a> </strong> </li>
#  <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%98%81%EC%84%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박영선</a> </strong> </li>
#  <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%9A%B0%EB%A6%AC+%EB%8B%A4%EC%8B%9C+%EC%82%AC%EB%9E%91%ED%95%A0+%EC%88%98+%EC%9E%88%EC%9D%84%EA%B9%8C&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">우리 다시 사랑할 수 있을까</a> </strong> </li>
#  </ol>
#  </div> </li>
#  <li><a class="link_tab link_tab4" href="#search_rank_sports">스포츠</a>
#  <div class="cont_aside" id="search_rank_sports">
#  <strong class="screen_out">스포츠</strong>
#  <ol class="list_ranking #right #search_keyword">
#  <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EB%94%94%EA%B7%B8%EB%A1%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">디그롬</a> </strong> </li>
#  <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%ED%8A%B8%EB%82%A8+%EC%B6%95%EA%B5%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">베트남 축구</a> </strong> </li>
#  <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%B0%EA%B5%AC%EC%84%A0%EC%88%98+%EC%9D%B4%EB%8B%A4%ED%98%84&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">배구선수 이다현</a> </strong> </li>
#  <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%84%EB%8C%80%EA%B1%B4%EC%84%A4+%EB%A7%88%EC%95%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">현대건설 마야</a> </strong> </li>
#  <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EA%B5%AD+%EB%A0%88%EB%B0%94%EB%85%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">한국 레바논</a> </strong> </li>
#  </ol>
#  <ol class="list_ranking #right #search_keyword">
#  <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%82%AC%EC%9D%B4%EC%98%81%EC%83%81+%EB%B0%9C%ED%91%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">사이영상 발표</a> </strong> </li>
#  <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%91%90%EB%B0%94%EC%9D%B4%EC%BB%B5&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">두바이컵</a> </strong> </li>
#  <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%8C%EB%A6%BF+%EC%BD%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">게릿 콜</a> </strong> </li>
#  <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B8%8C%EB%9D%BC%ED%95%A8&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">아브라함</a> </strong> </li>
#  <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%8C%EB%9E%9C%EB%8D%94&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">벌랜더</a> </strong> </li>
#  </ol>
#  </div> </li>
#  </ul>
#  </div>
#  <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideBottomAd" data-ad-height="250" data-ad-type="D" data-ad-unit="0QH44" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
#  </div>
#  </div>
#  <div class="hcg_media_pc_cEtc" id="cEtc">
#  <div class="realtime_view">
#  <div class="inner_realtime">
#  <div class="realtime_news hc_news_pc_cEtc_realtime_news_201904">
#  <h3 class="txt_newsview">이 시각 추천뉴스</h3>
#  <ul class="list_realtime"></ul>
#  </div>
#  <div class="realtime_aside" id="realtime_aside">
#  <div class="aside_g aside_issue hc_news_pc_cEtc_realtimeIssue">
#  <h3 class="txt_newsview">실시간 주요이슈</h3>
#  <span class="info_aside">2019.11.14. 10:21 기준</span>
#  <div class="cont_aside">
#  <ul class="list_issue">
#  <li> <a class="link_thumb" href="http://media.daum.net/issue/1636831"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/14/Edaily/20191114101621310dwka.jpg" width="84"/> </a>
#  <div class="cont_thumb">
#  <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1636831">2020 대학수학능력시험</a> </strong>
#  </div> </li>
#  <li> <a class="link_thumb" href="http://media.daum.net/issue/1655045"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/10/NEWS1/20191110060012287qmyk.jpg" width="84"/> </a>
#  <div class="cont_thumb">
#  <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1655045">유승준 판결 논란</a> </strong>
#  </div> </li>
#  <li> <a class="link_thumb" href="http://media.daum.net/issue/1707294"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/14/NEWS1/20191114101926748gsry.jpg" width="84"/> </a>
#  <div class="cont_thumb">
#  <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1707294">지소미아 종료</a> </strong>
#  </div> </li>
#  </ul>
#  </div>
#  </div>
#  <div class="shopad_news aside_g aside_shopping hc_news_pc_cEtc_shopping" id="daum-sfocus-root"></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- // kakaoContent -->
#  <hr class="hide"/>
#  <div class="hcg_media_pc_translation_status">
#  <!-- 번역중 -->
#  <div class="translate_layer" id="translatingLayer">
#  <!-- 레이어 열리면 display:block; 스타일 추가 -->
#  <div class="inner_translate_layer">
#  <div class="layer_body">
#  <strong class="tit_translate"> 번역중 <span class="eng_tit">Now in translation</span> </strong>
#  </div>
#  </div>
#  </div>
#  <!-- 번역 오류 -->
#  <div class="translate_layer" id="translateErrorLayer">
#  <!-- 레이어 열리면 display:block; 스타일 추가 -->
#  <div class="inner_translate_layer inner_error_layer">
#  <div class="layer_body">
#  <span class="ico_newsview ico_error"></span>
#  <strong class="tit_translate"> 잠시 후 다시 시도해 주세요 <span class="eng_tit">Please try again in a moment</span> </strong>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- 번역상태 레이어 -->
#  <div class="footer_comm hcg_media_pc_kakaoFoot" id="kakaoFoot" role="contentinfo">
#  <div class="inner_foot">
#  <div class="direct_link">
#  <h2 class="tit_direct">바로가기</h2>
#  <div class="item_bundle">
#  <a class="link_txt" href="http://media.daum.net/">뉴스홈</a>
#  <a class="link_txt" href="http://media.daum.net/society/">사회</a>
#  <a class="link_txt" href="http://media.daum.net/politics/">정치</a>
#  <a class="link_txt" href="http://media.daum.net/economic/">경제</a>
#  <a class="link_txt" href="http://media.daum.net/foreign/">국제</a>
#  <a class="link_txt" href="http://media.daum.net/culture/">문화</a>
#  <a class="link_txt" href="http://media.daum.net/digital/">IT</a>
#  <a class="link_txt" href="http://media.daum.net/photo/">포토</a>
#  <a class="link_txt" href="http://media.daum.net/tv/">TV</a>
#  </div>
#  <div class="item_bundle">
#  <a class="link_txt" href="http://media.daum.net/issue/">이슈</a>
#  </div>
#  <div class="item_bundle">
#  <a class="link_txt" href="http://media.daum.net/cp/">언론사별 뉴스</a>
#  </div>
#  <div class="item_bundle">
#  <a class="link_txt" href="http://media.daum.net/newsbox/">배열이력</a>
#  </div>
#  <div class="item_bundle">
#  <a class="link_txt" href="http://media.daum.net/breakingnews/">전체뉴스</a>
#  <a class="link_txt" href="http://media.daum.net/ranking/popular/">랭킹</a>
#  <a class="link_txt" href="http://media.daum.net/series/">연재</a>
#  <a class="link_txt" href="http://media.daum.net/1boon/">1boon</a>
#  </div>
#  <button class="btn_fold" type="button"><span class="ico_news">바로가기 링크 더보기/접기</span></button>
#  </div>
#  <h2 class="screen_out">서비스 이용정보</h2>
#  <div class="footer_link">
#  <a class="link_info" href="//media.daum.net/info/intro.html">다음뉴스 소개</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="//media.daum.net/info/notice/">공지사항</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="//news.daum.net/info/bbsrule">게시물 운영원칙</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="http://policy.daum.net/info/info">서비스 약관/정책</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="//with.kakao.com/media">뉴스제휴</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="//business.kakao.com/">비즈니스</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="//cs.daum.net/redbell/top.html">권리침해신고</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="//cs.daum.net/faq/63.html">다음뉴스 고객센터</a>
#  </div>
#  <div class="footer_link">
#  <a class="link_info" href="//news.daum.net/info/newscenter24">24시간 뉴스센터</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="//news.daum.net/info/edit">서비스원칙</a>
#  <span class="txt_dot"> ・ </span>
#  <a class="link_info" href="//media.daum.net/info/correct/">바로잡습니다</a>
#  <span class="txt_dot"> ・ </span>
#  <span class="link_info">기사배열책임자 : 손정아</span>
#  <span class="txt_dot"> ・ </span>
#  <span class="link_info">청소년보호책임자 : 권대열</span>
#  </div>
#  <div class="info_copyright">
#  <strong class="info_warn">위 내용에 대한 저작권 및 법적 책임은 자료제공사 또는 <br/>글쓴이에 있으며, Kakao의 입장과 다를 수 있습니다.</strong>
#  <small class="txt_copyright">Copyright © <strong class="txt_kakao"><a class="link_kakao" href="http://www.kakaocorp.com/">Kakao Corp.</a></strong> All rights reserved.</small>
#  </div>
#  </div>
#  </div>
#  <div id="wrapMinidaum"></div>
#  </div>]

# %%
type(div)
# Out:
# bs4.element.ResultSet

# %%
div.find_all('div', role='main')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c60444face7b> in <module>
# ----> 1 div.find_all('div', role='main')
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
div_1 = soup.body.find_all('div', class_='newsview_media')[0]
div_1
# Out:
# <div class="newsview_media" id="kakaoWrap">
# <!-- 2018-09-20 영어,인도네시아어 번역일 경우, lang_type1 클래스 추가 -->
# <!-- 2018-09-20 중국어, 일본어 번역일 경우, lang_type2 클래스 추가 -->
# <!-- 2018-09-11-v2  2018-09-20 베트남어 번역일 때 lang_type3 클래스 추가 -->
# <div class="#gnb #default hcg_media_pc_kakaoHead" id="kakaoHead" role="banner">
# <div class="head_media">
# <h1> <a class="link_daum" href="https://www.daum.net/"> <img alt="Daum" class="thumb_g" height="19" src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45"/> </a> <a href="https://media.daum.net/" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a> </h1>
# <strong class="screen_out">관련서비스</strong>
# <ul id="kakaoRelServices">
# <li><a class="link_services link_services1" href="https://media.daum.net/entertain/"><span class="ir_wa">연예</span></a></li>
# <li><a class="link_services link_services2" href="https://sports.media.daum.net/sports/"><span class="ir_wa">스포츠</span></a></li>
# </ul>
# <h2 class="screen_out">검색</h2>
# <div class="search_news" id="search_news">
# <form action="https://search.daum.net/search" id="kakaoSearch" method="get" name="kakaoSearch">
# <fieldset class="fld_inside">
# <legend class="screen_out">검색어 입력폼</legend>
# <div class="box_searchbar">
# <label class="lab_search" for="qVal">통합검색</label>
# <input name="nil_profile" type="hidden" value="search"/>
# <input name="nil_src" type="hidden" value="media"/>
# <input name="DA" type="hidden" value="23A"/>
# <input name="rtmaxcoll" type="hidden" value="NNS"/>
# <input autocomplete="off" class="tf_keyword" id="qVal" name="q" spellcheck="false" title="검색어 입력" type="text" value=""/>
# <button class="btn_search" id="kakaoBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </fieldset>
# <div class="wrap_suggestBox" id="wrap_suggestBox">
# <div class="suggestBox box_sub" id="suggestBox">
# <div class="baseBox bg" style="display: none"></div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div id="kakaoGnb" role="navigation">
# <div class="inner_gnb">
# <h2 class="screen_out">뉴스 메인메뉴</h2>
# <ul class="gnb_comm" data-category="economic">
# <li class="home"><a class="link_gnb link_gnb1" href="https://media.daum.net/"><span class="ir_wa">홈</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="society"><a class="link_gnb link_gnb2" href="https://media.daum.net/society/"><span class="ir_wa">사회</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <!-- 현재페이지에 on클래스 추가  -->
# <li class="politics"><a class="link_gnb link_gnb3" href="https://media.daum.net/politics/"><span class="ir_wa">정치</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="economic"><a class="link_gnb link_gnb4" href="https://media.daum.net/economic/"><span class="ir_wa">경제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="foreign"><a class="link_gnb link_gnb5" href="https://media.daum.net/foreign/"><span class="ir_wa">국제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="culture"><a class="link_gnb link_gnb6" href="https://media.daum.net/culture/"><span class="ir_wa">문화</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="digital"><a class="link_gnb link_gnb7" href="https://media.daum.net/digital/"><span class="ir_wa">IT</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="popular"><a class="link_gnb link_gnb8" href="https://media.daum.net/ranking/popular/"><span class="ir_wa">랭킹</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="series"><a class="link_gnb link_gnb9" href="https://media.daum.net/series/"><span class="ir_wa">연재</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="photo"><a class="link_gnb link_gnb10" href="https://media.daum.net/photo/"><span class="ir_wa">포토</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="tv"><a class="link_gnb link_gnb11" href="https://media.daum.net/tv/"><span class="ir_wa">TV</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# </ul>
# <div class="gnb_etc">
# <ul class="gnb_with">
# <li><a class="link_gnb link_gnb1" href="https://media.daum.net/1boon/"><span class="ir_wa">1boon</span></a></li>
# <li><a class="link_gnb link_gnb2" href="//gallery.v.daum.net/p/home"><span class="ir_wa">사진전</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# </ul>
# <div class="gnb_weather hc_news_pc_kakaoHead_gnbWeather">
# <strong class="screen_out">날씨 정보</strong>
# <div id="gnb_weather">
# <ul class="list_weather" data-nightyn="N">
# <!-- 69px씩 이동합니다 / 밤일 경우, type_night 클래스 추가 -->
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=서울%20날씨"> <span class="ico_weather ico_weather1">서울</span> <span class="txt_weather">서울 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=수원%20날씨"> <span class="ico_weather ico_weather1">수원</span> <span class="txt_weather">수원 <span class="num_heat">2</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=인천%20날씨"> <span class="ico_weather ico_weather1">인천</span> <span class="txt_weather">인천 <span class="num_heat">1</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대구%20날씨"> <span class="ico_weather ico_weather1">대구</span> <span class="txt_weather">대구 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대전%20날씨"> <span class="ico_weather ico_weather1">대전</span> <span class="txt_weather">대전 <span class="num_heat">3</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=광주%20날씨"> <span class="ico_weather ico_weather1">광주</span> <span class="txt_weather">광주 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=부산%20날씨"> <span class="ico_weather ico_weather1">부산</span> <span class="txt_weather">부산 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울산%20날씨"> <span class="ico_weather ico_weather1">울산</span> <span class="txt_weather">울산 <span class="num_heat">5</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울릉/독도%20날씨"> <span class="ico_weather ico_weather3">울릉/독도</span> <span class="txt_weather">울릉/독도 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=춘천%20날씨"> <span class="ico_weather ico_weather1">춘천</span> <span class="txt_weather">춘천 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=강릉%20날씨"> <span class="ico_weather ico_weather1">강릉</span> <span class="txt_weather">강릉 <span class="num_heat">0</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=백령%20날씨"> <span class="ico_weather ico_weather2">백령</span> <span class="txt_weather">백령 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=청주%20날씨"> <span class="ico_weather ico_weather1">청주</span> <span class="txt_weather">청주 <span class="num_heat">2</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=전주%20날씨"> <span class="ico_weather ico_weather2">전주</span> <span class="txt_weather">전주 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=목포%20날씨"> <span class="ico_weather ico_weather2">목포</span> <span class="txt_weather">목포 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=여수%20날씨"> <span class="ico_weather ico_weather1">여수</span> <span class="txt_weather">여수 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=제주%20날씨"> <span class="ico_weather ico_weather3">제주</span> <span class="txt_weather">제주 <span class="num_heat">11</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=안동%20날씨"> <span class="ico_weather ico_weather1">안동</span> <span class="txt_weather">안동 <span class="num_heat">3</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=창원%20날씨"> <span class="ico_weather ico_weather1">창원</span> <span class="txt_weather">창원 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bar_progress" id="barProgress"></div>
# </div>
# <hr class="hide hcg_media_pc_kakaoHead"/>
# <div class="cont_view" id="kakaoContent" role="main">
# <h2 class="screen_out" id="kakaoBody">경제</h2>
# <div class="hcg_media_pc_cSub" id="cSub">
# <div class="head_view">
# <em class="info_cp"> <a class="link_cp #body #cplogo" href="http://www.hankookilbo.com" target="_blank"> <img alt="한국일보" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_hankooki.gif"/> </a> </em>
# <h3 class="tit_view" data-translation="">잔금대출에도 DTI 규제 적용 검토</h3>
# <span class="info_view"> <span class="txt_info">김동욱</span> <span class="txt_info">입력 2017.06.15. 20:34</span> <span class="txt_info">수정 2017.06.15. 21:31</span> <button class="emph_g2 link_cmt" id="alexCounter">댓글 <span class="alex-count-area">0</span>개</button> </span>
# <div class="util_view">
# <!-- 2018-08-31-v2 버튼 순서 변경 / 자동요약 - TTS - 번역 - 공유 - 글씨크기 - 인쇄 순 -->
# <!-- 자동요약 -->
# <div class="btn_util util_summary">
# <!-- btn_summary 클릭시, layer_open 클래스 추가 -->
# <button aria-expanded="false" class="btn_summary #btn_summary" type="button"><span class="ico_newsview">자동요약</span></button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_summary">
# <p>금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다.</p>
# <p>지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다.</p>
# <p>앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다.</p>
# <span class="info_summary"><span class="ico_newsview"></span>기사 제목과 주요 문장을 기반으로 자동요약한 결과입니다. 전체 맥락을 이해하기 위해서는 본문 보기를 권장합니다.</span>
# </div>
# </div>
# </div>
# <!-- TTS -->
# <div class="btn_util tts_btn hc_news_pc_cSub_tts">
# <button aria-expanded="false" class="btn_set btn_tts" type="button"> <span class="ico_newsview ico_speak">음성 기사 듣기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_tts">
# <strong class="screen_out">음성 기사 옵션 조절 레이어</strong>
# <ul class="list_set list_tts">
# <li> <input class="screen_out" id="ttsGenderMale" name="ttsGender" type="radio" value="Male"/> <label class="lab_set" for="ttsGenderMale"><span class="ico_newsview"></span>남성</label> </li>
# <li> <input class="screen_out" id="ttsGenderFemale" name="ttsGender" type="radio" value="Female"/> <label class="lab_set" for="ttsGenderFemale"><span class="ico_newsview"></span>여성</label> </li>
# </ul>
# <ul class="list_set list_tts list_ttsspeed">
# <li> <input class="screen_out" id="ttsSpeedSlow" name="ttsSpeed" type="radio" value="slow"/> <label class="lab_set" for="ttsSpeedSlow"><span class="ico_newsview"></span>느림</label> </li>
# <li> <input class="screen_out" id="ttsSpeedNormal" name="ttsSpeed" type="radio" value="normal"/> <label class="lab_set" for="ttsSpeedNormal"><span class="ico_newsview"></span>보통</label> </li>
# <li> <input class="screen_out" id="ttsSpeedFast" name="ttsSpeed" type="radio" value="fast"/> <label class="lab_set" for="ttsSpeedFast"><span class="ico_newsview"></span>빠름</label> </li>
# </ul>
# </div>
# </div>
# <audio id="ttsPlayer" preload="none" style="display:none"></audio>
# </div>
# <!-- 번역 -->
# <div class="btn_util translate_btn hc_news_pc_cSub_translateButtons">
# <!-- 활성화시 aria-expanded="true" / 비활성화시 aria-expanded="false" 추가 -->
# <button aria-expanded="false" class="btn_set btn_translate #util #translate #set" type="button"><span class="ico_newsview">번역 설정</span></button>
# <div class="wrap_translatelayer">
# <div class="layer_util layer_translate">
# <strong class="tit_translate">번역<span class="ico_newsview">beta</span>
# <!-- 2018-09-04 추가--></strong>
# <p class="desc_translate txt_newsview">Translated by <a class="link_kakaoi #util #translate #kakaoi_link" href="https://kakao.ai/" target="_blank">kakao i</a></p>
# <strong class="screen_out">번역할 언어 선택</strong>
# <ul class="list_lang">
# <li> <button class="btn_lang btn_en #util #translate #lang_en" name="en"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">English</strong> </button> </li>
# <li> <button class="btn_lang btn_ch #util #translate #lang_cn" name="cn" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">简体中文</strong> </button> </li>
# <li> <button class="btn_lang btn_jp #util #translate #lang_jp" name="jp" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">日本語</strong> </button> </li>
# <li> <button class="btn_lang btn_ind #util #translate #lang_id" name="id" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">Bahasa Indonesia</strong> </button> </li>
# <li> <button class="btn_lang btn_viet #util #translate #lang_vi" name="vi" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">tiếng Việt</strong> </button> </li>
# <li> <button class="btn_lang btn_ko #util #translate #lang_kr" name="kr" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">한국어</strong> </button> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="hc_translator" style="display:none;"></div>
# <!-- 공유 -->
# <div class="btn_util share_btn hc_news_pc_cSub_shareButtons">
# <button aria-expanded="false" class="btn_set btn_share" id="rSocialShareButton"> <span class="ico_newsview">공유</span> </button>
# <div id="rSocialShareLayerContainer"></div>
# </div>
# <!-- 글씨크기 -->
# <div class="font_btn btn_util hc_news_pc_cSub_fontSizeController">
# <button aria-expanded="false" class="btn_set btn_font" type="button"> <span class="ico_newsview ico_font">글씨크기 조절하기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_font">
# <strong class="screen_out">글자 크기 조절 레이어</strong>
# <ul class="list_set list_font">
# <li> <input class="screen_out" id="inpFont17" name="inpFont" type="radio" value="17"/> <label class="lab_set lab_size0" for="inpFont17"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont18" name="inpFont" type="radio" value="18"/> <label class="lab_set lab_size1" for="inpFont18"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont19" name="inpFont" type="radio" value="19"/> <label class="lab_set lab_size2" for="inpFont19"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">보통 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont20" name="inpFont" type="radio" value="20"/> <label class="lab_set lab_size3" for="inpFont20"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">큰 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont21" name="inpFont" type="radio" value="21"/> <label class="lab_set lab_size4" for="inpFont21"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 큰 폰트</span> </label> </li>
# </ul>
# </div>
# </div>
# <!-- // font 팝업 레이어 -->
# </div>
# <!-- 인쇄 -->
# <div class="btn_util hc_news_pc_cSub_printButton">
# <button class="btn_print" type="button"> <span class="ico_newsview">인쇄하기 새창열림</span> </button>
# </div>
# </div>
# </div>
# </div>
# <div id="cMain">
# <div class="hcg_media_pc_mArticle" id="mArticle">
# <!-- 바꿔치기 -->
# <!-- 언론중재법 -->
# <!-- 번역 안내 -->
# <div class="status_view" id="translateNotice" style="display:none;">
# <span class="notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</span>
# <span class="notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</span>
# <span class="notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</span>
# <span class="notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</span>
# <span class="notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</span>
# </div>
# <div class="news_view" style="font-size:17px">
# <div class="article_view" data-translation-body="" id="harmonyContainer">
# <section dmcf-sid="ndxAvoEFLc">
# <p dmcf-pid="nzrJ5KB3Cc" dmcf-ptype="general">내주 부동산 종합대책 발표</p>
# <p dmcf-pid="ncFbmYUgSc" dmcf-ptype="general">집값 상승 노린 투기 분양 차단</p>
# <p dmcf-pid="naDeB8j0HH" dmcf-ptype="general">LTVㆍDTI 규제 다시 강화할 듯</p>
# <p dmcf-pid="ngfl6lJwwk" dmcf-ptype="general">저소득 실수요자 피해 우려도</p>
# <figure class="figure_frm origin_fig" dmcf-pid="nYQ8LWIMpD" dmcf-ptype="figure">
# <p class="link_figure"><img class="thumb_g_article" dmcf-mid="nkjJSoPdyb" dmcf-mtype="image" height="236" src="https://t1.daumcdn.net/news/201706/15/hankooki/20170615044256378kzbd.jpg" width="330"/></p>
# </figure>
# <p dmcf-pid="n8guDAko3Z" dmcf-ptype="general">금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다. 지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다. 앞으로 잔금대출에 DTI가 적용되면 소득 없는 사람이 입주 뒤 집값 상승을 노리고 분양시장에 뛰어드는 게 사실상 불가능해진다. </p>
# <p dmcf-pid="nYPaCCRO1q" dmcf-ptype="general">금융당국 고위관계자는 15일 “잔금대출에도 DTI를 적용하는 방안을 검토 중”이라며 “다만 아직 최종 결론이 난 건 아니다”고 말했다. 정부는 내주 이 같은 내용을 포함한 부동산 종합 대책을 발표할 예정이다. </p>
# <p dmcf-pid="naZLBbSgoZ" dmcf-ptype="general">정부가 잔금대출 DTI 적용 카드를 꺼내는 건, 집단대출을 잡지 않고선 과열된 주택시장을 진정시키기 어렵다는 판단에서다. 실제 정부는 지난해 잔금대출도 대출 초기부터 원리금을 함께 갚도록 하는 여신심사 가이드라인을 도입했지만 이렇다 할 효과를 거두지 못했다. 오히려 정부 대책에도 불구, 집단대출 증가액은 매달 늘어나는 추세인데 지난달엔 2조원으로 올 들어 최고치를 기록했다. </p>
# <p dmcf-pid="nhAfneUtnA" dmcf-ptype="general">아파트 분양 집단대출은 중도금과 잔금대출로 구분된다. 계약금 10%를 내면 입주 전까지 집값의 60%를 중도금 대출로 받을 수 있다. 중도금 대출은 건설사 보증으로 이뤄져 소득심사를 안 거친다. 잔금대출은 건설사가 아닌 집을 담보로 이뤄지는 대출이다. LTV 규제만 적용돼 소득이 없어도 집값의 70%까지 대출이 가능하다. 때문에 지금은 잔금대출로 집값의 70%를 대출받아 기존 중도금 대출을 갚고 나머지 20%만 본인 돈으로 충당하면 집을 살 수 있다.</p>
# <p dmcf-pid="nCcfu6DK1b" dmcf-ptype="general">앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다. 입주 뒤 집값 상승을 노리는 투기수요를 확실히 걸러낼 초강력 대책이 될 수 있다. 하지만 부작용도 우려된다. 소득이 낮은 사회초년생 등은 청약통장을 갖고도 분양시장에 진입하는 게 어려워지기 때문이다. </p>
# <p dmcf-pid="nzh7QZekII" dmcf-ptype="general">이에 따라 잔금대출에 DTI를 적용하는 것 역시 지역 등에 따라 선별적으로 이뤄질 가능성이 높다. 현재 당국은 신규 분양 물량부터 규제를 적용할지 아니면 기존 분양 물량까지 규제 범위를 확대할지를 놓고 시뮬레이션을 하고 있다. </p>
# <p dmcf-pid="nihh22vlmu" dmcf-ptype="general">아울러 당국은 지난 2년간 완화됐던 LTV와 DTI를 다시 강화할 것으로 보인다. 현재 LTV(은행 기준)는 기존 50~60%에서 70%, DTI는 50~60%에서 60%로 완화돼 있는 상태다. 당국은 일괄적인 조이기보다 지역ㆍ집값 수준별로 기준을 다르게 적용하는 방식을 모색할 것으로 보인다.</p>
# <p dmcf-pid="naJ5HNfuMQ" dmcf-ptype="general">김동욱 기자 kdw1280@hankookilbo.com</p>
# </section>
# </div>
# </div>
# <div class="foot_view">
# <div class="wrap_brunch hc_news_pc_mArticle_brunchAuthor" style="display:none;">
# </div>
# <div class="relate_tag hc_news_pc_mArticle_relatedTags">
# <strong class="screen_out">관련 태그</strong>
# </div>
# <div class="relate_series hc_news_pc_mArticle_series" style="display:none;">
# <strong class="tit_series"><em class="tag_series">연재</em><span class="title_series"></span></strong>
# <!-- MCCP-856 연재 영역 수정 -->
# <ul class="list_series">
# </ul>
# <!-- //MCCP-856 연재 영역 수정 -->
# <a class="link_more #body #series_more" href="#none">더보기</a>
# </div>
# <div class="copyright_view">
# <span class="txt_copyright">ⓒ한국일보 www.hankookilbo.com (무단복제 및 전재, 재배포를 금지합니다)</span>
# <div class="btn_empathy hc_news_pc_mArticle_empathyButton">
# <link href="//m1.daumcdn.net/svc/original/U03/cssjs/uoclike/common/uoclike.min-20150408-2.css" rel="stylesheet" type="text/css"/>
# <div class="btn_empathy_pc" id="likeButton">
# </div>
# </div>
# </div>
# <!-- 언론사 관련기사(주요뉴스) -->
# <div class="cp_view">
# <strong class="tit_cp">한국일보 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
# <ul class="list_relate">
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045" target="_blank">실제와 너무 다른 '서울로 7017' 홍보 이미지</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22" target="_blank">[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851" target="_blank">공승연 "여진구 오빠 같아..잘생기면 오빠"</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c" target="_blank">지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">“라떼는 말이야…” 달라진 입시 풍경</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">2020학년도 수능 보는 연예인들</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">수능 출제위원장 “국어, 초고난도 문항 없다”</a></li>
# </ul>
# </div>
# <div id="alex-scroll-area"></div>
# <div class="recomm_ad hc_news_pc_mArticle_recommend_ad" id="daum-ad-root">
# </div>
# <div class="cmt_news cmt_view">
# <div class="alex-area" data-base-url="//comment.daum.net" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-initial-limit="3" data-is-mobile="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-max-length="300" data-page-limit="10" data-post-id="@20170615203441266" data-show-mask-alert="true" data-sort="R" data-use-attachment="false" data-use-emoticon="true" data-use-live-comment-mode="notify" data-use-my="true" data-use-official="true" data-use-reply="true" data-use-social-share="true" id="alex-area">
# </div>
# </div>
# </div>
# </div>
# <div class="hcg_media_pc_mAside" id="mAside">
# <div class="hc_news_pc_cSub_bnr_130" style="position:relative">
# <div class="bnr_130">
# <ins class="daum_ddn_area" data-ad-height="250" data-ad-type="P" data-ad-unit="05d90" data-ad-width="130" id="RIGHT_SPACE_BANNER" name="RIGHT_SPACE_BANNER"></ins>
# </div>
# </div>
# <!-- //130 배너 -->
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideTopAd" data-ad-height="250" data-ad-type="D" data-ad-unit="05d24" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# <div class="hc_news_pc_mAside_popular_news"></div>
# <div class="aside_g aside_phototv hc_news_pc_mAside_phototv">
# <h3 class="txt_newsview">포토&amp;TV</h3>
# <div class="cont_aside">
# <ul class="list_phototv">
# <li> <a class="link_cont" href="https://gallery.v.daum.net/p/viewer/896465/20191114102117837"> <span class="wrap_thumb"> <img alt="[머니S포토] 2020 수능, 기도하는 수험생" class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/moneyweek/20191114102117870nzub.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_photo">포토</span> </span> </span> <strong class="tit_thumb">[머니S포토] 2020 수능, 기도하는 수험생</strong> </a> </li>
# <li> <a class="link_cont" href="https://v.daum.net/v/20191114101823717?s=tv_news"> <span class="wrap_thumb"> <img alt='[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"' class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/sbscnbc/20191114101823962mwag.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_vod">영상</span> </span> </span> <strong class="tit_thumb">[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"</strong> </a> </li>
# </ul>
# </div>
# </div>
# <div class="aside_g aside_search hc_news_pc_mAside_realtimeSearch">
# <h3 class="txt_newsview">실시간 이슈</h3>
# <ul class="tab_aside tab_media" id="search_rank_tab_heads">
# <li><a class="link_tab link_tab1" href="#search_rank_total">전체</a>
# <div class="cont_aside" id="search_rank_total">
# <strong class="screen_out">전체</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9C%A0%EB%A6%AC+%EC%98%A4%EB%B9%A0&amp;DA=23H&amp;rtmaxcoll=1TH">유리 오빠</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%8B%9C%EA%B0%84%ED%91%9C&amp;DA=23H&amp;rtmaxcoll=1TH">수능 시간표</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23H&amp;rtmaxcoll=1TH">흑사병</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">김경란</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EA%B5%AD%EC%96%B4&amp;DA=23H&amp;rtmaxcoll=1TH">수능 국어</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%9D%80%ED%98%9C&amp;DA=23H&amp;rtmaxcoll=1TH">박은혜</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%A1%B0%EA%B5%AD&amp;DA=23H&amp;rtmaxcoll=1TH">조국</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%B8%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">호란</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%8B%9C%ED%98%84&amp;DA=23H&amp;rtmaxcoll=1TH">시현</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EB%81%BC%EC%A4%8D%EC%87%BC&amp;DA=23H&amp;rtmaxcoll=1TH">한끼줍쇼</a> </strong> </li>
# </ol>
# </div> </li>
# <li class="on"><a class="link_tab link_tab2" href="#search_rank_news">뉴스</a>
# <div class="cont_aside" id="search_rank_news">
# <strong class="screen_out">뉴스</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%A4%91%EA%B5%AD+%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">중국 흑사병</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EA%B5%AD%EB%B0%A9%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">국방과학연구소</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=2020%EC%88%98%EB%8A%A5&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">2020수능</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%A3%BC%EC%8B%9D+%EA%B0%9C%EC%9E%A5%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">주식 개장시간</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B2%A0&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">아베</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%EB%84%A4%EC%B9%98%EC%95%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">베네치아</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%9D%80%ED%96%89+%EC%98%81%EC%97%85%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">은행 영업시간</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EC%88%98&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">김경수</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%B6%9C%EA%B7%BC%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">수능 출근시간</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%84%9C%EB%B6%80%EA%B0%84%EC%84%A0%EB%8F%84%EB%A1%9C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">서부간선도로</a> </strong> </li>
# </ol>
# </div> </li>
# <li><a class="link_tab link_tab3" href="#search_rank_entertain">연예</a>
# <div class="cont_aside" id="search_rank_entertain">
# <strong class="screen_out">연예</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9E%A5%EC%A0%95%EC%9C%A4+%EC%9E%91%EA%B0%80&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">장정윤 작가</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B9%84%EC%98%A4%EB%B8%8C%EC%9C%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">비오브유</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EC%A0%95%EC%A4%80%EC%98%81&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">정준영</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EB%AF%BC%ED%99%98+%EC%9C%A8%ED%9D%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최민환 율희</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%97%B0%EC%88%98&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박연수</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EC%A2%85%ED%9B%88&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최종훈</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%A5%98%EC%A7%84&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">류진</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%BD%EB%A6%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">경리</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%98%81%EC%84%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박영선</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%9A%B0%EB%A6%AC+%EB%8B%A4%EC%8B%9C+%EC%82%AC%EB%9E%91%ED%95%A0+%EC%88%98+%EC%9E%88%EC%9D%84%EA%B9%8C&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">우리 다시 사랑할 수 있을까</a> </strong> </li>
# </ol>
# </div> </li>
# <li><a class="link_tab link_tab4" href="#search_rank_sports">스포츠</a>
# <div class="cont_aside" id="search_rank_sports">
# <strong class="screen_out">스포츠</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EB%94%94%EA%B7%B8%EB%A1%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">디그롬</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%ED%8A%B8%EB%82%A8+%EC%B6%95%EA%B5%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">베트남 축구</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%B0%EA%B5%AC%EC%84%A0%EC%88%98+%EC%9D%B4%EB%8B%A4%ED%98%84&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">배구선수 이다현</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%84%EB%8C%80%EA%B1%B4%EC%84%A4+%EB%A7%88%EC%95%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">현대건설 마야</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EA%B5%AD+%EB%A0%88%EB%B0%94%EB%85%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">한국 레바논</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%82%AC%EC%9D%B4%EC%98%81%EC%83%81+%EB%B0%9C%ED%91%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">사이영상 발표</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%91%90%EB%B0%94%EC%9D%B4%EC%BB%B5&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">두바이컵</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%8C%EB%A6%BF+%EC%BD%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">게릿 콜</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B8%8C%EB%9D%BC%ED%95%A8&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">아브라함</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%8C%EB%9E%9C%EB%8D%94&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">벌랜더</a> </strong> </li>
# </ol>
# </div> </li>
# </ul>
# </div>
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideBottomAd" data-ad-height="250" data-ad-type="D" data-ad-unit="0QH44" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# </div>
# </div>
# <div class="hcg_media_pc_cEtc" id="cEtc">
# <div class="realtime_view">
# <div class="inner_realtime">
# <div class="realtime_news hc_news_pc_cEtc_realtime_news_201904">
# <h3 class="txt_newsview">이 시각 추천뉴스</h3>
# <ul class="list_realtime"></ul>
# </div>
# <div class="realtime_aside" id="realtime_aside">
# <div class="aside_g aside_issue hc_news_pc_cEtc_realtimeIssue">
# <h3 class="txt_newsview">실시간 주요이슈</h3>
# <span class="info_aside">2019.11.14. 10:21 기준</span>
# <div class="cont_aside">
# <ul class="list_issue">
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1636831"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/14/Edaily/20191114101621310dwka.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1636831">2020 대학수학능력시험</a> </strong>
# </div> </li>
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1655045"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/10/NEWS1/20191110060012287qmyk.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1655045">유승준 판결 논란</a> </strong>
# </div> </li>
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1707294"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/14/NEWS1/20191114101926748gsry.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1707294">지소미아 종료</a> </strong>
# </div> </li>
# </ul>
# </div>
# </div>
# <div class="shopad_news aside_g aside_shopping hc_news_pc_cEtc_shopping" id="daum-sfocus-root"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- // kakaoContent -->
# <hr class="hide"/>
# <div class="hcg_media_pc_translation_status">
# <!-- 번역중 -->
# <div class="translate_layer" id="translatingLayer">
# <!-- 레이어 열리면 display:block; 스타일 추가 -->
# <div class="inner_translate_layer">
# <div class="layer_body">
# <strong class="tit_translate"> 번역중 <span class="eng_tit">Now in translation</span> </strong>
# </div>
# </div>
# </div>
# <!-- 번역 오류 -->
# <div class="translate_layer" id="translateErrorLayer">
# <!-- 레이어 열리면 display:block; 스타일 추가 -->
# <div class="inner_translate_layer inner_error_layer">
# <div class="layer_body">
# <span class="ico_newsview ico_error"></span>
# <strong class="tit_translate"> 잠시 후 다시 시도해 주세요 <span class="eng_tit">Please try again in a moment</span> </strong>
# </div>
# </div>
# </div>
# </div>
# <!-- 번역상태 레이어 -->
# <div class="footer_comm hcg_media_pc_kakaoFoot" id="kakaoFoot" role="contentinfo">
# <div class="inner_foot">
# <div class="direct_link">
# <h2 class="tit_direct">바로가기</h2>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/">뉴스홈</a>
# <a class="link_txt" href="http://media.daum.net/society/">사회</a>
# <a class="link_txt" href="http://media.daum.net/politics/">정치</a>
# <a class="link_txt" href="http://media.daum.net/economic/">경제</a>
# <a class="link_txt" href="http://media.daum.net/foreign/">국제</a>
# <a class="link_txt" href="http://media.daum.net/culture/">문화</a>
# <a class="link_txt" href="http://media.daum.net/digital/">IT</a>
# <a class="link_txt" href="http://media.daum.net/photo/">포토</a>
# <a class="link_txt" href="http://media.daum.net/tv/">TV</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/issue/">이슈</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/cp/">언론사별 뉴스</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/newsbox/">배열이력</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" href="http://media.daum.net/breakingnews/">전체뉴스</a>
# <a class="link_txt" href="http://media.daum.net/ranking/popular/">랭킹</a>
# <a class="link_txt" href="http://media.daum.net/series/">연재</a>
# <a class="link_txt" href="http://media.daum.net/1boon/">1boon</a>
# </div>
# <button class="btn_fold" type="button"><span class="ico_news">바로가기 링크 더보기/접기</span></button>
# </div>
# <h2 class="screen_out">서비스 이용정보</h2>
# <div class="footer_link">
# <a class="link_info" href="//media.daum.net/info/intro.html">다음뉴스 소개</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//media.daum.net/info/notice/">공지사항</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//news.daum.net/info/bbsrule">게시물 운영원칙</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="http://policy.daum.net/info/info">서비스 약관/정책</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//with.kakao.com/media">뉴스제휴</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//business.kakao.com/">비즈니스</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//cs.daum.net/redbell/top.html">권리침해신고</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//cs.daum.net/faq/63.html">다음뉴스 고객센터</a>
# </div>
# <div class="footer_link">
# <a class="link_info" href="//news.daum.net/info/newscenter24">24시간 뉴스센터</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//news.daum.net/info/edit">서비스원칙</a>
# <span class="txt_dot"> ・ </span>
# <a class="link_info" href="//media.daum.net/info/correct/">바로잡습니다</a>
# <span class="txt_dot"> ・ </span>
# <span class="link_info">기사배열책임자 : 손정아</span>
# <span class="txt_dot"> ・ </span>
# <span class="link_info">청소년보호책임자 : 권대열</span>
# </div>
# <div class="info_copyright">
# <strong class="info_warn">위 내용에 대한 저작권 및 법적 책임은 자료제공사 또는 <br/>글쓴이에 있으며, Kakao의 입장과 다를 수 있습니다.</strong>
# <small class="txt_copyright">Copyright © <strong class="txt_kakao"><a class="link_kakao" href="http://www.kakaocorp.com/">Kakao Corp.</a></strong> All rights reserved.</small>
# </div>
# </div>
# </div>
# <div id="wrapMinidaum"></div>
# </div>

# %%
type(div_1)
# Out:
# bs4.element.Tag

# %%
div_2 = div_1.find_all('div', role='main')[0]
div_2
# Out:
# <div class="cont_view" id="kakaoContent" role="main">
# <h2 class="screen_out" id="kakaoBody">경제</h2>
# <div class="hcg_media_pc_cSub" id="cSub">
# <div class="head_view">
# <em class="info_cp"> <a class="link_cp #body #cplogo" href="http://www.hankookilbo.com" target="_blank"> <img alt="한국일보" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_hankooki.gif"/> </a> </em>
# <h3 class="tit_view" data-translation="">잔금대출에도 DTI 규제 적용 검토</h3>
# <span class="info_view"> <span class="txt_info">김동욱</span> <span class="txt_info">입력 2017.06.15. 20:34</span> <span class="txt_info">수정 2017.06.15. 21:31</span> <button class="emph_g2 link_cmt" id="alexCounter">댓글 <span class="alex-count-area">0</span>개</button> </span>
# <div class="util_view">
# <!-- 2018-08-31-v2 버튼 순서 변경 / 자동요약 - TTS - 번역 - 공유 - 글씨크기 - 인쇄 순 -->
# <!-- 자동요약 -->
# <div class="btn_util util_summary">
# <!-- btn_summary 클릭시, layer_open 클래스 추가 -->
# <button aria-expanded="false" class="btn_summary #btn_summary" type="button"><span class="ico_newsview">자동요약</span></button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_summary">
# <p>금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다.</p>
# <p>지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다.</p>
# <p>앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다.</p>
# <span class="info_summary"><span class="ico_newsview"></span>기사 제목과 주요 문장을 기반으로 자동요약한 결과입니다. 전체 맥락을 이해하기 위해서는 본문 보기를 권장합니다.</span>
# </div>
# </div>
# </div>
# <!-- TTS -->
# <div class="btn_util tts_btn hc_news_pc_cSub_tts">
# <button aria-expanded="false" class="btn_set btn_tts" type="button"> <span class="ico_newsview ico_speak">음성 기사 듣기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_tts">
# <strong class="screen_out">음성 기사 옵션 조절 레이어</strong>
# <ul class="list_set list_tts">
# <li> <input class="screen_out" id="ttsGenderMale" name="ttsGender" type="radio" value="Male"/> <label class="lab_set" for="ttsGenderMale"><span class="ico_newsview"></span>남성</label> </li>
# <li> <input class="screen_out" id="ttsGenderFemale" name="ttsGender" type="radio" value="Female"/> <label class="lab_set" for="ttsGenderFemale"><span class="ico_newsview"></span>여성</label> </li>
# </ul>
# <ul class="list_set list_tts list_ttsspeed">
# <li> <input class="screen_out" id="ttsSpeedSlow" name="ttsSpeed" type="radio" value="slow"/> <label class="lab_set" for="ttsSpeedSlow"><span class="ico_newsview"></span>느림</label> </li>
# <li> <input class="screen_out" id="ttsSpeedNormal" name="ttsSpeed" type="radio" value="normal"/> <label class="lab_set" for="ttsSpeedNormal"><span class="ico_newsview"></span>보통</label> </li>
# <li> <input class="screen_out" id="ttsSpeedFast" name="ttsSpeed" type="radio" value="fast"/> <label class="lab_set" for="ttsSpeedFast"><span class="ico_newsview"></span>빠름</label> </li>
# </ul>
# </div>
# </div>
# <audio id="ttsPlayer" preload="none" style="display:none"></audio>
# </div>
# <!-- 번역 -->
# <div class="btn_util translate_btn hc_news_pc_cSub_translateButtons">
# <!-- 활성화시 aria-expanded="true" / 비활성화시 aria-expanded="false" 추가 -->
# <button aria-expanded="false" class="btn_set btn_translate #util #translate #set" type="button"><span class="ico_newsview">번역 설정</span></button>
# <div class="wrap_translatelayer">
# <div class="layer_util layer_translate">
# <strong class="tit_translate">번역<span class="ico_newsview">beta</span>
# <!-- 2018-09-04 추가--></strong>
# <p class="desc_translate txt_newsview">Translated by <a class="link_kakaoi #util #translate #kakaoi_link" href="https://kakao.ai/" target="_blank">kakao i</a></p>
# <strong class="screen_out">번역할 언어 선택</strong>
# <ul class="list_lang">
# <li> <button class="btn_lang btn_en #util #translate #lang_en" name="en"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">English</strong> </button> </li>
# <li> <button class="btn_lang btn_ch #util #translate #lang_cn" name="cn" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">简体中文</strong> </button> </li>
# <li> <button class="btn_lang btn_jp #util #translate #lang_jp" name="jp" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">日本語</strong> </button> </li>
# <li> <button class="btn_lang btn_ind #util #translate #lang_id" name="id" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">Bahasa Indonesia</strong> </button> </li>
# <li> <button class="btn_lang btn_viet #util #translate #lang_vi" name="vi" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">tiếng Việt</strong> </button> </li>
# <li> <button class="btn_lang btn_ko #util #translate #lang_kr" name="kr" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">한국어</strong> </button> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="hc_translator" style="display:none;"></div>
# <!-- 공유 -->
# <div class="btn_util share_btn hc_news_pc_cSub_shareButtons">
# <button aria-expanded="false" class="btn_set btn_share" id="rSocialShareButton"> <span class="ico_newsview">공유</span> </button>
# <div id="rSocialShareLayerContainer"></div>
# </div>
# <!-- 글씨크기 -->
# <div class="font_btn btn_util hc_news_pc_cSub_fontSizeController">
# <button aria-expanded="false" class="btn_set btn_font" type="button"> <span class="ico_newsview ico_font">글씨크기 조절하기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_font">
# <strong class="screen_out">글자 크기 조절 레이어</strong>
# <ul class="list_set list_font">
# <li> <input class="screen_out" id="inpFont17" name="inpFont" type="radio" value="17"/> <label class="lab_set lab_size0" for="inpFont17"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont18" name="inpFont" type="radio" value="18"/> <label class="lab_set lab_size1" for="inpFont18"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont19" name="inpFont" type="radio" value="19"/> <label class="lab_set lab_size2" for="inpFont19"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">보통 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont20" name="inpFont" type="radio" value="20"/> <label class="lab_set lab_size3" for="inpFont20"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">큰 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont21" name="inpFont" type="radio" value="21"/> <label class="lab_set lab_size4" for="inpFont21"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 큰 폰트</span> </label> </li>
# </ul>
# </div>
# </div>
# <!-- // font 팝업 레이어 -->
# </div>
# <!-- 인쇄 -->
# <div class="btn_util hc_news_pc_cSub_printButton">
# <button class="btn_print" type="button"> <span class="ico_newsview">인쇄하기 새창열림</span> </button>
# </div>
# </div>
# </div>
# </div>
# <div id="cMain">
# <div class="hcg_media_pc_mArticle" id="mArticle">
# <!-- 바꿔치기 -->
# <!-- 언론중재법 -->
# <!-- 번역 안내 -->
# <div class="status_view" id="translateNotice" style="display:none;">
# <span class="notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</span>
# <span class="notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</span>
# <span class="notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</span>
# <span class="notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</span>
# <span class="notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</span>
# </div>
# <div class="news_view" style="font-size:17px">
# <div class="article_view" data-translation-body="" id="harmonyContainer">
# <section dmcf-sid="ndxAvoEFLc">
# <p dmcf-pid="nzrJ5KB3Cc" dmcf-ptype="general">내주 부동산 종합대책 발표</p>
# <p dmcf-pid="ncFbmYUgSc" dmcf-ptype="general">집값 상승 노린 투기 분양 차단</p>
# <p dmcf-pid="naDeB8j0HH" dmcf-ptype="general">LTVㆍDTI 규제 다시 강화할 듯</p>
# <p dmcf-pid="ngfl6lJwwk" dmcf-ptype="general">저소득 실수요자 피해 우려도</p>
# <figure class="figure_frm origin_fig" dmcf-pid="nYQ8LWIMpD" dmcf-ptype="figure">
# <p class="link_figure"><img class="thumb_g_article" dmcf-mid="nkjJSoPdyb" dmcf-mtype="image" height="236" src="https://t1.daumcdn.net/news/201706/15/hankooki/20170615044256378kzbd.jpg" width="330"/></p>
# </figure>
# <p dmcf-pid="n8guDAko3Z" dmcf-ptype="general">금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다. 지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다. 앞으로 잔금대출에 DTI가 적용되면 소득 없는 사람이 입주 뒤 집값 상승을 노리고 분양시장에 뛰어드는 게 사실상 불가능해진다. </p>
# <p dmcf-pid="nYPaCCRO1q" dmcf-ptype="general">금융당국 고위관계자는 15일 “잔금대출에도 DTI를 적용하는 방안을 검토 중”이라며 “다만 아직 최종 결론이 난 건 아니다”고 말했다. 정부는 내주 이 같은 내용을 포함한 부동산 종합 대책을 발표할 예정이다. </p>
# <p dmcf-pid="naZLBbSgoZ" dmcf-ptype="general">정부가 잔금대출 DTI 적용 카드를 꺼내는 건, 집단대출을 잡지 않고선 과열된 주택시장을 진정시키기 어렵다는 판단에서다. 실제 정부는 지난해 잔금대출도 대출 초기부터 원리금을 함께 갚도록 하는 여신심사 가이드라인을 도입했지만 이렇다 할 효과를 거두지 못했다. 오히려 정부 대책에도 불구, 집단대출 증가액은 매달 늘어나는 추세인데 지난달엔 2조원으로 올 들어 최고치를 기록했다. </p>
# <p dmcf-pid="nhAfneUtnA" dmcf-ptype="general">아파트 분양 집단대출은 중도금과 잔금대출로 구분된다. 계약금 10%를 내면 입주 전까지 집값의 60%를 중도금 대출로 받을 수 있다. 중도금 대출은 건설사 보증으로 이뤄져 소득심사를 안 거친다. 잔금대출은 건설사가 아닌 집을 담보로 이뤄지는 대출이다. LTV 규제만 적용돼 소득이 없어도 집값의 70%까지 대출이 가능하다. 때문에 지금은 잔금대출로 집값의 70%를 대출받아 기존 중도금 대출을 갚고 나머지 20%만 본인 돈으로 충당하면 집을 살 수 있다.</p>
# <p dmcf-pid="nCcfu6DK1b" dmcf-ptype="general">앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다. 입주 뒤 집값 상승을 노리는 투기수요를 확실히 걸러낼 초강력 대책이 될 수 있다. 하지만 부작용도 우려된다. 소득이 낮은 사회초년생 등은 청약통장을 갖고도 분양시장에 진입하는 게 어려워지기 때문이다. </p>
# <p dmcf-pid="nzh7QZekII" dmcf-ptype="general">이에 따라 잔금대출에 DTI를 적용하는 것 역시 지역 등에 따라 선별적으로 이뤄질 가능성이 높다. 현재 당국은 신규 분양 물량부터 규제를 적용할지 아니면 기존 분양 물량까지 규제 범위를 확대할지를 놓고 시뮬레이션을 하고 있다. </p>
# <p dmcf-pid="nihh22vlmu" dmcf-ptype="general">아울러 당국은 지난 2년간 완화됐던 LTV와 DTI를 다시 강화할 것으로 보인다. 현재 LTV(은행 기준)는 기존 50~60%에서 70%, DTI는 50~60%에서 60%로 완화돼 있는 상태다. 당국은 일괄적인 조이기보다 지역ㆍ집값 수준별로 기준을 다르게 적용하는 방식을 모색할 것으로 보인다.</p>
# <p dmcf-pid="naJ5HNfuMQ" dmcf-ptype="general">김동욱 기자 kdw1280@hankookilbo.com</p>
# </section>
# </div>
# </div>
# <div class="foot_view">
# <div class="wrap_brunch hc_news_pc_mArticle_brunchAuthor" style="display:none;">
# </div>
# <div class="relate_tag hc_news_pc_mArticle_relatedTags">
# <strong class="screen_out">관련 태그</strong>
# </div>
# <div class="relate_series hc_news_pc_mArticle_series" style="display:none;">
# <strong class="tit_series"><em class="tag_series">연재</em><span class="title_series"></span></strong>
# <!-- MCCP-856 연재 영역 수정 -->
# <ul class="list_series">
# </ul>
# <!-- //MCCP-856 연재 영역 수정 -->
# <a class="link_more #body #series_more" href="#none">더보기</a>
# </div>
# <div class="copyright_view">
# <span class="txt_copyright">ⓒ한국일보 www.hankookilbo.com (무단복제 및 전재, 재배포를 금지합니다)</span>
# <div class="btn_empathy hc_news_pc_mArticle_empathyButton">
# <link href="//m1.daumcdn.net/svc/original/U03/cssjs/uoclike/common/uoclike.min-20150408-2.css" rel="stylesheet" type="text/css"/>
# <div class="btn_empathy_pc" id="likeButton">
# </div>
# </div>
# </div>
# <!-- 언론사 관련기사(주요뉴스) -->
# <div class="cp_view">
# <strong class="tit_cp">한국일보 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
# <ul class="list_relate">
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045" target="_blank">실제와 너무 다른 '서울로 7017' 홍보 이미지</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22" target="_blank">[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851" target="_blank">공승연 "여진구 오빠 같아..잘생기면 오빠"</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c" target="_blank">지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">“라떼는 말이야…” 달라진 입시 풍경</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">2020학년도 수능 보는 연예인들</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">수능 출제위원장 “국어, 초고난도 문항 없다”</a></li>
# </ul>
# </div>
# <div id="alex-scroll-area"></div>
# <div class="recomm_ad hc_news_pc_mArticle_recommend_ad" id="daum-ad-root">
# </div>
# <div class="cmt_news cmt_view">
# <div class="alex-area" data-base-url="//comment.daum.net" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-initial-limit="3" data-is-mobile="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-max-length="300" data-page-limit="10" data-post-id="@20170615203441266" data-show-mask-alert="true" data-sort="R" data-use-attachment="false" data-use-emoticon="true" data-use-live-comment-mode="notify" data-use-my="true" data-use-official="true" data-use-reply="true" data-use-social-share="true" id="alex-area">
# </div>
# </div>
# </div>
# </div>
# <div class="hcg_media_pc_mAside" id="mAside">
# <div class="hc_news_pc_cSub_bnr_130" style="position:relative">
# <div class="bnr_130">
# <ins class="daum_ddn_area" data-ad-height="250" data-ad-type="P" data-ad-unit="05d90" data-ad-width="130" id="RIGHT_SPACE_BANNER" name="RIGHT_SPACE_BANNER"></ins>
# </div>
# </div>
# <!-- //130 배너 -->
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideTopAd" data-ad-height="250" data-ad-type="D" data-ad-unit="05d24" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# <div class="hc_news_pc_mAside_popular_news"></div>
# <div class="aside_g aside_phototv hc_news_pc_mAside_phototv">
# <h3 class="txt_newsview">포토&amp;TV</h3>
# <div class="cont_aside">
# <ul class="list_phototv">
# <li> <a class="link_cont" href="https://gallery.v.daum.net/p/viewer/896465/20191114102117837"> <span class="wrap_thumb"> <img alt="[머니S포토] 2020 수능, 기도하는 수험생" class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/moneyweek/20191114102117870nzub.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_photo">포토</span> </span> </span> <strong class="tit_thumb">[머니S포토] 2020 수능, 기도하는 수험생</strong> </a> </li>
# <li> <a class="link_cont" href="https://v.daum.net/v/20191114101823717?s=tv_news"> <span class="wrap_thumb"> <img alt='[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"' class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/sbscnbc/20191114101823962mwag.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_vod">영상</span> </span> </span> <strong class="tit_thumb">[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"</strong> </a> </li>
# </ul>
# </div>
# </div>
# <div class="aside_g aside_search hc_news_pc_mAside_realtimeSearch">
# <h3 class="txt_newsview">실시간 이슈</h3>
# <ul class="tab_aside tab_media" id="search_rank_tab_heads">
# <li><a class="link_tab link_tab1" href="#search_rank_total">전체</a>
# <div class="cont_aside" id="search_rank_total">
# <strong class="screen_out">전체</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9C%A0%EB%A6%AC+%EC%98%A4%EB%B9%A0&amp;DA=23H&amp;rtmaxcoll=1TH">유리 오빠</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%8B%9C%EA%B0%84%ED%91%9C&amp;DA=23H&amp;rtmaxcoll=1TH">수능 시간표</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23H&amp;rtmaxcoll=1TH">흑사병</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">김경란</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EA%B5%AD%EC%96%B4&amp;DA=23H&amp;rtmaxcoll=1TH">수능 국어</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%9D%80%ED%98%9C&amp;DA=23H&amp;rtmaxcoll=1TH">박은혜</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%A1%B0%EA%B5%AD&amp;DA=23H&amp;rtmaxcoll=1TH">조국</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%B8%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">호란</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%8B%9C%ED%98%84&amp;DA=23H&amp;rtmaxcoll=1TH">시현</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EB%81%BC%EC%A4%8D%EC%87%BC&amp;DA=23H&amp;rtmaxcoll=1TH">한끼줍쇼</a> </strong> </li>
# </ol>
# </div> </li>
# <li class="on"><a class="link_tab link_tab2" href="#search_rank_news">뉴스</a>
# <div class="cont_aside" id="search_rank_news">
# <strong class="screen_out">뉴스</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%A4%91%EA%B5%AD+%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">중국 흑사병</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EA%B5%AD%EB%B0%A9%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">국방과학연구소</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=2020%EC%88%98%EB%8A%A5&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">2020수능</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%A3%BC%EC%8B%9D+%EA%B0%9C%EC%9E%A5%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">주식 개장시간</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B2%A0&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">아베</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%EB%84%A4%EC%B9%98%EC%95%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">베네치아</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%9D%80%ED%96%89+%EC%98%81%EC%97%85%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">은행 영업시간</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EC%88%98&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">김경수</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%B6%9C%EA%B7%BC%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">수능 출근시간</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%84%9C%EB%B6%80%EA%B0%84%EC%84%A0%EB%8F%84%EB%A1%9C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">서부간선도로</a> </strong> </li>
# </ol>
# </div> </li>
# <li><a class="link_tab link_tab3" href="#search_rank_entertain">연예</a>
# <div class="cont_aside" id="search_rank_entertain">
# <strong class="screen_out">연예</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9E%A5%EC%A0%95%EC%9C%A4+%EC%9E%91%EA%B0%80&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">장정윤 작가</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B9%84%EC%98%A4%EB%B8%8C%EC%9C%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">비오브유</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EC%A0%95%EC%A4%80%EC%98%81&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">정준영</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EB%AF%BC%ED%99%98+%EC%9C%A8%ED%9D%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최민환 율희</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%97%B0%EC%88%98&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박연수</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EC%A2%85%ED%9B%88&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최종훈</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%A5%98%EC%A7%84&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">류진</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%BD%EB%A6%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">경리</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%98%81%EC%84%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박영선</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%9A%B0%EB%A6%AC+%EB%8B%A4%EC%8B%9C+%EC%82%AC%EB%9E%91%ED%95%A0+%EC%88%98+%EC%9E%88%EC%9D%84%EA%B9%8C&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">우리 다시 사랑할 수 있을까</a> </strong> </li>
# </ol>
# </div> </li>
# <li><a class="link_tab link_tab4" href="#search_rank_sports">스포츠</a>
# <div class="cont_aside" id="search_rank_sports">
# <strong class="screen_out">스포츠</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EB%94%94%EA%B7%B8%EB%A1%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">디그롬</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%ED%8A%B8%EB%82%A8+%EC%B6%95%EA%B5%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">베트남 축구</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%B0%EA%B5%AC%EC%84%A0%EC%88%98+%EC%9D%B4%EB%8B%A4%ED%98%84&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">배구선수 이다현</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%84%EB%8C%80%EA%B1%B4%EC%84%A4+%EB%A7%88%EC%95%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">현대건설 마야</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EA%B5%AD+%EB%A0%88%EB%B0%94%EB%85%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">한국 레바논</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%82%AC%EC%9D%B4%EC%98%81%EC%83%81+%EB%B0%9C%ED%91%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">사이영상 발표</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%91%90%EB%B0%94%EC%9D%B4%EC%BB%B5&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">두바이컵</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%8C%EB%A6%BF+%EC%BD%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">게릿 콜</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B8%8C%EB%9D%BC%ED%95%A8&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">아브라함</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%8C%EB%9E%9C%EB%8D%94&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">벌랜더</a> </strong> </li>
# </ol>
# </div> </li>
# </ul>
# </div>
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideBottomAd" data-ad-height="250" data-ad-type="D" data-ad-unit="0QH44" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# </div>
# </div>
# <div class="hcg_media_pc_cEtc" id="cEtc">
# <div class="realtime_view">
# <div class="inner_realtime">
# <div class="realtime_news hc_news_pc_cEtc_realtime_news_201904">
# <h3 class="txt_newsview">이 시각 추천뉴스</h3>
# <ul class="list_realtime"></ul>
# </div>
# <div class="realtime_aside" id="realtime_aside">
# <div class="aside_g aside_issue hc_news_pc_cEtc_realtimeIssue">
# <h3 class="txt_newsview">실시간 주요이슈</h3>
# <span class="info_aside">2019.11.14. 10:21 기준</span>
# <div class="cont_aside">
# <ul class="list_issue">
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1636831"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/14/Edaily/20191114101621310dwka.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1636831">2020 대학수학능력시험</a> </strong>
# </div> </li>
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1655045"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/10/NEWS1/20191110060012287qmyk.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1655045">유승준 판결 논란</a> </strong>
# </div> </li>
# <li> <a class="link_thumb" href="http://media.daum.net/issue/1707294"> <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/201911/14/NEWS1/20191114101926748gsry.jpg" width="84"/> </a>
# <div class="cont_thumb">
# <strong class="tit_thumb"> <a class="link_txt" href="http://media.daum.net/issue/1707294">지소미아 종료</a> </strong>
# </div> </li>
# </ul>
# </div>
# </div>
# <div class="shopad_news aside_g aside_shopping hc_news_pc_cEtc_shopping" id="daum-sfocus-root"></div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
div_3 = div_2.find_all('div', id="cMain")[0]
div_3
# Out:
# <div id="cMain">
# <div class="hcg_media_pc_mArticle" id="mArticle">
# <!-- 바꿔치기 -->
# <!-- 언론중재법 -->
# <!-- 번역 안내 -->
# <div class="status_view" id="translateNotice" style="display:none;">
# <span class="notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</span>
# <span class="notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</span>
# <span class="notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</span>
# <span class="notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</span>
# <span class="notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</span>
# </div>
# <div class="news_view" style="font-size:17px">
# <div class="article_view" data-translation-body="" id="harmonyContainer">
# <section dmcf-sid="ndxAvoEFLc">
# <p dmcf-pid="nzrJ5KB3Cc" dmcf-ptype="general">내주 부동산 종합대책 발표</p>
# <p dmcf-pid="ncFbmYUgSc" dmcf-ptype="general">집값 상승 노린 투기 분양 차단</p>
# <p dmcf-pid="naDeB8j0HH" dmcf-ptype="general">LTVㆍDTI 규제 다시 강화할 듯</p>
# <p dmcf-pid="ngfl6lJwwk" dmcf-ptype="general">저소득 실수요자 피해 우려도</p>
# <figure class="figure_frm origin_fig" dmcf-pid="nYQ8LWIMpD" dmcf-ptype="figure">
# <p class="link_figure"><img class="thumb_g_article" dmcf-mid="nkjJSoPdyb" dmcf-mtype="image" height="236" src="https://t1.daumcdn.net/news/201706/15/hankooki/20170615044256378kzbd.jpg" width="330"/></p>
# </figure>
# <p dmcf-pid="n8guDAko3Z" dmcf-ptype="general">금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다. 지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다. 앞으로 잔금대출에 DTI가 적용되면 소득 없는 사람이 입주 뒤 집값 상승을 노리고 분양시장에 뛰어드는 게 사실상 불가능해진다. </p>
# <p dmcf-pid="nYPaCCRO1q" dmcf-ptype="general">금융당국 고위관계자는 15일 “잔금대출에도 DTI를 적용하는 방안을 검토 중”이라며 “다만 아직 최종 결론이 난 건 아니다”고 말했다. 정부는 내주 이 같은 내용을 포함한 부동산 종합 대책을 발표할 예정이다. </p>
# <p dmcf-pid="naZLBbSgoZ" dmcf-ptype="general">정부가 잔금대출 DTI 적용 카드를 꺼내는 건, 집단대출을 잡지 않고선 과열된 주택시장을 진정시키기 어렵다는 판단에서다. 실제 정부는 지난해 잔금대출도 대출 초기부터 원리금을 함께 갚도록 하는 여신심사 가이드라인을 도입했지만 이렇다 할 효과를 거두지 못했다. 오히려 정부 대책에도 불구, 집단대출 증가액은 매달 늘어나는 추세인데 지난달엔 2조원으로 올 들어 최고치를 기록했다. </p>
# <p dmcf-pid="nhAfneUtnA" dmcf-ptype="general">아파트 분양 집단대출은 중도금과 잔금대출로 구분된다. 계약금 10%를 내면 입주 전까지 집값의 60%를 중도금 대출로 받을 수 있다. 중도금 대출은 건설사 보증으로 이뤄져 소득심사를 안 거친다. 잔금대출은 건설사가 아닌 집을 담보로 이뤄지는 대출이다. LTV 규제만 적용돼 소득이 없어도 집값의 70%까지 대출이 가능하다. 때문에 지금은 잔금대출로 집값의 70%를 대출받아 기존 중도금 대출을 갚고 나머지 20%만 본인 돈으로 충당하면 집을 살 수 있다.</p>
# <p dmcf-pid="nCcfu6DK1b" dmcf-ptype="general">앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다. 입주 뒤 집값 상승을 노리는 투기수요를 확실히 걸러낼 초강력 대책이 될 수 있다. 하지만 부작용도 우려된다. 소득이 낮은 사회초년생 등은 청약통장을 갖고도 분양시장에 진입하는 게 어려워지기 때문이다. </p>
# <p dmcf-pid="nzh7QZekII" dmcf-ptype="general">이에 따라 잔금대출에 DTI를 적용하는 것 역시 지역 등에 따라 선별적으로 이뤄질 가능성이 높다. 현재 당국은 신규 분양 물량부터 규제를 적용할지 아니면 기존 분양 물량까지 규제 범위를 확대할지를 놓고 시뮬레이션을 하고 있다. </p>
# <p dmcf-pid="nihh22vlmu" dmcf-ptype="general">아울러 당국은 지난 2년간 완화됐던 LTV와 DTI를 다시 강화할 것으로 보인다. 현재 LTV(은행 기준)는 기존 50~60%에서 70%, DTI는 50~60%에서 60%로 완화돼 있는 상태다. 당국은 일괄적인 조이기보다 지역ㆍ집값 수준별로 기준을 다르게 적용하는 방식을 모색할 것으로 보인다.</p>
# <p dmcf-pid="naJ5HNfuMQ" dmcf-ptype="general">김동욱 기자 kdw1280@hankookilbo.com</p>
# </section>
# </div>
# </div>
# <div class="foot_view">
# <div class="wrap_brunch hc_news_pc_mArticle_brunchAuthor" style="display:none;">
# </div>
# <div class="relate_tag hc_news_pc_mArticle_relatedTags">
# <strong class="screen_out">관련 태그</strong>
# </div>
# <div class="relate_series hc_news_pc_mArticle_series" style="display:none;">
# <strong class="tit_series"><em class="tag_series">연재</em><span class="title_series"></span></strong>
# <!-- MCCP-856 연재 영역 수정 -->
# <ul class="list_series">
# </ul>
# <!-- //MCCP-856 연재 영역 수정 -->
# <a class="link_more #body #series_more" href="#none">더보기</a>
# </div>
# <div class="copyright_view">
# <span class="txt_copyright">ⓒ한국일보 www.hankookilbo.com (무단복제 및 전재, 재배포를 금지합니다)</span>
# <div class="btn_empathy hc_news_pc_mArticle_empathyButton">
# <link href="//m1.daumcdn.net/svc/original/U03/cssjs/uoclike/common/uoclike.min-20150408-2.css" rel="stylesheet" type="text/css"/>
# <div class="btn_empathy_pc" id="likeButton">
# </div>
# </div>
# </div>
# <!-- 언론사 관련기사(주요뉴스) -->
# <div class="cp_view">
# <strong class="tit_cp">한국일보 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
# <ul class="list_relate">
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045" target="_blank">실제와 너무 다른 '서울로 7017' 홍보 이미지</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22" target="_blank">[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851" target="_blank">공승연 "여진구 오빠 같아..잘생기면 오빠"</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c" target="_blank">지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">“라떼는 말이야…” 달라진 입시 풍경</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">2020학년도 수능 보는 연예인들</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">수능 출제위원장 “국어, 초고난도 문항 없다”</a></li>
# </ul>
# </div>
# <div id="alex-scroll-area"></div>
# <div class="recomm_ad hc_news_pc_mArticle_recommend_ad" id="daum-ad-root">
# </div>
# <div class="cmt_news cmt_view">
# <div class="alex-area" data-base-url="//comment.daum.net" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-initial-limit="3" data-is-mobile="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-max-length="300" data-page-limit="10" data-post-id="@20170615203441266" data-show-mask-alert="true" data-sort="R" data-use-attachment="false" data-use-emoticon="true" data-use-live-comment-mode="notify" data-use-my="true" data-use-official="true" data-use-reply="true" data-use-social-share="true" id="alex-area">
# </div>
# </div>
# </div>
# </div>
# <div class="hcg_media_pc_mAside" id="mAside">
# <div class="hc_news_pc_cSub_bnr_130" style="position:relative">
# <div class="bnr_130">
# <ins class="daum_ddn_area" data-ad-height="250" data-ad-type="P" data-ad-unit="05d90" data-ad-width="130" id="RIGHT_SPACE_BANNER" name="RIGHT_SPACE_BANNER"></ins>
# </div>
# </div>
# <!-- //130 배너 -->
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideTopAd" data-ad-height="250" data-ad-type="D" data-ad-unit="05d24" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# <div class="hc_news_pc_mAside_popular_news"></div>
# <div class="aside_g aside_phototv hc_news_pc_mAside_phototv">
# <h3 class="txt_newsview">포토&amp;TV</h3>
# <div class="cont_aside">
# <ul class="list_phototv">
# <li> <a class="link_cont" href="https://gallery.v.daum.net/p/viewer/896465/20191114102117837"> <span class="wrap_thumb"> <img alt="[머니S포토] 2020 수능, 기도하는 수험생" class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/moneyweek/20191114102117870nzub.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_photo">포토</span> </span> </span> <strong class="tit_thumb">[머니S포토] 2020 수능, 기도하는 수험생</strong> </a> </li>
# <li> <a class="link_cont" href="https://v.daum.net/v/20191114101823717?s=tv_news"> <span class="wrap_thumb"> <img alt='[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"' class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/201911/14/sbscnbc/20191114101823962mwag.jpg"/> <span class="ico_phototv"> <span class="ico_newsview ico_vod">영상</span> </span> </span> <strong class="tit_thumb">[오늘의 키워드] 흑사병이 돌아왔다..중국 "네이멍구 출신 2명 확진"</strong> </a> </li>
# </ul>
# </div>
# </div>
# <div class="aside_g aside_search hc_news_pc_mAside_realtimeSearch">
# <h3 class="txt_newsview">실시간 이슈</h3>
# <ul class="tab_aside tab_media" id="search_rank_tab_heads">
# <li><a class="link_tab link_tab1" href="#search_rank_total">전체</a>
# <div class="cont_aside" id="search_rank_total">
# <strong class="screen_out">전체</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9C%A0%EB%A6%AC+%EC%98%A4%EB%B9%A0&amp;DA=23H&amp;rtmaxcoll=1TH">유리 오빠</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%8B%9C%EA%B0%84%ED%91%9C&amp;DA=23H&amp;rtmaxcoll=1TH">수능 시간표</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23H&amp;rtmaxcoll=1TH">흑사병</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">김경란</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EA%B5%AD%EC%96%B4&amp;DA=23H&amp;rtmaxcoll=1TH">수능 국어</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%9D%80%ED%98%9C&amp;DA=23H&amp;rtmaxcoll=1TH">박은혜</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%A1%B0%EA%B5%AD&amp;DA=23H&amp;rtmaxcoll=1TH">조국</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%B8%EB%9E%80&amp;DA=23H&amp;rtmaxcoll=1TH">호란</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%8B%9C%ED%98%84&amp;DA=23H&amp;rtmaxcoll=1TH">시현</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EB%81%BC%EC%A4%8D%EC%87%BC&amp;DA=23H&amp;rtmaxcoll=1TH">한끼줍쇼</a> </strong> </li>
# </ol>
# </div> </li>
# <li class="on"><a class="link_tab link_tab2" href="#search_rank_news">뉴스</a>
# <div class="cont_aside" id="search_rank_news">
# <strong class="screen_out">뉴스</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%A4%91%EA%B5%AD+%ED%9D%91%EC%82%AC%EB%B3%91&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">중국 흑사병</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EA%B5%AD%EB%B0%A9%EA%B3%BC%ED%95%99%EC%97%B0%EA%B5%AC%EC%86%8C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">국방과학연구소</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=2020%EC%88%98%EB%8A%A5&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">2020수능</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%A3%BC%EC%8B%9D+%EA%B0%9C%EC%9E%A5%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">주식 개장시간</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B2%A0&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">아베</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%EB%84%A4%EC%B9%98%EC%95%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">베네치아</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EC%9D%80%ED%96%89+%EC%98%81%EC%97%85%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">은행 영업시간</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B9%80%EA%B2%BD%EC%88%98&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">김경수</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%88%98%EB%8A%A5+%EC%B6%9C%EA%B7%BC%EC%8B%9C%EA%B0%84&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">수능 출근시간</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%84%9C%EB%B6%80%EA%B0%84%EC%84%A0%EB%8F%84%EB%A1%9C&amp;DA=23I&amp;rtmaxcoll=EOA,1TH">서부간선도로</a> </strong> </li>
# </ol>
# </div> </li>
# <li><a class="link_tab link_tab3" href="#search_rank_entertain">연예</a>
# <div class="cont_aside" id="search_rank_entertain">
# <strong class="screen_out">연예</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EC%9E%A5%EC%A0%95%EC%9C%A4+%EC%9E%91%EA%B0%80&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">장정윤 작가</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B9%84%EC%98%A4%EB%B8%8C%EC%9C%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">비오브유</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EC%A0%95%EC%A4%80%EC%98%81&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">정준영</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EB%AF%BC%ED%99%98+%EC%9C%A8%ED%9D%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최민환 율희</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%97%B0%EC%88%98&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박연수</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%B5%9C%EC%A2%85%ED%9B%88&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">최종훈</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%A5%98%EC%A7%84&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">류진</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%BD%EB%A6%AC&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">경리</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EC%98%81%EC%84%A0&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">박영선</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EC%9A%B0%EB%A6%AC+%EB%8B%A4%EC%8B%9C+%EC%82%AC%EB%9E%91%ED%95%A0+%EC%88%98+%EC%9E%88%EC%9D%84%EA%B9%8C&amp;DA=23K&amp;rtmaxcoll=DRU,1TH">우리 다시 사랑할 수 있을까</a> </strong> </li>
# </ol>
# </div> </li>
# <li><a class="link_tab link_tab4" href="#search_rank_sports">스포츠</a>
# <div class="cont_aside" id="search_rank_sports">
# <strong class="screen_out">스포츠</strong>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num1">1위</em> <strong class="tit_g"> <a class="link_txt @1" href="https://search.daum.net/search?w=tot&amp;q=%EB%94%94%EA%B7%B8%EB%A1%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">디그롬</a> </strong> </li>
# <li> <em class="num_newsview num2">2위</em> <strong class="tit_g"> <a class="link_txt @2" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%A0%ED%8A%B8%EB%82%A8+%EC%B6%95%EA%B5%AC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">베트남 축구</a> </strong> </li>
# <li> <em class="num_newsview num3">3위</em> <strong class="tit_g"> <a class="link_txt @3" href="https://search.daum.net/search?w=tot&amp;q=%EB%B0%B0%EA%B5%AC%EC%84%A0%EC%88%98+%EC%9D%B4%EB%8B%A4%ED%98%84&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">배구선수 이다현</a> </strong> </li>
# <li> <em class="num_newsview num4">4위</em> <strong class="tit_g"> <a class="link_txt @4" href="https://search.daum.net/search?w=tot&amp;q=%ED%98%84%EB%8C%80%EA%B1%B4%EC%84%A4+%EB%A7%88%EC%95%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">현대건설 마야</a> </strong> </li>
# <li> <em class="num_newsview num5">5위</em> <strong class="tit_g"> <a class="link_txt @5" href="https://search.daum.net/search?w=tot&amp;q=%ED%95%9C%EA%B5%AD+%EB%A0%88%EB%B0%94%EB%85%BC&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">한국 레바논</a> </strong> </li>
# </ol>
# <ol class="list_ranking #right #search_keyword">
# <li> <em class="num_newsview num6">6위</em> <strong class="tit_g"> <a class="link_txt @6" href="https://search.daum.net/search?w=tot&amp;q=%EC%82%AC%EC%9D%B4%EC%98%81%EC%83%81+%EB%B0%9C%ED%91%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">사이영상 발표</a> </strong> </li>
# <li> <em class="num_newsview num7">7위</em> <strong class="tit_g"> <a class="link_txt @7" href="https://search.daum.net/search?w=tot&amp;q=%EB%91%90%EB%B0%94%EC%9D%B4%EC%BB%B5&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">두바이컵</a> </strong> </li>
# <li> <em class="num_newsview num8">8위</em> <strong class="tit_g"> <a class="link_txt @8" href="https://search.daum.net/search?w=tot&amp;q=%EA%B2%8C%EB%A6%BF+%EC%BD%9C&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">게릿 콜</a> </strong> </li>
# <li> <em class="num_newsview num9">9위</em> <strong class="tit_g"> <a class="link_txt @9" href="https://search.daum.net/search?w=tot&amp;q=%EC%95%84%EB%B8%8C%EB%9D%BC%ED%95%A8&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">아브라함</a> </strong> </li>
# <li> <em class="num_newsview num10">10위</em> <strong class="tit_g"> <a class="link_txt @10" href="https://search.daum.net/search?w=tot&amp;q=%EB%B2%8C%EB%9E%9C%EB%8D%94&amp;DA=23J&amp;rtmaxcoll=MBK,1TH">벌랜더</a> </strong> </li>
# </ol>
# </div> </li>
# </ul>
# </div>
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideBottomAd" data-ad-height="250" data-ad-type="D" data-ad-unit="0QH44" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# </div>
# </div>

# %%
div_4 = div_3.find_all('div', class_="foot_view")[0]
div_4
# Out:
# <div class="foot_view">
# <div class="wrap_brunch hc_news_pc_mArticle_brunchAuthor" style="display:none;">
# </div>
# <div class="relate_tag hc_news_pc_mArticle_relatedTags">
# <strong class="screen_out">관련 태그</strong>
# </div>
# <div class="relate_series hc_news_pc_mArticle_series" style="display:none;">
# <strong class="tit_series"><em class="tag_series">연재</em><span class="title_series"></span></strong>
# <!-- MCCP-856 연재 영역 수정 -->
# <ul class="list_series">
# </ul>
# <!-- //MCCP-856 연재 영역 수정 -->
# <a class="link_more #body #series_more" href="#none">더보기</a>
# </div>
# <div class="copyright_view">
# <span class="txt_copyright">ⓒ한국일보 www.hankookilbo.com (무단복제 및 전재, 재배포를 금지합니다)</span>
# <div class="btn_empathy hc_news_pc_mArticle_empathyButton">
# <link href="//m1.daumcdn.net/svc/original/U03/cssjs/uoclike/common/uoclike.min-20150408-2.css" rel="stylesheet" type="text/css"/>
# <div class="btn_empathy_pc" id="likeButton">
# </div>
# </div>
# </div>
# <!-- 언론사 관련기사(주요뉴스) -->
# <div class="cp_view">
# <strong class="tit_cp">한국일보 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
# <ul class="list_relate">
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045" target="_blank">실제와 너무 다른 '서울로 7017' 홍보 이미지</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22" target="_blank">[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851" target="_blank">공승연 "여진구 오빠 같아..잘생기면 오빠"</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c" target="_blank">지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">“라떼는 말이야…” 달라진 입시 풍경</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">2020학년도 수능 보는 연예인들</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">수능 출제위원장 “국어, 초고난도 문항 없다”</a></li>
# </ul>
# </div>
# <div id="alex-scroll-area"></div>
# <div class="recomm_ad hc_news_pc_mArticle_recommend_ad" id="daum-ad-root">
# </div>
# <div class="cmt_news cmt_view">
# <div class="alex-area" data-base-url="//comment.daum.net" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-initial-limit="3" data-is-mobile="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-max-length="300" data-page-limit="10" data-post-id="@20170615203441266" data-show-mask-alert="true" data-sort="R" data-use-attachment="false" data-use-emoticon="true" data-use-live-comment-mode="notify" data-use-my="true" data-use-official="true" data-use-reply="true" data-use-social-share="true" id="alex-area">
# </div>
# </div>
# </div>

# %%
div_5 = div_4.find_all('div', class_ = "cp_view")[0]
div_5
# Out:
# <div class="cp_view">
# <strong class="tit_cp">한국일보 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
# <ul class="list_relate">
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045" target="_blank">실제와 너무 다른 '서울로 7017' 홍보 이미지</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22" target="_blank">[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851" target="_blank">공승연 "여진구 오빠 같아..잘생기면 오빠"</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c" target="_blank">지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">“라떼는 말이야…” 달라진 입시 풍경</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">2020학년도 수능 보는 연예인들</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">수능 출제위원장 “국어, 초고난도 문항 없다”</a></li>
# </ul>
# </div>

# %%
news_list = div_5.find_all("li")
news_list
# Out:
# [<li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045" target="_blank">실제와 너무 다른 '서울로 7017' 홍보 이미지</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22" target="_blank">[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851" target="_blank">공승연 "여진구 오빠 같아..잘생기면 오빠"</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c" target="_blank">지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">“라떼는 말이야…” 달라진 입시 풍경</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">2020학년도 수능 보는 연예인들</a></li>,
#  <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&amp;dtype=3&amp;dtypecode=3381" target="_blank">수능 출제위원장 “국어, 초고난도 문항 없다”</a></li>]

# %%
type(news_list)
# Out:
# bs4.element.ResultSet

# %%
news_list[0]
# Out:
# <li><a class="link_txt #body #outmedia #related_list" data-type="related" href="http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1" target="_blank">[36.5°] 욕하면서 닮는 것도 적폐다</a></li>

# %%
news_list[0].text
# Out:
# '[36.5°] 욕하면서 닮는 것도 적폐다'

# %%
text_sum = []
for item in news_list:
    text_sum.append(item.text)

# %%
text_sum
# Out:
# ['[36.5°] 욕하면서 닮는 것도 적폐다',
#  "실제와 너무 다른 '서울로 7017' 홍보 이미지",
#  '[영상] 동국대.충무로에서 인기 있는 맛집 BEST 5',
#  '공승연 "여진구 오빠 같아..잘생기면 오빠"',
#  '지드래곤 "뭐가 문제죠?".. USB 음반 논란 일격',
#  '장관 사퇴 한 달 만에… 조국, 검찰 비공개 출두',
#  '“라떼는 말이야…” 달라진 입시 풍경',
#  '‘골프 황제’ 우즈의 욕설 방송은 ‘삐-’소리',
#  '2020학년도 수능 보는 연예인들',
#  '수능 출제위원장 “국어, 초고난도 문항 없다”']

# %%
final_url = []
for item in news_list:
    final_url.append(item.a["href"])
    # attrs

# %%
final_url
# Out:
# ['http://www.hankookilbo.com/v/801b1cc777e5438f9aa8107a27ec29e1',
#  'http://www.hankookilbo.com/v/211ec3b6e3f441e394a0710975399045',
#  'http://www.hankookilbo.com/v/04b5627be58645dfa7960e16a4624b22',
#  'http://www.hankookilbo.com/v/dae59b9e0adfd851dae59b9e0adfd851',
#  'http://www.hankookilbo.com/v/6162946d032e4b53909f80f78ef9b69c',
#  'http://www.hankookilbo.com/news/npath/201911140990066765?did=PA&dtype=3&dtypecode=3381',
#  'http://www.hankookilbo.com/news/npath/201911131301036287?did=PA&dtype=3&dtypecode=3381',
#  'http://www.hankookilbo.com/news/npath/201911140769749979?did=PA&dtype=3&dtypecode=3381',
#  'http://www.hankookilbo.com/news/npath/201911140903336785?did=PA&dtype=3&dtypecode=3381',
#  'http://www.hankookilbo.com/news/npath/201911140940786805?did=PA&dtype=3&dtypecode=3381']

# %% [markdown]
# 연습: http://media.daum.net/digital 에서 뉴스 리스트와 URL을 불러와보세요.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.naver.com")  

bsObject = BeautifulSoup(html, "html.parser") 

print(bsObject)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title">
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description">
# <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://pm.pstatic.net/css/main_v190926.css" rel="stylesheet" type="text/css"/>
# <link href="https://pm.pstatic.net/css/webfont_v170623.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_190612.css" rel="stylesheet" type="text/css"/>
# <script src="https://pm.pstatic.net/js/c/nlog_v181107.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/tveta/libs/assets/js/common/min/probe.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# var nsc = "navertop.v3";
# document.domain = "naver.com";
# var jindoAll = "";
# var iframeLazyLoad = false;
# if (!!!window.console) {window.console={};window.console["log"]=function(){}}
# var isLogin = false;
# function refreshLcs(etc) {etc = etc ? etc : {};if(document.cookie.indexOf("nrefreshx=1") != -1) {etc["mrf"]="1";} else {etc["pan"]="emo";}return etc;}
#
# </script>
# <title>NAVER</title>
# </meta></meta></meta></meta></meta></head>
# <style>
# 	#_nx_kbd .setkorhelp a { display:none; }
# </style>
# <body class="">
# <!-- 스킵 내비게이션 -->
# <div class="u_skip">
# <a href="#news_cast" onclick="document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"><span>연합뉴스 바로가기</span></a>
# <a href="#themecast" onclick="document.getElementById('themecast').tabIndex = -1;document.getElementById('themecast').focus();return false;"><span>주제별캐스트 바로가기</span></a>
# <a href="#time_square" onclick="document.getElementById('time_square').tabIndex = -1;document.getElementById('time_square').focus();return false;"><span>타임스퀘어 바로가기</span></a>
# <a href="#shp_cst" onclick="document.getElementById('shp_cst').tabIndex = -1;document.getElementById('shp_cst').focus();return false;"><span>쇼핑캐스트 바로가기</span></a>
# <a href="#account" onclick="document.getElementById('account').tabIndex = -1;document.getElementById('account').focus();return false;"><span>로그인 바로가기</span></a>
# </div>
# <!-- //스킵 내비게이션 -->
# <div class="wrap" id="PM_ID_ct">
# <!-- 헤더 -->
# <div class="header" role="banner">
# <div class="special_bg">
# <div class="area_flex">
# <div class="area_logo">
# <h1>
# <a data-clk="top.logo" href="/"><span class="naver_logo">네이버</span></a>
# </h1>
# </div>
# <div class="area_links">
# <a class="al_favorite" data-clk="top.mkhome" href="http://help.naver.com/support/alias/contents2/naverhome/naverhome_1.naver">네이버를 시작페이지로<span class="al_ico_link"></span></a>
# <span class="al_bar"></span>
# <a class="al_jr" data-clk="top.jrnaver" href="http://jr.naver.com"><span class="blind">쥬니어네이버</span><span class="al_ico"></span></a>
# <a class="al_happybean" data-clk="top.happybean" href="http://happybean.naver.com/main/SectionMain.nhn"><span class="blind">해피빈</span><span class="al_ico"></span></a>
# </div>
# <div class="search" id="search">
# <!--자동완성 입력창-->
# <form action="https://search.naver.com/search.naver" id="sform" method="get" name="sform">
# <fieldset>
# <legend class="blind">검색</legend>
# <input id="sm" name="sm" type="hidden" value="top_hty"/>
# <input id="fbm" name="fbm" type="hidden" value="0"/>
# <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
# <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
# <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
# <input id="ie" name="ie" type="hidden" value="utf8"/>
# <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
# <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
# <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
# <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
# <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
# <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
# <span class="green_window">
# <input accesskey="s" autocomplete="off" class="input_text" id="query" maxlength="255" name="query" onclick="document.getElementById('fbm').value=1;" style="ime-mode:active;" tabindex="1" title="검색어 입력" type="text" value=""/>
# </span>
# <div class="autocomplete" id="nautocomplete">
# <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
# <a class="btn_arw _btn_arw fold" href="javascript:;" role="button" tabindex="2"><span class="blind _text">자동완성 펼치기</span><span class="ico_arr"></span></a>
# </div>
# <button class="sch_smit" id="search_btn" onclick="clickcr(this,'sch.action','','',event);" onmousedown="this.className='sch_smit down'" onmouseout="this.className='sch_smit'" onmouseover="this.className='sch_smit over'" tabindex="3" title="검색" type="submit"><span class="blind">검색</span><span class="ico_search_submit"></span></button>
# </fieldset>
# </form>
# <!--자동완성 입력창-->
# <!--한글입력기 -->
# <a class="btn_keyboard" data-clk="sch.ime" href="javascript:;" id="ke_kbd_btn" onclick="nx_ime_load(this)" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>
# <style id="_nx_kbd_style" type="text/css"></style>
# <div id="_nx_kbd" style="display:none;"></div>
# <!--한글입력기 -->
# <!--자동완성 레이어 -->
# <div class="reatcmp" id="autoFrame" style="background-color:rgb(255, 255, 255);display:none;">
# <div class="api_atcmp_wrap _atcmp" style="display:none;">
# <div class="words _words">
# <div class="_atcmp_result_wrap">
# <ul class="_resultBox"></ul>
# <ul class="_resultBox"></ul>
# <ul class="_resultBox"></ul>
# <ul class="_resultBox"></ul>
# </div>
# <!-- 우측 정답형 영역 -->
# <div class="add_group _atcmp_answer_wrap"></div>
# </div>
# <!-- 컨텍스트 자동완성 플러스 -->
# <!-- [AU] _plus -->
# <div class="atcmp_plus _plus">
# <span class="desc">
# <span class="plus_txt _plusTxt">시간대와 관심사에 맞춘 <em class="txt">컨텍스트 자동완성</em></span>
# <a class="spat ico_info _plusHelp" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16658" onclick="__atcmpCR(event, this, 'plus.help', '','','');" target="_blank"><span class="blind">도움말 보기</span></a>
# </span>
# <!-- [AU] _plus_btn -->
# <span class="switch _plus_btn">
# <a class="btn_turnon active" href="#" onclick="__atcmpCR(event, this, 'plus.use', '','','');">ON<span class="blind">선택됨</span></a>
# <a class="btn_turnoff" href="#" onclick="__atcmpCR(event, this, 'plus.unuse', '','','');">OFF</a>
# </span>
# <div class="layer_plus _plusAlert">
# <strong class="tit">컨텍스트 자동완성</strong>
# <div class="_logout" style="display:block;">
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br/>관심사에 맞춰 자동완성을 제공합니다.</p>
# <div class="btn_area">
# <a class="btn btn_login" href="https://nid.naver.com/nidlogin.login" onclick="__atcmpCR(event, this, 'plus.login', '','','');">로그인</a>
# <a class="btn btn_view" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>
# </div>
# </div>
# <div class="_login" style="display:none;">
# <p class="dsc">ON/OFF설정은<br/>해당 기기(브라우저)에 저장됩니다.</p>
# <div class="btn_area">
# <a class="btn btn_view" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16659" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>
# </div>
# </div>
# <button class="btn_close _close" onclick="__atcmpCR(event, this, 'plus.close', '','','');" type="button"><i class="spat ico_close">컨텍스트 자동완성 레이어 닫기</i></button>
# </div>
# </div>
# <!-- //컨텍스트 자동완성 플러스 -->
# <p class="func _atcmpBtnGroup"><span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a class="report" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span><span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 끄기</a></span></p>
# <span class="atcmp_helper _help_tooltip1">기능을 다시 켤 때는 <em class="ico_search spat">자동완성 펼치기</em>을 클릭하세요</span>
# </div>
# <div class="api_atcmp_wrap _atcmpIng" style="display:none;">
# <div class="words"><p class="info_words">현재 자동완성 기능을 사용하고 계십니다.</p></div>
# <p class="func _atcmpBtnGroup"><span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a class="report" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span><span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 끄기</a></span></p>
# <span class="atcmp_helper _help_tooltip2">기능을 다시 켤 때는 <em class="ico_search spat">자동완성 펼치기</em>을 클릭하세요</span>
# </div>
# <div class="api_atcmp_wrap _atcmpStart" style="display:none;">
# <div class="words"><p class="info_words">자동완성 기능이 활성화되었습니다.</p></div>
# <p class="func _atcmpBtnGroup"><span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a class="report" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span><span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 끄기</a></span></p>
# <span class="atcmp_helper _help_tooltip3">기능을 다시 켤 때는 <em class="ico_search spat">자동완성 펼치기</em>을 클릭하세요</span>
# </div>
# <div class="api_atcmp_wrap _atcmpOff" style="display:none;">
# <div class="words"><p class="info_words">자동완성 기능이 꺼져 있습니다.</p></div>
# <p class="func _atcmpBtnGroup"><span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a class="report" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span><span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 켜기</a></span></p>
# </div>
# <!-- 최근검색어 & 내검색어 -->
# <div class="api_atcmp_wrap _keywords" style="display:none;">
# <div class="my_words">
# <div class="lst_tab">
# <ul><li class="on _recentTab"><a href="javascript:;">최근검색어</a></li><li class="_myTab"><a href="javascript:;">내 검색어</a></li></ul>
# </div>
# <div class="words _recent">
# <ul><li data-rank="@rank@"><a class="t@my@ _star _myBtn" href="javascript:;" title="내 검색어 등록"><em class="spat">내 검색어 등록</em></a><a class="keyword" href="javascript:;">@txt@</a><em class="keyword_date">@date@.</em><a class="btn_delete spat _del" href="javascript:;" title="검색어삭제">삭제</a><span style="display:none">@in_txt@</span></li></ul>
# <div class="info_words _recentNone" style="display:none">최근검색어 내역이 없습니다.</div>
# <p class="info_words _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.</p>
# </div>
# <div class="words _my" style="display:none">
# <ul><li data-rank="@rank@"><a class="ton _star _myBtn" href="javascript:;" title="내 검색어 해제"><em class="spat">내 검색어 해제</em></a><a class="keyword" href="javascript:;">@txt@</a></li></ul>
# <div class="info_words _myNone" style="display:none">설정된 내 검색어가 없습니다.<br>최근검색어에서 <span class="star spat">내 검색어 등록</span>를 선택하여 자주 찾는 검색어를<br>내 검색어로 저장해 보세요.</br></br></div>
# <p class="info_words _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.</p>
# </div>
# <p class="noti _noti" style="display:none"><em class="ico_noti spat"><span class="blind">알림</span></em>공용 PC에서는 개인정보 보호를 위하여 반드시 로그아웃을 해 주세요.</p>
# <p class="func _recentBtnGroup"><span class="fl"><a class="_delMode" href="javascript:;">기록 삭제</a></span><span><a class="_keywordOff" href="javascript:;">검색어저장 끄기</a><span class="atcmp_bar"></span><a class="_acOff" href="javascript:;">자동완성 끄기</a></span></p>
# <p class="func _recentDelBtnGroup" style="display:none"><span class="fl"><a class="_delAll" href="javascript:;" title="최근 검색어 기록을 모두 삭제합니다.">기록 전체 삭제</a></span><span><a class="_delDone" href="javascript:;">완료</a></span></p>
# <p class="func _myBtnGroup" style="display:none"><span class="fl"><a class="_delAll" href="javascript:;" title="설정된 내 검색어를 모두 삭제합니다.">기록 전체 삭제</a></span><span><a class="_keywordOff" href="javascript:;">검색어저장 끄기</a><span class="atcmp_bar"></span><a class="_acOff" href="javascript:;">자동완성 끄기</a></span></p>
# <span class="atcmp_helper _help2">기능을 다시 켤 때는 <em class="ico_search spat">자동완성 펼치기</em>을 클릭하세요</span>
# <div class="ly_noti _maxLayer" style="display:none">
# <span class="mask"></span>
# <p><span class="ico_alert spat"></span>내 검색어는 <em>최대 10</em>개 까지 저장할 수 있습니다.<br/>추가하시려면 기존 내 검색어를 지워주세요. <a class="btn_close _close" href="javascript:;"><i class="spat ico_close">닫기</i></a></p>
# </div>
# </div>
# </div>
# <!-- 자동완성 안내문구 (선거) -->
# <div class="api_atcmp_wrap _alert" style="display:none;">
# <div class="api_atcmp_alert">
# <span class="ico_alert spat"></span>
# <p class="dsc_txt"><em class="_passage"></em><br/>
# <a class="_link" href="" onclick="clickcr(this,'sug.vote','','',event);" target="_blank">자세히보기</a></p>
# </div>
# </div>
# <!-- //자동완성 안내문구 (선거) -->
# <!-- [D] IE 계열, wmode="window" flash와 겹치지 않기 위함 -->
# <iframe border="0" hspace="0" style="display:none;display:block\9;display:block\0/;position:absolute;left:0;top:0;width:100%;height:100%;z-index:-1;" title="빈 프레임" vspace="0"></iframe>
# </div>
# <!--자동완성 레이어 -->
# <!--자동완성 템플릿 추가-->
# <!-- 신규 공통 템플릿 -->
# <script id="_atcmp_answer_0" type="text/template">
#     <div class="add_opt _item" data-sm="@2@" data-keyword="@1@" data-template_id="@0@" data-acir="@rank@" data-os="@8@" data-bid="@9@" data-eid="@3@" data-pkid="@10@" data-mra="@11@" >
#         <a href="#" class="opt_dsc">
#             <span class="dsc_thmb" style="@style7@">@image7@</span>
#             <span class="dsc_group">
#                 <span class="dsc_cate">@6@</span>
#                 <strong class="dsc_word">@1@</strong>
#                 <span class="dsc_sub" style="@style12@">@12@</span>
#             </span>
#         </a>
#     </div>
# </script>
# <!-- 로또당첨번호 -->
# <script id="_atcmp_answer_3" type="text/template">
#     <div class="add_opt _item" data-sm="@2@" data-keyword="@1@" data-template_id="@0@" data-acir="@rank@">
#         <a href="javascript:;" class="opt_lotto">
#             <span class="lotto_num_area">
#                 <span class="spat lotto_num lotto_num@6@">@6@</span><span class="spat lotto_num lotto_num@7@">@7@</span><span class="spat lotto_num lotto_num@8@">@8@</span><span class="spat lotto_num lotto_num@9@">@9@</span><span class="spat lotto_num lotto_num@10@">@10@</span><span class="spat lotto_num lotto_num@11@">@11@</span><span class="spat lotto_bonus">+</span><span class="spat lotto_num lotto_num@12@">@12@</span>
#             </span>
#             <span class="lotto_sub">@5@회차<em class="lotto_date">(@13@.)</em></span>
#         </a>
#     </div>
# </script>
# <!-- 환율:엔화환율 -->
# <script id="_atcmp_answer_9" type="text/template">
#     <div class="add_opt _item" data-sm="@2@" data-keyword="@1@" data-template_id="@0@" data-acir="@rank@">
#         <a href="javascript:;" class="opt_exchange opt_exchange_@11@">
#             <span class="opt_nation">
#                 <img src="https://ssl.pstatic.net/sstatic/keypage/lifesrch/exchange/ico_@12@1.gif" alt="" />
#                 @14@<span class="tx_nation">@money@</span>
#             </span>
#             <span class="opt_amount">
#                 <span class="amount"><strong>@6@</strong>원</span><span class="changes"><i class="bullet">@10@</i> @8@ (@9@%)<span class="opt_time"><time datetime="@fulldate@">@7@</time></span></span>
#             </span>
#         </a>
#     </div>
# </script>
# <!-- 해외날씨 : 파리날씨 -->
# <script id="_atcmp_answer_10" type="text/template">
#     <div class="add_opt _item" data-sm="@2@" data-keyword="@1@" data-template_id="@0@" data-acir="@rank@">
#         <a href="javascript:;" class="opt_weather">
#             <span class="opt_weather_thmb">
#                 <img src="https://ssl.pstatic.net/sstatic/search/pc/img/wt_@6@.png" width="56" height="56" alt="@7@">
#             </span>
#             <span class="opt_weather_group">
#                 <span class="opt_weather_state">@7@</span>
#                 <span class="opt_weather_state">기온 <em class="opt_deg">@8@</em><span class="opt_unit">℃</span></span>
#                 <span class="opt_weather_state">@9@ <em>@10@</em><span class="opt_unit">@11@</span></span>
# 				<span class="opt_weather_state"><span class="opt_time"><time datetime="@fulldate@">@5@</time></span></span>
#             </span>
#         </a>
#     </div>
# </script>
# <!-- 국내날씨 : 서울날씨 -->
# <script id="_atcmp_answer_11" type="text/template">
#     <div class="add_opt _item" data-sm="@2@" data-keyword="@1@" data-template_id="@0@" data-acir="@rank@">
#         <a href="javascript:;" class="opt_weather">
#             <span class="opt_weather_thmb">
#                 <img src="https://ssl.pstatic.net/sstatic/search/pc/img/wt_@6@.png" width="56" height="56" alt="@7@">
#             </span>
#             <span class="opt_weather_group">
#                 <span class="opt_weather_state">@7@</span>
#                 <span class="opt_weather_state">기온 <em class="opt_deg">@8@</em><span class="opt_unit">℃</span></span>
#                 <span class="opt_weather_state">@9@ <em>@10@</em><span class="opt_unit">@11@</span></span>
# 				<span class="opt_weather_state"><span class="opt_time"><time datetime="@fulldate@">@5@</time></span></span>
#             </span>
#         </a>
#     </div>
# </script>
# <!-- 바로가기 -->
# <script id="_atcmp_answer_17" type="text/template">
#     <div class="add_opt _item" data-sm="@2@" data-keyword="@1@" data-template_id="@0@" data-acir="@rank@">
#         <a href="@5@" target="_blank" class="opt_shortcut">
#             <span class="opt_url">@display_link@</span>
#             <span class="opt_txt">사이트로 바로 이동</span>
#         </a>
#     </div>
# </script>
# <!-- 해외날씨 : 국내날씨 형태로 제공하기 위한 새로운 템플릿(10번으로 ID변경됨) -->
# <script id="_atcmp_answer_20" type="text/template"></script>
# <!-- 문맥검색 -->
# <script id="_atcmp_intend" type="text/template">
#     <div class="add_opt type_context _item" data-sm="asct" data-keyword="@transquery@" data-acir="@rank@">
#         <a href="#" class="opt_context">
#             <span class="opt_tit"><strong>@query@</strong></span>
#             <span class="opt_sub">@intend@</span>
#         </a>
#     </div>
# </script>
# <!-- 결과 키워드 템플릿 (좌측 결과목록 템플릿:정답형 템플릿 아님) -->
# <script id="_atcmp_result_item_tpl" type="text/template">
#     <li class="_item @url_class@" data-acr="@rank@">
#         <a href="#" class="atcmp_keyword" onclick="return false;" title=""><span class="atcmp_keyword_txt">@txt@<span class="spat ic_expand"></span></span></a>
#         <a href="@url@" target="_blank" class="mquick">바로이동</a>
#         <span style="display:none">@in_txt@</span>
#     </li>
# </script>
# <!-- 일반 자동완성 하이라이팅 템플릿 -->
# <script id="_atcmp_keyword_highlight_tpl" type="text/template">
#     @mismatch_before@<strong>@match@</strong>@mismatch_after@
# </script>
# <!-- 부분 자동완성 하이라이팅 템플릿 -->
# <script id="_atcmp_keyword_partial_match_highlight_tpl" type="text/template">
#     @mismatch_before@<strong>@match@</strong>@mismatch_after@
# </script>
# <!--자동완성 템플릿 추가-->
# </div>
# <!-- EMPTY --></div>
# </div>
# <div class="section_navbar">
# <div class="area_navigation" role="navigation">
# <ul class="an_l">
# <li class="an_item">
# <a class="an_a mn_mail" data-clk="svc.mail" href="https://mail.naver.com/">
# <span class="an_icon"></span><span class="an_txt">메일</span>
# </a>
# </li>
# <li class="an_item">
# <a class="an_a mn_cafe" data-clk="svc.cafe" href="https://section.cafe.naver.com/">
# <span class="an_icon"></span><span class="an_txt">카페</span>
# </a>
# </li>
# <li class="an_item">
# <a class="an_a mn_blog" data-clk="svc.blog" href="https://section.blog.naver.com/">
# <span class="an_icon"></span><span class="an_txt">블로그</span>
# </a>
# </li>
# <li class="an_item">
# <a class="an_a mn_kin" data-clk="svc.kin" href="https://kin.naver.com/">
# <span class="an_icon"></span><span class="an_txt">지식인</span>
# </a>
# </li>
# <li class="an_item">
# <a class="an_a mn_shopping" data-clk="svc.shopping" href="https://shopping.naver.com/">
# <span class="an_icon"></span><span class="an_txt">쇼핑</span>
# </a>
# </li>
# <li class="an_item">
# <a class="an_a mn_checkout" data-clk="svc.pay" href="https://order.pay.naver.com/home">
# <span class="an_icon"></span><span class="an_txt">네이버페이</span>
# </a>
# </li>
# <li class="an_item">
# <a class="an_a mn_tvcast" data-clk="svc.tvcast" href="https://tv.naver.com/">
# <span class="an_icon"></span><span class="an_txt">네이버TV</span>
# </a>
# </li>
# </ul>
# <ul class="an_l" id="PM_ID_serviceNavi">
# <li class="an_item"><a class="an_a mn_dic" data-clk="svc.dic" href="https://dict.naver.com/"><span class="an_icon"></span><span class="an_txt">사전</span></a></li>
# <li class="an_item"><a class="an_a mn_news" data-clk="svc.news" href="https://news.naver.com/"><span class="an_icon"></span><span class="an_txt">뉴스</span></a></li>
# <li class="an_item"><a class="an_a mn_stock" data-clk="svc.stock" href="https://finance.naver.com/"><span class="an_icon"></span><span class="an_txt">증권(금융)</span></a></li>
# <li class="an_item"><a class="an_a mn_land" data-clk="svc.land" href="https://land.naver.com/"><span class="an_icon"></span><span class="an_txt">부동산</span></a></li>
# <li class="an_item"><a class="an_a mn_map" data-clk="svc.map" href="https://map.naver.com/"><span class="an_icon"></span><span class="an_txt">지도</span></a></li>
# <li class="an_item"><a class="an_a mn_movie" data-clk="svc.movie" href="https://movie.naver.com/"><span class="an_icon"></span><span class="an_txt">영화</span></a></li>
# <li class="an_item"><a class="an_a mn_music" data-clk="svc.music" href="https://music.naver.com"><span class="an_icon"></span><span class="an_txt">뮤직</span></a></li>
# <li class="an_item"><a class="an_a mn_book" data-clk="svc.book" href="https://book.naver.com/"><span class="an_icon"></span><span class="an_txt">책</span></a></li>
# <li class="an_item"><a class="an_a mn_comic" data-clk="svc.webtoon" href="https://comic.naver.com/"><span class="an_icon"></span><span class="an_txt">만화 / 웹툰</span></a></li>
# </ul>
# <ul class="an_l an_custom" id="PM_ID_serviceNaviEmpty" style="display:none">
# <li class="an_item an_pointer"><span class="an_empty"></span></li>
# <li class="an_item"><span class="an_empty"></span></li>
# <li class="an_item"><span class="an_empty"></span></li>
# <li class="an_item"><span class="an_empty"></span></li>
# <li class="an_item"><span class="an_empty"></span></li>
# </ul>
# <div class="an_bar"></div>
# <a class="PM_CL_btnServiceMore an_btn_more" data-clk="svc.more" href="#" id="PM_ID_btnServiceMore" role="button"><span class="an_mtxt"><span class="blind">더보기</span></span><span class="ico_an_more"></span></a>
# </div>
# <div class="area_hotkeyword PM_CL_realtimeKeyword_base">
# <div aria-hidden="false" class="ah_roll PM_CL_realtimeKeyword_rolling_base">
# <h3 class="blind">급상승 검색어 검색어</h3>
# <div class="ah_roll_area PM_CL_realtimeKeyword_rolling">
# <ul class="ah_l">
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">1</span>
# <span class="ah_k">뉴트리코어 맥스크릴오일</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">2</span>
# <span class="ah_k">kb스타뱅킹 축하금</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">3</span>
# <span class="ah_k">kb스타뱅킹</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">4</span>
# <span class="ah_k">skt pass 5만원준다 해외주식</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">5</span>
# <span class="ah_k">조국 구속</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">6</span>
# <span class="ah_k">뉴트리코어 크릴오일</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">7</span>
# <span class="ah_k">크레온 평생무료</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">8</span>
# <span class="ah_k">맥스크릴오일</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">9</span>
# <span class="ah_k">페이스팩토리 뷰티석션</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">10</span>
# <span class="ah_k">skt pass 5만원준다</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">11</span>
# <span class="ah_k">bgf리테일 채용</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">12</span>
# <span class="ah_k">뉴트리코어</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">13</span>
# <span class="ah_k">조국수호 검찰개혁</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">14</span>
# <span class="ah_k">skt pass 15만원준다카드</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">15</span>
# <span class="ah_k">홍선영</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">16</span>
# <span class="ah_k">류현진</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">17</span>
# <span class="ah_k">황석영</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">18</span>
# <span class="ah_k">여미휴게소</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">19</span>
# <span class="ah_k">skt pass</span>
# </a>
# </li>
# <li class="ah_item">
# <a class="ah_a" data-clk="lve.keyword" href="#">
# <span class="ah_r">20</span>
# <span class="ah_k">19호 태풍 하기비스</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <span class="ah_ico_open"></span>
# <div aria-hidden="true" class="ah_list PM_CL_realtimeKeyword_list_base">
# <h3 class="ah_ltit">급상승 검색어</h3>
# <div class="ah_target"><em class="target">전체연령</em>·<em class="target">현재</em></div>
# <div class="ah_tab">
# <a class="ah_tab_btn ah_tab_on" data-clk="lve.tab1" data-tab="1to10" href="#" role="tab">1~10위</a>
# <a class="ah_tab_btn" data-clk="lve.tab2" data-tab="11to20" href="#" role="tab">11~20위</a>
# </div>
# <h4 class="blind PM_CL_realtimeKeyword_sublist_heading">급상승 검색어 1~10위</h4>
# <ul class="ah_l" data-list="1to10">
# <li class="ah_item" data-order="1">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">1</span>
# <span class="ah_k">뉴트리코어 맥스크릴오일</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="2">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9+%EC%B6%95%ED%95%98%EA%B8%88&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9+%EC%B6%95%ED%95%98%EA%B8%88&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">2</span>
# <span class="ah_k">kb스타뱅킹 축하금</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9+%EC%B6%95%ED%95%98%EA%B8%88&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="3">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">3</span>
# <span class="ah_k">kb스타뱅킹</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="4">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4+%ED%95%B4%EC%99%B8%EC%A3%BC%EC%8B%9D&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4+%ED%95%B4%EC%99%B8%EC%A3%BC%EC%8B%9D&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">4</span>
# <span class="ah_k">skt pass 5만원준다 해외주식</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4+%ED%95%B4%EC%99%B8%EC%A3%BC%EC%8B%9D&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="5">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A1%B0%EA%B5%AD+%EA%B5%AC%EC%86%8D&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A1%B0%EA%B5%AD+%EA%B5%AC%EC%86%8D&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">5</span>
# <span class="ah_k">조국 구속</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%EC%A1%B0%EA%B5%AD+%EA%B5%AC%EC%86%8D&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="6">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">6</span>
# <span class="ah_k">뉴트리코어 크릴오일</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="7">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%ED%81%AC%EB%A0%88%EC%98%A8+%ED%8F%89%EC%83%9D%EB%AC%B4%EB%A3%8C&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%81%AC%EB%A0%88%EC%98%A8+%ED%8F%89%EC%83%9D%EB%AC%B4%EB%A3%8C&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">7</span>
# <span class="ah_k">크레온 평생무료</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%ED%81%AC%EB%A0%88%EC%98%A8+%ED%8F%89%EC%83%9D%EB%AC%B4%EB%A3%8C&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="8">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">8</span>
# <span class="ah_k">맥스크릴오일</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="9">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%ED%8E%98%EC%9D%B4%EC%8A%A4%ED%8C%A9%ED%86%A0%EB%A6%AC+%EB%B7%B0%ED%8B%B0%EC%84%9D%EC%85%98&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%8E%98%EC%9D%B4%EC%8A%A4%ED%8C%A9%ED%86%A0%EB%A6%AC+%EB%B7%B0%ED%8B%B0%EC%84%9D%EC%85%98&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">9</span>
# <span class="ah_k">페이스팩토리 뷰티석션</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%ED%8E%98%EC%9D%B4%EC%8A%A4%ED%8C%A9%ED%86%A0%EB%A6%AC+%EB%B7%B0%ED%8B%B0%EC%84%9D%EC%85%98&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="10">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">10</span>
# <span class="ah_k">skt pass 5만원준다</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# </ul>
# <ul class="ah_l" data-list="11to20" style="display:none;">
# <li class="ah_item" data-order="11">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=bgf%EB%A6%AC%ED%85%8C%EC%9D%BC+%EC%B1%84%EC%9A%A9&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=bgf%EB%A6%AC%ED%85%8C%EC%9D%BC+%EC%B1%84%EC%9A%A9&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">11</span>
# <span class="ah_k">bgf리테일 채용</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=bgf%EB%A6%AC%ED%85%8C%EC%9D%BC+%EC%B1%84%EC%9A%A9&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="12">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">12</span>
# <span class="ah_k">뉴트리코어</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="13">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A1%B0%EA%B5%AD%EC%88%98%ED%98%B8+%EA%B2%80%EC%B0%B0%EA%B0%9C%ED%98%81&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A1%B0%EA%B5%AD%EC%88%98%ED%98%B8+%EA%B2%80%EC%B0%B0%EA%B0%9C%ED%98%81&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">13</span>
# <span class="ah_k">조국수호 검찰개혁</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%EC%A1%B0%EA%B5%AD%EC%88%98%ED%98%B8+%EA%B2%80%EC%B0%B0%EA%B0%9C%ED%98%81&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="14">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=skt+pass+15%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4%EC%B9%B4%EB%93%9C&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=skt+pass+15%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4%EC%B9%B4%EB%93%9C&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">14</span>
# <span class="ah_k">skt pass 15만원준다카드</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=skt+pass+15%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4%EC%B9%B4%EB%93%9C&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="15">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%ED%99%8D%EC%84%A0%EC%98%81&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%99%8D%EC%84%A0%EC%98%81&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">15</span>
# <span class="ah_k">홍선영</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%ED%99%8D%EC%84%A0%EC%98%81&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="16">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%A5%98%ED%98%84%EC%A7%84&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%A5%98%ED%98%84%EC%A7%84&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">16</span>
# <span class="ah_k">류현진</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%EB%A5%98%ED%98%84%EC%A7%84&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="17">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%ED%99%A9%EC%84%9D%EC%98%81&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%99%A9%EC%84%9D%EC%98%81&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">17</span>
# <span class="ah_k">황석영</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%ED%99%A9%EC%84%9D%EC%98%81&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="18">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%97%AC%EB%AF%B8%ED%9C%B4%EA%B2%8C%EC%86%8C&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%97%AC%EB%AF%B8%ED%9C%B4%EA%B2%8C%EC%86%8C&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">18</span>
# <span class="ah_k">여미휴게소</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=%EC%97%AC%EB%AF%B8%ED%9C%B4%EA%B2%8C%EC%86%8C&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="19">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=skt+pass&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=skt+pass&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">19</span>
# <span class="ah_k">skt pass</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=skt+pass&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# <li class="ah_item" data-order="20">
# <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=19%ED%98%B8+%ED%83%9C%ED%92%8D+%ED%95%98%EA%B8%B0%EB%B9%84%EC%8A%A4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=19%ED%98%B8+%ED%83%9C%ED%92%8D+%ED%95%98%EA%B8%B0%EB%B9%84%EC%8A%A4&amp;sm=top_lve&amp;ie=utf8">
# <span class="ah_r">20</span>
# <span class="ah_k">19호 태풍 하기비스</span>
# </a>
# <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&amp;query=19%ED%98%B8+%ED%83%9C%ED%92%8D+%ED%95%98%EA%B8%B0%EB%B9%84%EC%8A%A4&amp;where=main">
# <span class="blind">데이터랩 그래프 보기</span>
# <span class="ah_ico_datagraph"></span>
# </a>
# </li>
# </ul>
# <div class="ah_info">
# <p class="ah_time" data-time="20191007151700">2019.10.07. 15:17 기준 <a class="ah_btn_help" data-clk="lve.help" data-ssl="https://help.naver.com/support/alias/search/word/word_5.naver" href="http://help.naver.com/support/alias/search/word/word_5.naver"><span class="ah_ico_help"></span><span class="blind">도움말</span></a></p>
# <a class="ah_ha" data-clk="lve.rankhistory" href="http://datalab.naver.com/keyword/realtimeList.naver?where=main"><span class="ah_ico_datalab">DataLab.</span>급상승 트래킹<span class="ah_ico_hlink"></span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- //헤더 -->
# <div style="position:relative;width:1080px;margin:0 auto;z-index:11">
# <div id="da_top"></div>
# <div id="da_brand"></div>
# <div id="da_stake"></div>
# <div id="da_expwide"></div>
# </div>
# <div class="container" role="main">
# <div class="column_left">
# <!-- AD TOP -->
# <div id="veta_top">
# <iframe data-veta-preview="main_time" frameborder="0" height="120" id="da_iframe_time" marginheight="0" marginwidth="0" name="da_iframe_time" scrolling="no" src="https://nv.veta.naver.com/fxshow?su=SU10079&amp;nrefreshx=0" title="광고" width="740"></iframe>
# <div class="veta_bdt"></div><div class="veta_bdr"></div><div class="veta_bdb"></div><div class="veta_bdl"></div>
# </div>
# <!-- //AD TOP -->
# <!-- 뉴스캐스트 -->
# <div class="section_newscast" id="news_cast">
# <div class="area_newstop">
# <div class="cast_flash">
# <h3 class="cf_tit">
# <a class="cf_ta" data-clk="ncy.newsflash" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">연합뉴스<span class="cf_ico_link"></span></a>
# </h3>
# <div class="cast_atc _PM_newsstand_rolling">
# <ol class="ca_l">
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126895">文대통령 "국민 목소리 엄중히 들어…대립의 골 바람직 않아"</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126607">검찰, 밤 9시 이후 심야조사 폐지…윤석열 3번째 개혁안</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126605">'수상한 집값' 부동산거래 대대적 조사…강남4구·마용성 '집중'</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126438">류현진 '다저스 살렸다'…5이닝 2실점 호투로 PS 통산 3승</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126613">연매출 30억미만 온라인사업자에 최대 1억원, 2%대 대출</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126576">화성 8차 사건 범인,  "고문당해 자백" 항소했다가 기각</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126917">예견됐던 日단속선·北어선 '대화퇴' 충돌</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126916">만취 10대에게 운전시킨 40대 구속기소</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126667">미투 의혹 발끈 오거돈, 강용석 등 가로세로연구소 유튜버 고소</a></li>
# <li class="ca_item"><a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0011126923">타다, 택시와 상생안에 "회사 망하면 국가 배상문제 짚어야"</a></li>
# </ol>
# </div>
# </div>
# <ul class="cast_link">
# <li class="cl_item">
# <a class="cl_a cl_news" data-clk="ncy.newshome" href="http://news.naver.com/">
# 네이버뉴스</a>
# </li>
# <li class="cl_item">
# <a class="cl_a cl_ent" data-clk="ncy.entertainment" href="http://entertain.naver.com/home">
# 연예</a>
# </li>
# <li class="cl_item">
# <a class="cl_a cl_sports" data-clk="ncy.sports" href="http://sports.news.naver.com/">
# 스포츠</a>
# </li>
# <li class="cl_item">
# <a class="cl_a cl_finance" data-clk="ncy.economy" href="http://news.naver.com/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101">
# 경제</a>
# </li>
# </ul>
# </div>
# <div class="area_newsstand">
# <div class="an_menulist">
# <h3 class="an_tit">
# <a class="an_ta" data-clk="nsd.title" href="http://newsstand.naver.com/" target="_blank">뉴스스탠드<span class="an_ico_link"></span></a>
# </h3>
# <div class="an_menulist_section1">
# ...
# <li class="at_item"><span class="at_bar"></span><a class="at_a" data-clk="plc.youth" href="/policy/youthpolicy.html">청소년보호정책</a></li>
# <li class="at_item"><span class="at_bar"></span><a class="at_a" data-clk="plc.policy" href="/policy/spamcheck.html">네이버 정책</a></li>
# <li class="at_item"><span class="at_bar"></span><a class="at_a" data-clk="plc.helpcenter" href="https://help.naver.com/">고객센터</a></li>
# </ul>
# <address class="at_cr">ⓒ <a class="at_ca" data-clk="plc.nhn" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a></address>
# </div>
# </div>
# </div>
# </div>
# <script src="https://pm.pstatic.net/js/c/jindo_v190909.js"></script>
# <script>
# 		var svr = "<!--aweb102-->";
# 		var svt = "20191007151740";
# 		var aPanelListAll;
#
# 		var nmainJS = ["https://pm.pstatic.net/js/c/nmain_v190926.js"];
#
# 		var sThemecastAdScriptUrl = 'https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js?20180330';
# 		nmainJS.push(sThemecastAdScriptUrl);
#
# 		function loadJS() {
#
#
# 				setTimeout(function() { lcs_do(refreshLcs()); }, 0);
#
#
# 			jindo.LazyLoading.load(nmainJS, function(){
#
# 				try { naver.main.nelo.setEnable(true); } catch(e) { };
#
# 				if ( svr === "<!--cweb301.ntop-->" ) {
# 					JEagleEyeClient.setEnable(true);
# 				}
#
# 				if(typeof initPage != 'undefined') {
#     				initPage();
# 				}
#
# 				try {
# 					aPanelListAll = [{"adMap":null,"code":"LIVINGHOME","name":"리빙","css":"livinghome","nclick":"lif","openDate":null},{"adMap":null,"code":"LIVING","name":"푸드","css":"living","nclick":"fod","openDate":null},{"adMap":null,"code":"SPORTS","name":"스포츠","css":"sports","nclick":"spo","openDate":null},{"adMap":null,"code":"CARGAME","name":"자동차","css":"cargame","nclick":"aut","openDate":null},{"adMap":null,"code":"BEAUTY","name":"패션뷰티","css":"beauty","nclick":"bty","openDate":null},{"adMap":null,"code":"MOMKIDS","name":"부모i","css":"momkids","nclick":"mom","openDate":null},{"adMap":null,"code":"HEALTH","name":"건강","css":"health","nclick":"hea","openDate":null},{"adMap":null,"code":"BBOOM","name":"웹툰","css":"bboom","nclick":"web","openDate":null},{"adMap":null,"code":"GAMEAPP","name":"게임","css":"gameapp","nclick":"gam","openDate":null},{"adMap":null,"code":"VIDEO","name":"TV연예","css":"video","nclick":"tvc","openDate":null},{"adMap":null,"code":"MUSIC","name":"뮤직","css":"music","nclick":"muc","openDate":null},{"adMap":{"id":"p_main_movie_00","adPath":"%2Ffxshow%3Fsu%3DSU10199%26da_dom_id%3Dp_main_movie_00%26tb%3DMOVIE_1"},"code":"MOVIE","name":"영화","css":"movie","nclick":"mov","openDate":null},{"adMap":null,"code":"CULTURE","name":"책문화","css":"culture","nclick":"bok","openDate":null},{"adMap":null,"code":"WITH","name":"함께N","css":"with","nclick":"pub","openDate":null},{"adMap":{"id":"p_main_travel_00","adPath":"%2Ffxshow%3Fsu%3DSU10198%26da_dom_id%3Dp_main_travel_00%26tb%3DTRAVEL_1"},"code":"TRAVEL","name":"여행+","css":"travel","nclick":"tra","openDate":null},{"adMap":null,"code":"DESIGN","name":"디자인","css":"design","nclick":"des","openDate":null},{"adMap":null,"code":"FINANCE","name":"경제M","css":"finance","nclick":"fin","openDate":null},{"adMap":{"id":"p_main_job_00","adPath":"%2Ffxshow%3Fsu%3DSU10200%26da_dom_id%3Dp_main_job_00%26tb%3DJOB_1"},"code":"JOB","name":"JOB&","css":"job","nclick":"job","openDate":null},{"adMap":null,"code":"SCIENCE","name":"과학","css":"science","nclick":"sci","openDate":null},{"adMap":null,"code":"CHINA","name":"중국","css":"china","nclick":"chn","openDate":null},{"adMap":{"id":"p_main_business_00","adPath":"%2Ffxshow%3Fsu%3DSU10204%26da_dom_id%3Dp_main_business_00%26tb%3DBUSINESS_1"},"code":"BUSINESS","name":"비즈니스","css":"business","nclick":"bsn","openDate":null},{"adMap":null,"code":"FARM","name":"FARM","css":"farm","nclick":"far","openDate":null},{"adMap":{"id":"p_main_school_01","adPath":"%2Ffxshow%3Fsu%3DSU10210%26da_dom_id%3Dp_main_school_01%26tb%3DSCHOOL_1"},"code":"SCHOOL","name":"스쿨잼","css":"school","nclick":"scl","openDate":null},{"adMap":null,"code":"SHOW","name":"공연전시","css":"show","nclick":"sow","openDate":"20170622"},{"adMap":null,"code":"LAW","name":"법률","css":"law","nclick":"law","openDate":"20170803"},{"adMap":null,"code":"ANIMAL","name":"동물공감","css":"animal","nclick":"ani","openDate":"20170824"},{"adMap":null,"code":"WEDDING","name":"연애·결혼","css":"wedding","nclick":"wed","openDate":"20170831"},{"adMap":null,"code":"ITTECH","name":"테크","css":"ittech","nclick":"tec","openDate":"20170921"},{"adMap":null,"code":"EMOTION","name":"감성충전","css":"emotion","nclick":"emo","openDate":"20180322"}];
# 				} catch(e) {
# 					JEagleEyeClient.sendError("invalid panel.json");
# 				}
# 				naver.main.PageRefresh.init();
#
# 				naver.main.Panel.init(aPanelListAll);
#
# 				naver.main.Log.init();
#
# 				naver.main.ServiceNavi.init();
# 				naver.main.ThemecastNavi.init({
# 					bFlick: false,
# 					sAdList: '{"header":{"msg":"success","code":0},"body":{"adScriptList":[{"adScriptPCMain1":{"http":"https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js?20180330","https":"https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js?20180330"}}],"adList":[{"menu":"ANIMAL","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000124","singleDomAdUrl":"https://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_00","tb":"ANIMAL_1","unit":"SU10261","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000106","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_00","tb":"BEAUTY_1","unit":"SU10249","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"BUSINESS","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000084","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_00","tb":"BUSINESS_1","unit":"SU10204","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"CARGAME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000102","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_cargame_00","tb":"CARGAME_1","unit":"SU10253","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"CHINA","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000107","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_china_00","tb":"CHINA_1","unit":"SU10206","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"DESIGN","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000090","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_design_00","tb":"DESIGN_1","unit":"SU10205","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"FARM","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000101","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_farm_00","tb":"FARM_1","unit":"SU10207","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"FINANCE","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000105","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_finance_00","tb":"FINANCE_1","unit":"SU10250","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"ITTECH","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000113","singleDomAdUrl":"https://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_ittech_00","tb":"ITTECH_1","unit":"SU10260","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"JOB","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000088","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_job_00","tb":"JOB_1","unit":"SU10200","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":null}]},{"menu":"LAW","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000100","singleDomAdUrl":"http://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_law_00","tb":"LAW_1","unit":"SU10255","calp":"-"},"type":{"position":"rel","positionIndex":0,"subject":"contents"},"dom":nul ...
# 				});
# 				naver.main.CenterBanner.init();
# 				newSmartSearch();
#
# 				new naver.main.Newsstand({
# 					rcode : "09350103",
#         		    newspaperURL : "newspaper.naver.com",
#             		newsStandURL : "newsstand.naver.com",
# 		            userInfoURL : "userinfo.www.naver.com",
#     		        newsCastInfo : "",
#         		    newsStandInfo : "",
#             		headlineList : {"pid" : ["002","003","005","006","008","009","011","013","014","015","016","018","020","021","022","023","024","025","028","029","030","031","032","038","040","042","044","047","050","052","055","056","057","073","075","076","079","081","082","087","088","089","092","094","108","109","117","120","122","123","135","138","139","140","143","144","213","214","215","241","243","277","293","296","301","308","310","311","312","314","326","327","328","329","330","331","332","333","334","335","336","337","338","339","340","344","345","346","353","354","355","356","361","362","363","364","366","368","374","376","384","385","387","388","389","390","391","396","404","410","416","417","421","422","440","447","477","529","536","539","801","802","803","804","806","807","808","809","810","811","812","813","814","815","816","817","818","820","901","902","903","904","905","906","907","908","909","910","911","912","913","914","915","916","917","920","921","922","923","924","925","926","927","928","930","932","933","934","935","936","937","938","939","940","941","942","943","944","945","946","947","948","949","950","951","952","953","954","955","956","957","958","959","960","961","962","963","964","965","966","967","968","969","970","971","972","973","974","975","976","977","978","979","980","981","982","983","984","986","987","988","989","990","991","993"], "amigo" : [], "invalid" : []},
# 					pressCategory : {"ct1":[{"pid":"032","name":"경향신문","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd14372435.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/032.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"005","name":"국민일보","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd1438916.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/005.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"079","name":"노컷뉴스","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd143958887.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/079.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"327","name":"뉴데일리","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd144037935.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/327.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"930","name":"뉴스타파","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd144152433.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/930.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"003","name":"뉴시스","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd14449981.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/003.png","cate":"ct3","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"368","name":"데일리안","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd14463367.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/368.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"020","name":"동아일보","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd14479875.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/020.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"029","name":"디지털타임스","img":"https://s.pstatic.net/static/newsstand/up/2018/0719/nsd162516824.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/029.png","cate":"ct4","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"117","name":"마이데일리","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd144944309.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/117.png","cate":"ct6","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"009","name":"매일경제","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145032565.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/009.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"008","name":"머니투데이","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145214517.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/008.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"021","name":"문화일보","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd19245981.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/021.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"006","name":"미디어오늘","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145346617.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/006.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"293","name":"블로터","img":"https://s.pstatic.net/static/newsstand/up/2018/0316/nsd175350622.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/293.png","cate":"ct4","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"011","name":"서울경제","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145718601.png","newMainLogo":"https://s.pstatic.net/static/newsstand/2019/logo/011.png","cate":"ct2","amigo":"N","viewer":"Y","today":"N","local":null},{"pid":"081","name":"서울신문","img":"https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145738195.png","newMainLogo":" ...
# 					isSupportedFlicking : false
#     		    });
#
# 				new naver.main.Timesquare({
#     	    	    aOrderedPanel : [{"code":"weather","name":"날씨"},{"code":"news","name":"뉴스"},{"code":"sports","name":"스포츠"},{"code":"finance","name":"금융"},{"code":"conversation","name":"회화"},{"code":"lifetools","name":"생활도구"}],
#         	    	isSupportedFlicking : false
# 		        });
#
# 				new naver.main.RealtimeKeyword();
# 				if ( !($Agent().navigator().ie && $Agent().navigator().version <= 8) ) {
# 					naver_adbd.Manager().activate();
# 				}
#
# 				naver.main.SchoolFixed.init("(none)");
# 				naver.main.bestseller.init();
# 				naver.main.PromotionTopBanner.init();
#
# 				setTimeout(function() {
# 					if (iframeLazyLoad) {
# 						$Element("da_iframe_time").attr("src", urlDaIframeTime);
# 						var welMinime = $Element("minime");
# 						if (welMinime) {
# 							welMinime.attr("src", urlMinime);
# 						}
# 						$Element("da_iframe_rolling").attr("src", urlDaIframeRolling);
# 						$Element("cnsv_shbx").attr("src", urlCnsvShbx);
# 						$Element("da_iframe_below").attr("src", urlDaIframeBelow);
# 					}
# 					//console.log(performance.timing.loadEventEnd - performance.timing.navigationStart);
# 				}, 0);
#
# 			});
# 		}
#
# 		if (window.addEventListener) {
# 			window.addEventListener("load", function() { loadJS(); }, true);
# 		} else if (window.attachEvent) {
# 			window.attachEvent("onload", loadJS);
# 		} else {
# 			window.onload = loadJS;
# 		}
#
# 	</script>
# </body>
# </html>

# %%
print(bsObject.head.title)
# Out:
# <title>NAVER</title>

# %%
for meta in bsObject.head.find_all('meta'):
    print(meta.get('content'))
# Out:
# None
# origin
# text/javascript
# text/css
# IE=edge
# width=1100
# NAVER
# index,nofollow
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# 네이버
# https://www.naver.com/
# https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# summary
#
# https://www.naver.com/
# https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
print (bsObject.head.find("meta", {"name":"description"}).get('content'))
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
# 연합뉴스 바로가기 #news_cast
# 주제별캐스트 바로가기 #themecast
# 타임스퀘어 바로가기 #time_square
# 쇼핑캐스트 바로가기 #shp_cst
# 로그인 바로가기 #account
# 네이버 /
# 네이버를 시작페이지로 http://help.naver.com/support/alias/contents2/naverhome/naverhome_1.naver
# 쥬니어네이버 http://jr.naver.com
# 해피빈 http://happybean.naver.com/main/SectionMain.nhn
# 자동완성 펼치기 javascript:;
# 한글 입력기 javascript:;
# 도움말 보기 https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16658
# ON선택됨 #
# OFF #
# 로그인 https://nid.naver.com/nidlogin.login
# 자세히 https://help.naver.com/support/alias/search/word/word_16.naver
# 자세히 https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16659
# 도움말 https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# 신고 https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# 검색어저장 켜기 javascript:;
# 자동완성 끄기 javascript:;
# 도움말 https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# 신고 https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# 검색어저장 켜기 javascript:;
# 자동완성 끄기 javascript:;
# 도움말 https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# 신고 https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# 검색어저장 켜기 javascript:;
# 자동완성 끄기 javascript:;
# 도움말 https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# 신고 https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# 검색어저장 켜기 javascript:;
# 자동완성 켜기 javascript:;
# 최근검색어 javascript:;
# 내 검색어 javascript:;
# 내 검색어 등록 javascript:;
# @txt@ javascript:;
# 삭제 javascript:;
# 내 검색어 해제 javascript:;
# @txt@ javascript:;
# 기록 삭제 javascript:;
# 검색어저장 끄기 javascript:;
# 자동완성 끄기 javascript:;
# 기록 전체 삭제 javascript:;
# 완료 javascript:;
# 기록 전체 삭제 javascript:;
# 검색어저장 끄기 javascript:;
# 자동완성 끄기 javascript:;
# 닫기 javascript:;
# 자세히보기
# 메일 https://mail.naver.com/
# 카페 https://section.cafe.naver.com/
# 블로그 https://section.blog.naver.com/
# 지식인 https://kin.naver.com/
# 쇼핑 https://shopping.naver.com/
# 네이버페이 https://order.pay.naver.com/home
# 네이버TV https://tv.naver.com/
# 사전 https://dict.naver.com/
# 뉴스 https://news.naver.com/
# 증권(금융) https://finance.naver.com/
# 부동산 https://land.naver.com/
# 지도 https://map.naver.com/
# 영화 https://movie.naver.com/
# 뮤직 https://music.naver.com
# 책 https://book.naver.com/
# 만화 / 웹툰 https://comic.naver.com/
# 더보기 #
# 1
# 뉴트리코어 맥스크릴오일 #
# 2
# kb스타뱅킹 축하금 #
# 3
# kb스타뱅킹 #
# 4
# skt pass 5만원준다 해외주식 #
# 5
# 조국 구속 #
# 6
# 뉴트리코어 크릴오일 #
# 7
# 크레온 평생무료 #
# 8
# 맥스크릴오일 #
# 9
# 페이스팩토리 뷰티석션 #
# 10
# skt pass 5만원준다 #
# 11
# bgf리테일 채용 #
# 12
# 뉴트리코어 #
# 13
# 조국수호 검찰개혁 #
# 14
# skt pass 15만원준다카드 #
# 15
# 홍선영 #
# 16
# 류현진 #
# 17
# 황석영 #
# 18
# 여미휴게소 #
# 19
# skt pass #
# 20
# 19호 태풍 하기비스 #
# 1~10위 #
# 11~20위 #
# 1
# 뉴트리코어 맥스크릴오일 http://search.naver.com/search.naver?where=nexearch&query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&where=main
# 2
# kb스타뱅킹 축하금 http://search.naver.com/search.naver?where=nexearch&query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9+%EC%B6%95%ED%95%98%EA%B8%88&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9+%EC%B6%95%ED%95%98%EA%B8%88&where=main
# 3
# kb스타뱅킹 http://search.naver.com/search.naver?where=nexearch&query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=kb%EC%8A%A4%ED%83%80%EB%B1%85%ED%82%B9&where=main
# 4
# skt pass 5만원준다 해외주식 http://search.naver.com/search.naver?where=nexearch&query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4+%ED%95%B4%EC%99%B8%EC%A3%BC%EC%8B%9D&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4+%ED%95%B4%EC%99%B8%EC%A3%BC%EC%8B%9D&where=main
# 5
# 조국 구속 http://search.naver.com/search.naver?where=nexearch&query=%EC%A1%B0%EA%B5%AD+%EA%B5%AC%EC%86%8D&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%EC%A1%B0%EA%B5%AD+%EA%B5%AC%EC%86%8D&where=main
# 6
# 뉴트리코어 크릴오일 http://search.naver.com/search.naver?where=nexearch&query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4+%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&where=main
# 7
# 크레온 평생무료 http://search.naver.com/search.naver?where=nexearch&query=%ED%81%AC%EB%A0%88%EC%98%A8+%ED%8F%89%EC%83%9D%EB%AC%B4%EB%A3%8C&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%ED%81%AC%EB%A0%88%EC%98%A8+%ED%8F%89%EC%83%9D%EB%AC%B4%EB%A3%8C&where=main
# 8
# 맥스크릴오일 http://search.naver.com/search.naver?where=nexearch&query=%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A6%B4%EC%98%A4%EC%9D%BC&where=main
# 9
# 페이스팩토리 뷰티석션 http://search.naver.com/search.naver?where=nexearch&query=%ED%8E%98%EC%9D%B4%EC%8A%A4%ED%8C%A9%ED%86%A0%EB%A6%AC+%EB%B7%B0%ED%8B%B0%EC%84%9D%EC%85%98&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%ED%8E%98%EC%9D%B4%EC%8A%A4%ED%8C%A9%ED%86%A0%EB%A6%AC+%EB%B7%B0%ED%8B%B0%EC%84%9D%EC%85%98&where=main
# 10
# skt pass 5만원준다 http://search.naver.com/search.naver?where=nexearch&query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=skt+pass+5%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4&where=main
# 11
# bgf리테일 채용 http://search.naver.com/search.naver?where=nexearch&query=bgf%EB%A6%AC%ED%85%8C%EC%9D%BC+%EC%B1%84%EC%9A%A9&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=bgf%EB%A6%AC%ED%85%8C%EC%9D%BC+%EC%B1%84%EC%9A%A9&where=main
# 12
# 뉴트리코어 http://search.naver.com/search.naver?where=nexearch&query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%EB%89%B4%ED%8A%B8%EB%A6%AC%EC%BD%94%EC%96%B4&where=main
# 13
# 조국수호 검찰개혁 http://search.naver.com/search.naver?where=nexearch&query=%EC%A1%B0%EA%B5%AD%EC%88%98%ED%98%B8+%EA%B2%80%EC%B0%B0%EA%B0%9C%ED%98%81&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%EC%A1%B0%EA%B5%AD%EC%88%98%ED%98%B8+%EA%B2%80%EC%B0%B0%EA%B0%9C%ED%98%81&where=main
# 14
# skt pass 15만원준다카드 http://search.naver.com/search.naver?where=nexearch&query=skt+pass+15%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4%EC%B9%B4%EB%93%9C&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=skt+pass+15%EB%A7%8C%EC%9B%90%EC%A4%80%EB%8B%A4%EC%B9%B4%EB%93%9C&where=main
# 15
# 홍선영 http://search.naver.com/search.naver?where=nexearch&query=%ED%99%8D%EC%84%A0%EC%98%81&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%ED%99%8D%EC%84%A0%EC%98%81&where=main
# 16
# 류현진 http://search.naver.com/search.naver?where=nexearch&query=%EB%A5%98%ED%98%84%EC%A7%84&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%EB%A5%98%ED%98%84%EC%A7%84&where=main
# 17
# 황석영 http://search.naver.com/search.naver?where=nexearch&query=%ED%99%A9%EC%84%9D%EC%98%81&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%ED%99%A9%EC%84%9D%EC%98%81&where=main
# 18
# 여미휴게소 http://search.naver.com/search.naver?where=nexearch&query=%EC%97%AC%EB%AF%B8%ED%9C%B4%EA%B2%8C%EC%86%8C&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=%EC%97%AC%EB%AF%B8%ED%9C%B4%EA%B2%8C%EC%86%8C&where=main
# 19
# skt pass http://search.naver.com/search.naver?where=nexearch&query=skt+pass&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=skt+pass&where=main
# 20
# 19호 태풍 하기비스 http://search.naver.com/search.naver?where=nexearch&query=19%ED%98%B8+%ED%83%9C%ED%92%8D+%ED%95%98%EA%B8%B0%EB%B9%84%EC%8A%A4&sm=top_lve&ie=utf8
# 데이터랩 그래프 보기 http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-10-07T15:17:00&query=19%ED%98%B8+%ED%83%9C%ED%92%8D+%ED%95%98%EA%B8%B0%EB%B9%84%EC%8A%A4&where=main
# 도움말 http://help.naver.com/support/alias/search/word/word_5.naver
# DataLab.급상승 트래킹 http://datalab.naver.com/keyword/realtimeList.naver?where=main
# 연합뉴스 http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y
# 文대통령 "국민 목소리 엄중히 들어…대립의 골 바람직 않아" http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126895
# 검찰, 밤 9시 이후 심야조사 폐지…윤석열 3번째 개혁안 http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126607
# '수상한 집값' 부동산거래 대대적 조사…강남4구·마용성 '집중' http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126605
# 류현진 '다저스 살렸다'…5이닝 2실점 호투로 PS 통산 3승 http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126438
# 연매출 30억미만 온라인사업자에 최대 1억원, 2%대 대출 http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126613
# 화성 8차 사건 범인,  "고문당해 자백" 항소했다가 기각 http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126576
# 예견됐던 日단속선·北어선 '대화퇴' 충돌 http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126917
# 만취 10대에게 운전시킨 40대 구속기소 http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126916
# 미투 의혹 발끈 오거돈, 강용석 등 가로세로연구소 유튜버 고소 http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126667
# 타다, 택시와 상생안에 "회사 망하면 국가 배상문제 짚어야" http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011126923
# 네이버뉴스 http://news.naver.com/
# 연예 http://entertain.naver.com/home
# 스포츠 http://sports.news.naver.com/
# 경제 http://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101
# 뉴스스탠드 http://newsstand.naver.com/
# 전체 언론사 #
# MY 뉴스 #
# 이미지형 #
# 리스트형 #
# 설정 http://newsstand.naver.com/config.html
# 이전 페이지 #
# 다음 페이지 #
#  http://newsstand.naver.com/?list=ct1&pcode=079
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=079
#  http://newsstand.naver.com/?list=ct1&pcode=366
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=366
#  http://newsstand.naver.com/?list=ct1&pcode=904
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=904
#  http://newsstand.naver.com/?list=ct1&pcode=314
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=314
#  http://newsstand.naver.com/?list=ct1&pcode=015
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=015
#  http://newsstand.naver.com/?list=ct1&pcode=081
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=081
#  http://newsstand.naver.com/?list=ct1&pcode=008
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=008
#  http://newsstand.naver.com/?list=ct1&pcode=422
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=422
#  http://newsstand.naver.com/?list=ct1&pcode=003
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=003
#  http://newsstand.naver.com/?list=ct1&pcode=241
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=241
#  http://newsstand.naver.com/?list=ct1&pcode=327
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=327
#  http://newsstand.naver.com/?list=ct1&pcode=215
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct1&pcode=215
#  http://newsstand.naver.com/?list=ct2&pcode=960
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct2&pcode=960
#  http://newsstand.naver.com/?list=ct6&pcode=477
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct6&pcode=477
#  http://newsstand.naver.com/?list=ct3&pcode=902
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct3&pcode=902
#  http://newsstand.naver.com/?list=ct7&pcode=362
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct7&pcode=362
#  http://newsstand.naver.com/?list=ct2&pcode=417
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct2&pcode=417
#  http://newsstand.naver.com/?list=ct6&pcode=410
# 구독 #
# 해지 #
# 기사보기 http://newsstand.naver.com/?list=ct6&pcode=410
# 종합/경제 #
# 방송/통신 #
# IT #
# 영자지 #
# 스포츠/연예 #
# 매거진/전문지 #
# 지역 #
# 언론사 추가 http://newsstand.naver.com/config.html
# NAVER Sign in https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com
# Sign up https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com
# Username https://nid.naver.com/user/help.nhn?todo=idinquiry
# Password? https://nid.naver.com/nidreminder.form
# 10.07.(월) https://calendar.naver.com
# 앞의 목록으로 이동 #
# 뒤의 목록으로 이동 #
# 코스피
# 2021.77
# 1.08상승 http://finance.naver.com/sise/sise_index.nhn?code=KOSPI
# 코스닥
# 627.40
# 5.56상승 http://finance.naver.com/sise/sise_index.nhn?code=KOSDAQ
# 증권 http://finance.naver.com
# 오늘의 주요 시황뉴스 http://finance.naver.com/news/
#  #
# 리빙 #LIVINGHOME
# 푸드 #LIVING
# 스포츠 #SPORTS
# 자동차 #CARGAME
# 패션뷰티 #BEAUTY
# 부모i #MOMKIDS
# 건강 #HEALTH
# 웹툰 #BBOOM
# 게임 #GAMEAPP
# TV연예 #VIDEO
# 뮤직 #MUSIC
# 영화 #MOVIE
# 책문화 #CULTURE
# 함께N #WITH
# 여행+ #TRAVEL
# 디자인 #DESIGN
# 경제M #FINANCE
# JOB& #JOB
# 과학 #SCIENCE
# 중국 #CHINA
# 비즈니스 #BUSINESS
# FARM #FARM
# 스쿨잼 #SCHOOL
# 공연전시 #SHOW
# 법률 #LAW
# 동물공감 #ANIMAL
# 연애·결혼 #WEDDING
# 테크 #ITTECH
# 감성충전 #EMOTION
# 이전 주제 #
# 다음 주제 #
# 전체 주제 열기 #
# 전체 주제 목록 닫기 #
# 관심주제 설정 #
# 모바일 관심 주제 가져오기 #
# 취소 #
# 확인 #
# 초기화 #
# 전체선택 #
# 모바일 관심 주제 가져오기 #
# 그라폴리오 https://www.grafolio.com/
# 배경화면 https://www.grafolio.com/wallpaper.grfl
# 콜라보레이션 http://www.grafolio.com/collaboration/list.grfl
# 후원 https://www.grafolio.com/patron/creatorList.grfl
# 공식 블로그 https://blog.naver.com/nv_emotion
# 심플 라이프
# 바람과 커피, 그리고 귀뚜라미가 함께하는 가을밤 https://www.grafolio.com/story/27829?mainPjtNo=1006334
# 매 순간 느끼는 다양한 감정들과 생각들을 그립니다 https://www.grafolio.com/story/38649
# 그 시절 유행하던 오버핏(?) 점퍼를 입고 찰칵! https://www.grafolio.com/works/1009064
# 그곳에 가면 보고 싶은 그대 만날 수 있을까 https://www.grafolio.com/works/1011835
# ëìì
#
#
# 청소년 작곡가가 트와이스를 위해 만든 노래 https://www.grafolio.com/works/993165
# 빗물 머금은 바닥에 비치는 주홍 불빛들 https://www.grafolio.com/works/1015337
# 콘크리트와 식물, 조명이 만나 아늑함을 자아내는 공간 https://blog.naver.com/sasabana/221658389841
# 클래식한 포장으로 졸업식 느낌나는 장미 꽃다발 https://blog.naver.com/cmj10243/221556320030
# 아이들 간식으로 준비한 학창시절 추억의 '파르페' https://blog.naver.com/gentle0293/221659033345
# 이슬람&가톨릭 문화권이 공존하는 독특한 도시 https://blog.naver.com/hloveh01/221662451845
#  https://www.grafolio.com/works/655557
# 우주의 어느 행성 위 우리 둘 https://www.grafolio.com/works/655557
#  https://www.grafolio.com/works/997574
# 언제나 네 마음에 귀 기울일게 https://www.grafolio.com/works/997574
#  https://www.grafolio.com/works/15184
# 나는 날아 올라, 그대와 함께 있을 때면 https://www.grafolio.com/works/15184
#  https://www.grafolio.com/works/124422
# 행운을 주는 열쇠고리에요! https://www.grafolio.com/works/124422
# https://castbox.shopping.naver.com/shopbox/main.nhn? https://castbox.shopping.naver.com/shopbox/main.nhn?
# 소상공인 온라인마켓
# 작은가게 오래가게
# 입소문난 유명한가게를 만나보세요! https://shopping.naver.com/plan2/p/detail.nhn?seq=356908
# 해피빈 더블기부
# 두 배로 기부해요!
# 태풍이 할퀴고 간 뒤,슬픔에 빠진 이웃들 https://happybean.naver.com/doubleproject/201910
# 공지사항 //www.naver.com/NOTICE
# 서비스 전체보기 more.html
# 바로가기 https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83
# 프로젝트 꽃 https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83
# 다운받기 http://whale.naver.com/
# 네이버웨일 http://whale.naver.com/
# 크리에이터 https://www.navercorp.com/service/creators
# 스몰비즈니스 https://www.navercorp.com/service/business
# 비즈니스 · 광고 https://business.naver.com/service.html
# 스토어 개설 https://sell.storefarm.naver.com/#/home/about
# 지역업체 등록 https://smartplace.naver.com/
# 네이버 개발자센터 https://developers.naver.com
# 오픈 API https://developers.naver.com/docs/common/openapiguide/#/apilist.md/
# 오픈소스 https://naver.github.io/
# 네이버 D2 https://d2.naver.com/
# 네이버 랩스 https://www.naverlabs.com/
# 회사소개 https://www.navercorp.com/
# 인재채용 https://recruit.navercorp.com/naver/recruitMain
# 제휴제안 https://www.navercorp.com/naver/proposalGuide
# 이용약관 /policy/service.html
# 개인정보처리방침 /policy/privacy.html
# 청소년보호정책 /policy/youthpolicy.html
# 네이버 정책 /policy/spamcheck.html
# 고객센터 https://help.naver.com/
# NAVER Corp. https://www.navercorp.com/
