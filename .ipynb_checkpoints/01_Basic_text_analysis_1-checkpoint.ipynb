# %%
from konlpy.tag import Hannanum
from pprint import pprint
import nltk

# %%
doc = open('final_announcement_for_Park.txt', 'r', encoding='utf-8').read()

# print(doc)

# %% [markdown]
# ### tokenizing이란? </b>
# 주어진 문서나 문장을 기본 단어 기준으로 나누는 작업 </b>
# ### Part -of-speech tagging </b>
# 품사를 판단해서 나눔 POS tagging이라 함

# %%
# Hannanum package
pos_tagger = Hannanum()

# list comprehension, for loop가 빨라짐, 간결한 표현
pos = ['/'.join(t) for t in pos_tagger.pos(doc)] # 형태소로 tokenizing

# 뉴스를 tokenizing한 후, 명사만 추출
pos_nouns = ['/'.join(t) for t in pos_tagger.pos(doc) if t[1]=='N']

# list 원소 중 10개를 살펴보기
pprint(pos[0:10])

# list 원소 모두 출력
pprint(pos_nouns[0:10])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)
# ['지금/N',
#  '부터/J',
#  '2016헌나1/N',
#  '대통령/N',
#  '박근혜/N',
#  '탄핵사건/N',
#  '에/J',
#  '대하/P',
#  'ㄴ/E',
#  '선고/N']
# ['지금/N',
#  '2016헌나1/N',
#  '대통령/N',
#  '박근혜/N',
#  '탄핵사건/N',
#  '선고/N',
#  '시작/N',
#  '선고/N',
#  '사건/N',
#  '진행경과/N']

# %%
# 형태소 분석과 전처리 과정만 끝난다면 nltk와 scikit learn을 예전과 동일한 방법으로 사용할 수 있습니다.

# Text() - 단일 문서에 대한 탐색에 좋은 함수가 내장
text = nltk.Text(pos_nouns) # 형태소 분석이 된 list를 input으로 넣어주면

# %%
text
# Out:
# <Text: 지금/N 2016헌나1/N 대통령/N 박근혜/N 탄핵사건/N 선고/N 시작/N 선고/N...>

# %%
text.tokens
# Out:
# ['지금/N',
#  '2016헌나1/N',
#  '대통령/N',
#  '박근혜/N',
#  '탄핵사건/N',
#  '선고/N',
#  '시작/N',
#  '선고/N',
#  '사건/N',
#  '진행경과/N',
#  '저희/N',
#  '재판관들/N',
#  '90/N',
#  '동안/N',
#  '사건/N',
#  '공정/N',
#  '신속/N',
#  '해결/N',
#  '힘/N',
#  '지금/N',
#  '대한민국/N',
#  '국민들/N',
#  '번민/N',
#  '고뇌/N',
#  '시간/N',
#  '생각/N',
#  '저희/N',
#  '재판관들/N',
#  '사건/N',
#  '재판소/N',
#  '접수/N',
#  '해/N',
#  '12/N',
#  '9./N',
#  '이후/N',
#  '오늘/N',
#  '휴일/N',
#  '제외/N',
#  '60/N',
#  '매일/N',
#  '재판관/N',
#  '평의/N',
#  '진행/N',
#  '재판과정/N',
#  '중/N',
#  '진행/N',
#  '결정/N',
#  '재판관/N',
#  '전원/N',
#  '논의/N',
#  '사항/N',
#  '저희/N',
#  '그간/N',
#  '3차례/N',
#  '준비기일/N',
#  '17차례/N',
#  '변론기일/N',
#  '청구인/N',
#  '증거/N',
#  '갑/N',
#  '제174호증/N',
#  '서증/N',
#  '열두/N',
#  '명/N',
#  '증/N',
#  '5건/N',
#  '문서송부촉탁결정/N',
#  '1건/N',
#  '사실조회결정/N',
#  '피청구인/N',
#  '증거인/N',
#  '제60호증/N',
#  '서증/N',
#  '열일곱/N',
#  '명/N',
#  '증인(안종범/N',
#  '중복/N',
#  '17명/N',
#  '6건/N',
#  '문서송부촉탁결정/N',
#  '68건/N',
#  '사실조회결정/N',
#  '증거조사/N',
#  '소추위원/N',
#  '양쪽/N',
#  '대리인들/N',
#  '변론/N',
#  '경청/N',
#  '증거조사/N',
#  '자료/N',
#  '48,000/N',
#  '쪽/N',
#  '당사자/N',
#  '이외/N',
#  '들/N',
#  '제출/N',
#  '탄원서/N',
#  '등/N',
#  '자료들/N',
#  '40박스/N',
#  '분량/N',
#  '대한민국/N',
#  '국민/N',
#  '헌법/N',
#  '대통령/N',
#  '포함/N',
#  '국가기관/N',
#  '존립근거/N',
#  '국민/N',
#  '헌법/N',
#  '내/N',
#  '힘/N',
#  '원천/N',
#  '재판부/N',
#  '점/N',
#  '인식하/N',
#  '역사/N',
#  '법정/N',
#  '앞/N',
#  '당사자/N',
#  '심정/N',
#  '선고/N',
#  '저희/N',
#  '재판부/N',
#  '국민들/N',
#  '부/N',
#  '권한/N',
#  '오늘/N',
#  '선고/N',
#  '이상/N',
#  '국론분열/N',
#  '혼란/N',
#  '종식/N',
#  '경우/N',
#  '법치주의/N',
#  '우리/N',
#  '모두/N',
#  '가치/N',
#  '생각/N',
#  '지금/N',
#  '선고/N',
#  '시작/N',
#  '먼저,/N',
#  '사건/N',
#  '탄핵소추안/N',
#  '가결절차/N',
#  '관련하/N',
#  '흠결/N',
#  '소추의결서/N',
#  '기재/N',
#  '소추사실/N',
#  '구체적/N',
#  '특정/N',
#  '점/N',
#  '헌법상/N',
#  '탄핵소추사유/N',
#  '공무원/N',
#  '직무집행/N',
#  '헌법/N',
#  '법률/N',
#  '위배/N',
#  '사실/N',
#  '여기/N',
#  '법률/N',
#  '형사법/N',
#  '한정/N',
#  '탄핵결정/N',
#  '대상자/N',
#  '공직/N',
#  '파면/N',
#  '것/N',
#  '형사상/N',
#  '책/N',
#  '것/N',
#  '피청구인/N',
#  '방어권/N',
#  '행사/N',
#  '수/N',
#  '심판대상/N',
#  '확정/N',
#  '수/N',
#  '정도/N',
#  '사실관계/N',
#  '기재/N',
#  '사건/N',
#  '소추의결/N',
#  '헌법/N',
#  '위배행위/N',
#  '부분/N',
#  '분명/N',
#  '유형별/N',
#  '구분/N',
#  '측면/N',
#  '법률/N',
#  '위배행위/N',
#  '부분/N',
#  '종합/N',
#  '소추사유/N',
#  '특정/N',
#  '수/N',
#  '다음/N',
#  '사건/N',
#  '탄핵소추안/N',
#  '의결/N',
#  '당시/N',
#  '국회/N',
#  '법사위/N',
#  '조사/N',
#  '공소장/N',
#  '신문기사/N',
#  '정도/N',
#  '증거/N',
#  '제시/N',
#  '점/N',
#  '국회/N',
#  '의사절차/N',
#  '자율권/N',
#  '권력분립/N',
#  '원칙상/N',
#  '존중/N',
#  '국회법/N',
#  '탄핵소추발의시/N',
#  '사유조사/N',
#  '여부/N',
#  '국회/N',
#  '재량/N',
#  '규정하/N',
#  '의결/N',
#  '헌법/N',
#  '법률/N',
#  '위배/N',
#  '것/N',
#  '수/N',
#  '다음/N',
#  '사건/N',
#  '소추의결/N',
#  '토론/N',
#  '진행/N',
#  '점/N',
#  '의결/N',
#  '당시/N',
#  '상황/N',
#  '토론/N',
#  '표결/N',
#  '것/N',
#  '사실/N',
#  '국회법상/N',
#  '토론/N',
#  '규정/N',
#  '찬성/N',
#  '반대/N',
#  '뜻/N',
#  '국회의장/N',
#  '통지/N',
#  '토론/N',
#  '수/N',
#  '당시/N',
#  '토론/N',
#  '희망한/N',
#  '의원/N',
#  '사람/N',
#  '국회의장/N',
#  '토론/N',
#  '희망/N',
#  '사실/N',
#  '탄핵사유/N',
#  '개별/N',
#  '사유별/N',
#  '의결절차/N',
#  '개/N',
#  '탄핵사유/N',
#  '전체/N',
#  '일괄/N',
#  '의결/N',
#  '것/N',
#  '위법/N',
#  '점/N',
#  '소추사유/N',
#  '개/N',
#  '경우/N',
#  '사유별/N',
#  '표결할/N',
#  '것/N',
#  '사유/N',
#  '하나/N',
#  '소추안/N',
#  '표결할/N',
#  '것/N',
#  '소추안/N',
#  '발의/N',
#  '국회의원/N',
#  '자유로운/N',
#  '의사/N',
#  '것/N',
#  '표결방법/N',
#  '명문규정/N',
#  '8/N',
#  '재판관/N',
#  '선고/N',
#  '9인/N',
#  '구성/N',
#  '재판부/N',
#  '공정한/N',
#  '재판/N',
#  '권리/N',
#  '침해/N',
#  '점/N',
#  '헌법재판소/N',
#  '헌법상/N',
#  '아홉/N',
#  '명/N',
#  '재판관/N',
#  '구성/N',
#  '현실적/N',
#  '재판관/N',
#  '공무상/N',
#  '출장/N',
#  '질병/N',
#  '재판관/N',
#  '퇴/N',
#  '이후/N',
#  '후임재판관/N',
#  '임명/N',
#  '사이/N',
#  '공백/N',
#  '등/N',
#  '가지/N',
#  '사유/N',
#  '일부/N',
#  '재판관/N',
#  '재판/N',
#  '관여/N',
#  '수/N',
#  '경우/N',
#  '발생/N',
#  '수/N',
#  '헌법/N',
#  '법률/N',
#  '경우/N',
#  '대비한/N',
#  '규정/N',
#  '마련/N',
#  '탄핵/N',
#  '결정/N',
#  '때/N',
#  '재판관/N',
#  '6/N',
#  '이상/N',
#  '찬성/N',
#  '재판관/N',
#  '7/N',
#  '이상/N',
#  '출석/N',
#  '사건/N',
#  '심리/N',
#  '규정하/N',
#  '아홉명/N',
#  '재판관/N',
#  '참석/N',
#  '상태/N',
#  '재판/N',
#  '수/N',
#  '때/N',
#  '주장/N',
#  '현재/N',
#  '대통령/N',
#  '권한대행/N',
#  '헌법재판소장/N',
#  '임명/N',
#  '수/N',
#  '논란/N',
#  '상황/N',
#  '심리/N',
#  '주장/N',
#  '탄핵소추/N',
#  '대통령의/N',
#  '권한정지상태/N',
#  '헌정위/N',
#  '상황/N',
#  '방치/N',
#  '결과/N',
#  '여덟/N',
#  '명/N',
#  '재판관/N',
#  '사건/N',
#  '심리/N',
#  '결정/N',
#  '데/N',
#  '헌법/N',
#  '법률상/N',
#  '문제/N',
#  '이상/N',
#  '헌법재판소로/N',
#  '헌정위/N',
#  '상황/N',
#  '계속/N',
#  '방치/N',
#  '수/N',
#  '국회/N',
#  '탄핵소추가결/N',
#  '절차/N',
#  '헌법/N',
#  '법률/N',
#  '위배/N',
#  '위법/N',
#  '적법요건/N',
#  '흠결/N',
#  '탄핵사유/N',
#  '탄핵사유별/N',
#  '피청구인/N',
#  '직무집행/N',
#  '헌법/N',
#  '법률/N',
#  '위배/N',
#  '공무원/N',
#  '임면권/N',
#  '남용/N',
#  '직업공무원제도/N',
#  '본질/N',
#  '침해/N',
#  '점/N',
#  '문화체육관광부/N',
#  '노/N',
#  '국장/N',
#  '과장/N',
#  '피청구인/N',
#  '지시/N',
#  '문책성/N',
#  '인사/N',
#  '노/N',
#  '국장/N',
#  '명예퇴직/N',
#  '장관/N',
#  '유진룡/N',
#  '면직/N',
#  '대통령비서실장/N',
#  '김기춘/N',
#  '제1차관에/N',
#  '지시/N',
#  '1급/N',
#  '공무원/N',
#  '여섯/N',
#  '명/N',
#  '사직서/N',
#  '제출/N',
#  '중/N',
#  '세/N',
#  '명/N',
#  '사직서/N',
#  '수리/N',
#  '사실/N',
#  '인정/N',
#  '사건/N',
#  '증거/N',
#  '종합/N',
#  '피청구인/N',
#  '노/N',
#  '국장/N',
#  '과장/N',
#  '최서원/N',
#  '사익/N',
#  '추구/N',
#  '방해/N',
#  '때문/N',
#  '인사/N',
#  '인정/N',
#  '부족/N',
#  '유진룡/N',
#  '면직/N',
#  '이유/N',
#  '김기춘/N',
#  '여섯/N',
#  '명/N',
#  '1급/N',
#  '공무원/N',
#  '사직서/N',
#  '제출/N',
#  '이유/N',
#  '분명/N',
#  '언론/N',
#  '자유/N',
#  '침해/N',
#  '점/N',
#  '청구인/N',
#  '피청구인/N',
#  '압력/N',
#  '행사/N',
#  '세계일보/N',
#  '사장/N',
#  '해임/N',
#  '주장/N',
#  '세계일보/N',
#  '청와대/N',
#  '민정수석비서관실/N',
#  '작성/N',
#  '정윤회/N',
#  '문건/N',
#  '보도/N',
#  '사실/N',
#  '피청구인/N',
#  '보도/N',
#  '청와대/N',
#  '문건/N',
#  '외부유출/N',
#  '국기문/N',
#  '행위/N',
#  '검찰/N',
#  '철저/N',
#  '수사/N',
#  '진실/N',
#  '문건/N',
#  '유출/N',
#  '비난/N',
#  '사실/N',
#  '인정/N',
#  '사건/N',
#  '증거/N',
#  '종합/N',
#  '세계일보/N',
#  '구체적/N',
#  '누구/N',
#  '압력/N',
#  '행사/N',
#  '분명/N',
#  '피청구인/N',
#  '관여/N',
#  '인정/N',
#  '만한/N',
#  '증거/N',
#  '다음/N',
#  '세월호사건/N',
#  '생명권/N',
#  '보호의무/N',
#  '직책성실의무/N',
#  '위반/N',
#  '점/N',
#  '2014/N',
#  '4./N',
#  '16/N',
#  '세월호/N',
#  '침몰/N',
#  '304명/N',
#  '희생/N',
#  '참사/N',
#  '발생/N',
#  '당시/N',
#  '피청구인/N',
#  '관저/N',
#  '헌법/N',
#  '국가/N',
#  '개인/N',
#  '불가침/N',
#  '기본적/N',
#  '인권/N',
#  '확인/N',
#  '이/N',
#  '보장/N',
#  '의무/N',
#  '규정하/N',
#  '세월호/N',
#  '침몰사건/N',
#  '국민들/N',
#  '충격/N',
#  '고통/N',
#  '참사/N',
#  '점/N',
#  '말/N',
#  '희생자들/N',
#  '위로/N',
#  '부족/N',
#  '것/N',
#  '피청구인/N',
#  '국가/N',
#  '국민/N',
#  '생명/N',
#  '신체/N',
#  '전/N',
#  '보호의무/N',
#  '충실/N',
#  '이행/N',
#  '수/N',
#  '권한/N',
#  '행사/N',
#  '직책/N',
#  '수행/N',
#  '의무/N',
#  '부담/N',
#  '국민/N',
#  '생명/N',
#  '위협/N',
#  '재난상황/N',
#  '발생/N',
#  '피청구인/N',
#  '구조/N',
#  '활동/N',
#  '참여/N',
#  '등/N',
#  '구체적/N',
#  '특정/N',
#  '행위의무/N',
#  '발생/N',
#  '피청구인/N',
#  '헌법상/N',
#  '대통령/N',
#  '직책/N',
#  '수행/N',
#  '의무/N',
#  '부담/N',
#  '성실/N',
#  '개념/N',
#  '상대적/N',
#  '추상적/N',
#  '성실/N',
#  '직책수행의무/N',
#  '추상적/N',
#  '의무규정/N',
#  '위반/N',
#  '이유/N',
#  '탄핵소추/N',
#  '것/N',
#  '점/N',
#  '헌법재판소/N',
#  '이미,/N',
#  '대통령의/N',
#  '성실/N',
#  '직책수행의무/N',
#  '규범적/N',
#  '이행/N',
#  '관철/N',
#  '수/N',
#  '원칙적/N',
#  '사법적/N',
#  '판단/N',
#  '대상/N',
#  '수/N',
#  '정치적/N',
#  '무능력/N',
#  '정책결정상/N',
#  '잘못/N',
#  '등/N',
#  '직책수행/N',
#  '성실성/N',
#  '여부/N',
#  '자체/N',
#  '소추사유/N',
#  '수/N',
#  '세월호/N',
#  '참혹/N',
#  '그/N',
#  '세월호/N',
#  '참사/N',
#  '당/N',
#  '피청구인/N',
#  '직책/N',
#  '수행/N',
#  '여부/N',
#  '탄핵심판절차/N',
#  '판단대상/N',
#  '것/N',
#  '지금/N',
#  '피청구인/N',
#  '최서원/N',
#  '국정개입/N',
#  '허용/N',
#  '권한남용/N',
#  '피청구인/N',
#  '서류/N',
#  '대부분/N',
#  '부속비서관/N',
#  '정호성/N',
#  '피청구인/N',
#  '전달/N',
#  '정호성/N',
#  '2013년/N',
#  '1월/N',
#  '2016년/N',
#  '4월/N',
#  '각종/N',
#  '인사자료/N',
#  '국무회의자료/N',
#  '대통령/N',
#  '해외순방일정/N',
#  '미국/N',
#  '국무부장관/N',
#  '접견자료/N',
#  '등/N',
#  '공무상/N',
#  '비밀/N',
#  '문건/N',
#  '최서원에/N',
#  '전달/N',
#  '최서원은/N',
#  '문건/N',
#  '이/N',
#  '의견/N',
#  '내용/N',
#  '수정하기/N',
#  '피청구인/N',
#  '일정/N',
#  '조정/N',
#  '등/N',
#  '직무활동/N',
#  '관여/N',
#  '최서원/N',
#  '공직/N',
#  '후보자/N',
#  '추천/N',
#  '중/N',
#  '일부/N',
#  '최서원/N',
#  '이권/N',
#  '추구/N',
#  '피청구인/N',
#  '최서원으로부터/N',
#  '케이디코퍼레이션/N',
#  '자동차/N',
#  '부품회사/N',
#  '대기업/N',
#  '납품/N',
#  '부탁/N',
#  '안종범/N',
#  '현대자동차그룹/N',
#  '거래/N',
#  '부탁/N',
#  '피청구인/N',
#  '안종범에/N',
#  '문화/N',
#  '체육/N',
#  '관련/N',
#  '재단법인/N',
#  '설립/N',
#  '지시/N',
#  '대기업들/N',
#  '486억/N',
#  '원/N',
#  '출연/N',
#  '재단법/N',
#  '미르,/N',
#  '288억/N',
#  '원/N',
#  '출연/N',
#  '재단법/N',
#  '케이스포츠/N',
#  '설립/N',
#  '두/N',
#  '재단법인/N',
#  '임직원/N',
#  '임면/N',
#  '사업/N',
#  '추진/N',
#  '자금/N',
#  '집행/N',
#  '업무/N',
#  '지시/N',
#  '등/N',
#  '운영/N',
#  '의사결정/N',
#  '피청구인/N',
#  '최서원/N',
#  '재단법인/N',
#  '출연/N',
#  '기업들/N',
#  '관여/N',
#  '최서원/N',
#  '미르/N',
#  '설립/N',
#  '직전/N',
#  '광고회사/N',
#  '플레이그라운드/N',
#  '설립/N',
#  '운영/N',
#  '최서원/N',
#  '자신/N',
#  '추천/N',
#  '임원/N',
#  '미르/N',
#  '장악하/N',
#  '자신/N',
#  '회사/N',
#  '플레이그라운드/N',
#  '용역계약/N',
#  '체결/N',
#  '이익/N',
#  '최서원/N',
#  '요청/N',
#  '피청구인/N',
#  '안종범/N',
#  '케이티/N',
#  '특정인/N',
#  '2명/N',
#  '채용/N',
#  '뒤/N',
#  '광고/N',
#  '관련/N',
#  '업무/N',
#  '담당/N',
#  '요구/N',
#  '뒤/N',
#  '플레이그라운드/N',
#  '케이티/N',
#  '광고대행사/N',
#  '선정/N',
#  '케이티/N',
#  '68억/N',
#  '원/N',
#  '광고/N',
#  '수주/N',
#  '안종범/N',
#  '피청구인/N',
#  '지시/N',
#  '현대자동차그룹/N',
#  '플레이그라운드/N',
#  '소개자료/N',
#  '전달/N',
#  '현대/N',
#  '기아자동차/N',
#  '신생/N',
#  '광고회사/N',
#  '플레이그라운드/N',
#  '9억/N',
#  '원/N',
#  '광고/N',
#  '발주/N',
#  '한편/N',
#  '최서원/N',
#  '케이스포츠/N',
#  '설립/N',
#  '하루/N',
#  '전/N',
#  '더블루케이/N',
#  '설립/N',
#  '운영/N',
#  '최서원/N',
#  '노승일/N',
#  '박헌영/N',
#  '케이스포츠/N',
#  '직원/N',
#  '채용/N',
#  '더블루케이/N',
#  '업무협약/N',
#  '체결/N',
#  '피청구인/N',
#  '안종범/N',
#  '그랜드코리아레저/N',
#  '포스코/N',
#  '스포츠팀/N',
#  '창단하/N',
#  '더블루케이/N',
#  '스포츠팀/N',
#  '소속/N',
#  '수/N',
#  '에이전트/N',
#  '운영/N',
#  '최서원/N',
#  '문화체육관광부/N',
#  '제2차관/N',
#  '김종/N',
#  '지역/N',
#  '스포츠클럽/N',
#  '전면/N',
#  '개편/N',
#  '문화체육관광부/N',
#  '내부/N',
#  '문건/N',
#  '전달/N',
#  '케이스포츠/N',
#  '이/N',
#  '관여/N',
#  '더블루케이/N',
#  '이득/N',
#  '방안/N',
#  '마련/N',
#  '피청구인/N',
#  '롯데그룹/N',
#  '회장/N',
#  '독대하/N',
#  '5대/N',
#  '거점/N',
#  '체육인재/N',
#  '육성/N',
#  '사업/N',
#  '관련해/N',
#  '하남시/N',
#  '체육시설/N',
#  '건립/N',
#  '자금/N',
#  '지원/N',
#  '요구/N',
#  '롯데/N',
#  '케이스포츠/N',
#  '70억/N',
#  '원/N',
#  '송금/N',
#  '다음/N',
#  '피청구인/N',
#  '행위/N',
#  '헌법/N',
#  '법률/N',
#  '위배/N',
#  '지/N',
#  '헌법/N',
#  '공무원/N',
#  '‘국민/N',
#  '전체/N',
#  '봉사자’/N',
#  '규정하/N',
#  '공무원/N',
#  '공익실현의무/N',
#  '천명/N',
#  '의무/N',
#  '국가공무원법/N',
#  '공직자윤리법/N',
#  '등/N',
#  '구체화/N',
#  '피청구인/N',
#  '행위/N',
#  '최서원/N',
#  '이익/N',
#  '대통령의/N',
#  '지위/N',
#  '권한/N',
#  '남용/N',
#  '것/N',
#  '공정한/N',
#  '직무수행/N',
#  '수/N',
#  '헌법/N',
#  '국가공무원법/N',
#  '공직자윤리법/N',
#  '등/N',
#  '위배/N',
#  '것/N',
#  '재단법/N',
#  '미르/N',
#  '케이스포츠/N',
#  '설립/N',
#  '최성원/N',
#  '이권/N',
#  '개입/N',
#  '직/N',
#  '간접적/N',
#  '도움/N',
#  '피청구인/N',
#  '행위/N',
#  '기업/N',
#  '재산권/N',
#  '침해/N',
#  '뿐/N',
#  '기업경영/N',
#  '자유/N',
#  '침해/N',
#  '것/N',
#  '피청구인/N',
#  '지시/N',
#  '방치/N',
#  '직무상/N',
#  '비밀/N',
#  '해당/N',
#  '문건/N',
#  '최서원에/N',
#  '유출/N',
#  '점/N',
#  '국가공무원법/N',
#  '비밀엄수의무/N',
#  '위배/N',
#  '것/N',
#  '지금/N',
#  '피청구인/N',
#  '법위반/N',
#  '행위/N',
#  '피청구인/N',
#  '파면/N',
#  '만큼/N',
#  '중대한/N',
#  '것/N',
#  '지/N',
#  '대통령/N',
#  '헌법/N',
#  '법률/N',
#  '권한/N',
#  '행사/N',
#  '물론/N',
#  '공무/N',
#  '수행/N',
#  '투명/N',
#  '공개/N',
#  '국민/N',
#  '평가/N',
#  '피청구인/N',
#  '최서원/N',
#  '국정개입사실/N',
#  '그/N',
#  '의혹/N',
#  '제기/N',
#  '때/N',
#  '이/N',
#  '부인/N',
#  '의혹/N',
#  '제/N',
#  '비난/N',
#  ...]

# %%
len(set(text.tokens))
# Out:
# 639

# %%
text.vocab() # 겹치는 단어들 개수 세어주기
# Out:
# FreqDist({'피청구인/N': 45, '것/N': 20, '수/N': 19, '헌법/N': 16, '재판관/N': 15, '최서원/N': 14, '사건/N': 13, '등/N': 12, '점/N': 12, '법률/N': 10, ...})

# %%
text.vocab().most_common(20)
# Out:
# [('피청구인/N', 45),
#  ('것/N', 20),
#  ('수/N', 19),
#  ('헌법/N', 16),
#  ('재판관/N', 15),
#  ('최서원/N', 14),
#  ('사건/N', 13),
#  ('등/N', 12),
#  ('점/N', 12),
#  ('법률/N', 10),
#  ('선고/N', 8),
#  ('설립/N', 8),
#  ('대통령/N', 7),
#  ('명/N', 7),
#  ('국민/N', 7),
#  ('위배/N', 7),
#  ('사실/N', 7),
#  ('지시/N', 7),
#  ('문건/N', 7),
#  ('위반/N', 7)]

# %%
print("문서에 나온 토큰 수: ", len(text.tokens)) # 문서에서 나온 token 수
print("문서에 나온 토큰 종류 수:  ", len(set(text.tokens))) # 겹치지 않는 token 개수
pprint(text.vocab().most_common(20)) # 가장 빈번히 나온 token 나열
# Out:
# 문서에 나온 토큰 수:  1214
# 문서에 나온 토큰 종류 수:   639
# [('피청구인/N', 45),
#  ('것/N', 20),
#  ('수/N', 19),
#  ('헌법/N', 16),
#  ('재판관/N', 15),
#  ('최서원/N', 14),
#  ('사건/N', 13),
#  ('등/N', 12),
#  ('점/N', 12),
#  ('법률/N', 10),
#  ('선고/N', 8),
#  ('설립/N', 8),
#  ('대통령/N', 7),
#  ('명/N', 7),
#  ('국민/N', 7),
#  ('위배/N', 7),
#  ('사실/N', 7),
#  ('지시/N', 7),
#  ('문건/N', 7),
#  ('위반/N', 7)]

# %%
# font 문제가 있다면 먼저 실행
from matplotlib import font_manager, rc
#font_fname = 'c:/windows/fonts/gulim.ttc'     # A font of your choice
#font_fname = 'Malgun Gothic'
#font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family='Malgun Gothic')

# %%
# %matplotlib inline 
# 빈도 기준으로 token plot - distribution확인
text.plot(10)

# %%
# FreqDist 함수로도 같은 기능을 수행할 수 있다.
freq = nltk.FreqDist(text)
freq['것/Noun']
freq.most_common(10)
freq.plot(10)
