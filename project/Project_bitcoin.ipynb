# %%
import requests
from bs4 import BeautifulSoup
import time
from selenium import webdriver
driver = webdriver.Chrome()

# %%
# duration 설정
start_date = input()
close_date = input()
start_date = list(start_date.split(','))
close_date = list(close_date.split(','))
duration = '%2Ccd_min%3A{0}%2F{1}%2F{2}%2Ccd_max%3A{3}%2F{4}%2F{5}'.format(start_date[1], start_date[2], start_date[0], close_date[1], close_date[2], close_date[0])
base_url = 'https://www.google.com/search?q=bitcoin&biw=1005&bih=842&source=lnt&tbs=cdr%3A1'+ duration + '&tbm=nws'
print(base_url)
# Out:
# 2017,3,3
# 2017,4,3
# https://www.google.com/search?q=bitcoin&biw=1005&bih=842&source=lnt&tbs=cdr%3A1%2Ccd_min%3A3%2F3%2F2017%2Ccd_max%3A4%2F3%2F2017&tbm=nws

# %%
driver.get(base_url)

# %%
contents = driver.find_elements_by_css_selector\
("a.l.lLrAF" )
for i in contents:
    print(i.get_attribute('href'))
# Out:
# https://www.nasdaq.com/articles/why-bitcoin-worth-more-gold-2017-03-07
# https://www.vice.com/en_us/article/paz5vb/bitcoins-are-more-expensive-than-gold-now-thanks-china
# https://www.reuters.com/article/us-bitcoin-etp/sec-denies-a-second-application-to-list-bitcoin-product-idUSKBN16Z2HH
# https://www.businessinsider.com/bitcoin-price-spikes-as-japan-recognizes-it-as-a-legal-payment-method-2017-4
# https://www.businessinsider.com/bitcoin-price-plunges-suddenly-and-sharply-march-8-2017-2017-3
# https://www.businessinsider.com/bitcoin-price-charts-show-trouble-ahead-2017-3
# https://www.coindesk.com/report-bitcoin-social-media-scams-rise
# https://www.forbes.com/sites/panosmourdoukoutas/2017/03/04/bitcoin-is-better-than-gold/
# https://www.forbes.com/sites/laurashin/2017/03/21/is-this-massive-power-struggle-about-to-blow-up-bitcoin/
# https://qz.com/937312/bitcoin-btc-is-tearing-itself-apart-again-and-its-price-is-yo-yoing/

# %%
print(contents)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2acc546d169d9a2198c6d7572c8da0ac", element="64e4b63d-c7bd-494a-8064-f651c65407b4")>]

# %%
res = requests.get(base_url)
soup = BeautifulSoup(res.content, 'html.parser')
body = soup.body.find_all('div', class_='bkWMgd')
# body = soup.body.find_all('a', class_='l lLrAF')
url_list = []
# for i in body:
  #  url_list.append(body["href"])
# url = body.find_all('a', class_='l lLrAF')
print(soup.body)
# Out:
# <body jsmodel=" "><header id="hdr"><div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwiQrJLZuIXmAhVCE6YKHc-RCmsQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div><div class="bz1lBb"><form class="Pg70bf" id="sf"><input name="biw" type="hidden" value="1005"/><input name="bih" type="hidden" value="842"/><input name="ie" type="hidden" value="ISO-8859-1"/><input name="tbm" type="hidden" value="nws"/><div class="H0PQec"><div class="sbc esbc"><input autocapitalize="none" autocomplete="off" class="noHIxc" name="q" spellcheck="false" type="text" value="bitcoin"/><input name="oq" type="hidden"/><input name="aqs" type="hidden"/><div class="x">×</div><div class="sc"></div></div></div><button id="qdClwb" type="submit"></button></form></div><noscript><meta content="0;url=/search?q=bitcoin&amp;tbm=nws&amp;tbs=cdr:1,cd_min:5/4/2016,cd_max:8/4/2016&amp;biw=1
# ...
