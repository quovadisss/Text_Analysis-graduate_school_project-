# %%
# !pip install html5lib

# %%
import pandas as pd

# %% [markdown]
# ### 네이버 주식 - 엘지전자 페이지

# %%
id_list = ['035420','066570']

# %%
for id_ in id_list:
    base_url = "http://finance.naver.com/item/main.nhn?code="
    target_url = base_url + id_
    
    data = pd.read_html(target_url, encoding='cp949')
   
    print(target_url)
    print(data[2])
# Out:
# http://finance.naver.com/item/main.nhn?code=035420
#       날짜        종가         전일비       외국인        기관
# 0    NaN       NaN         NaN       NaN       NaN
# 1  11/20  169500.0   하향  1,000    -90629   +44,164
# 2  11/19  170500.0   하향  8,000   -216862   +42,553
# 3  11/18  178500.0   상향  5,000    -25139   +80,174
# 4  11/15  173500.0   하향  6,500   -373258  +279,381
# 5  11/14  180000.0  상향  22,000  +420,327  +110,870
# 6  11/13  158000.0   하향  4,000    -42323    +8,773
# 7    NaN       NaN         NaN       NaN       NaN
# http://finance.naver.com/item/main.nhn?code=066570
#       날짜       종가        전일비       외국인        기관
# 0    NaN      NaN        NaN       NaN       NaN
# 1  11/20  70900.0  하향  1,000    -76662   +24,800
# 2  11/19  71900.0    상향  400   +46,610   +68,715
# 3  11/18  71500.0  상향  1,000   +30,505  +156,146
# 4  11/15  70500.0  상향  1,500  +211,119  +176,718
# 5  11/14  69000.0    상향  200   +30,682   +24,495
# 6  11/13  68800.0    하향  200   +28,674    -48942
# 7    NaN      NaN        NaN       NaN       NaN

# %%
data
# Out:
# [                    0                                        1  \
#  0  전일  70,900  70,900  고가  71,30071,300  (상한가  92,10092,100  )
#  1    시가  70,70070,700        저가  70,00070,000  (하한가  49,700  )
#
#                          2
#  0   거래량  121,234  121,234
#  1  거래대금  8,553  8,553  백만  ,      매도상위      거래량    매수상위      거개량
#  0     NaN      NaN     NaN      NaN
#  1  미래에셋대우  17426.0     골드만  13582.0
#  2  신한금융투자   8089.0    키움증권  11911.0
#  3    키움증권   7960.0  미래에셋대우   8953.0
#  4    CS증권   6500.0      신영   6490.0
#  5  NH투자증권   5762.0   모건스탠리   5957.0
#  6  외국계추정합  13726.0  +9,903  23629.0,       날짜       종가        전일비       외국인        기관
#  0    NaN      NaN        NaN       NaN       NaN
#  1  11/20  70900.0  하향  1,000    -76662   +24,800
#  2  11/19  71900.0    상향  400   +46,610   +68,715
#  3  11/18  71500.0  상향  1,000   +30,505  +156,146
#  4  11/15  70500.0  상향  1,500  +211,119  +176,718
#  5  11/14  69000.0    상향  200   +30,682   +24,495
#  6  11/13  68800.0    하향  200   +28,674    -48942
#  7    NaN      NaN        NaN       NaN       NaN,        주요재무정보   최근 연간 실적                                    최근 분기 실적  \
#         주요재무정보    2016.12    2017.12    2018.12 2019.12(E)    2018.09
#         주요재무정보     IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
#  0         매출액  553670.00  613963.00  613417.00  626967.00  154270.00
#  1        영업이익   13378.00   24685.00   27033.00   26047.00    7488.00
#  2       당기순이익    1263.00   18695.00   14728.00   10756.00    4971.00
#  3       영업이익률       2.42       4.02       4.41       4.15       4.85
#  4        순이익률       0.23       3.05       2.40       1.72       3.22
#  5   ROE(지배주주)       0.65      13.69       9.03       6.02      10.90
#  6        부채비율     183.42     180.92     171.84        NaN     174.04
#  7        당좌비율      75.02      75.64      72.73        NaN      79.23
#  8         유보율    1344.52    1535.94    1658.84        NaN    1680.42
#  9      EPS(원)     425.00    9543.00    6858.00    4888.00    2270.00
#  10     PER(배)     121.37      11.11       9.08      14.51       8.42
#  11     BPS(원)   66571.00   73441.00   79156.00   83819.00   80378.00
#  12     PBR(배)       0.78       1.44       0.79       0.85       0.88
#  13   주당배당금(원)     400.00     400.00     750.00     799.00        NaN
#  14   시가배당률(%)       0.78       0.38       1.20        NaN        NaN
#  15    배당성향(%)      94.81       4.22      10.96        NaN        NaN
#
#
#        2018.12    2019.03    2019.06    2019.09 2019.12(E)
#         IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
#  0   157723.00  149151.00  156293.00  157006.00  164402.00
#  1      757.00    9006.00    6522.00    7815.00    2841.00
#  2     -807.00    5780.00    1060.00    3457.00    -697.00
#  3        0.48       6.04       4.17       4.98       1.73
#  4       -0.51       3.88       0.68       2.20      -0.42
#  5        9.03       7.59       6.16       4.94        NaN
#  6      171.84     171.18     168.31     170.50        NaN
#  7       72.73      75.14      76.67      76.77        NaN
#  8     1658.84    1701.01    1699.94    1722.72        NaN
#  9     -942.00    3157.00     507.00    1350.00    -569.00
#  10       9.08      12.41      15.89      16.55    -124.53
#  11   79156.00   82564.00   83454.00   84837.00   83819.00
#  12       0.79       0.91       0.95       0.79       0.85
#  13        NaN        NaN        NaN        NaN        NaN
#  14        NaN        NaN        NaN        NaN        NaN
#  15        NaN        NaN        NaN        NaN        NaN  ,            종목명 LG전자*066570 드림어스컴퍼니060570  삼본전자111870  아남전자008700  홈캐스트064240
#  0          현재가       70300          5280        3030        2085        4535
#  1         전일대비     하향  600       하향  220     하향  130      하향  70     하향  115
#  2          등락률  하향  -0.85%    하향  -4.00%  하향  -4.11%  하향  -3.25%  하향  -2.47%
#  3      시가총액(억)      115044          2972        1678        1608        1500
#  4     외국인비율(%)       33.97          4.26         .15        2.90        4.75
#  5       매출액(억)      157006           NaN         NaN         NaN         NaN
#  6      영업이익(억)        7815           NaN         NaN         NaN         NaN
#  7    조정영업이익(억)        7815           NaN         NaN         NaN         NaN
#  8   영업이익증가율(%)       19.81           NaN         NaN         NaN         NaN
#  9     당기순이익(억)        3457           NaN         NaN         NaN         NaN
#  10    주당순이익(원)     1350.27           NaN         NaN         NaN         NaN
#  11      ROE(%)        4.94           NaN         NaN         NaN         NaN
#  12      PER(%)       10.25        -12.57       51.36      -11.52       -7.27
#  13      PBR(배)         .89          1.84        1.61        2.93        1.91,           0               1
#  0      시가총액  11조  5,044  억원
#  1    시가총액순위         코스피 27위
#  2     상장주식수       163647814
#  3  액면가l매매단위   5,000원  l  1주,              0          1
#  0  외국인한도주식수(A)  163647814
#  1  외국인보유주식수(B)   55597167
#  2  외국인소진율(B/A)     33.97%,            0                  1
#  0  투자의견l목표주가  3.95매수  l  86,295
#  1   52주최고l최저  83,400  l  58,500,                   0                  1
#  0  PERlEPS(FnGuide)  10.25배  l  6,858원
#  1      PERlEPS(KRX)  10.22배  l  6,882원
#  2         추정PERlEPS  14.00배  l  4,888원
#  3  PBRlBPS(FnGuide)  0.89배  l  79,156원
#  4     배당수익률l2018.12              1.07%,           0       1
#  0  동일업종 PER  12.31배
#  1  동일업종 등락률  -1.06%,        매도잔량 호가(20분지연)     매수잔량
#  0       NaN       NaN      NaN
#  1    3356.0     71000      NaN
#  2    1934.0     70900      NaN
#  3     469.0     70800      NaN
#  4     817.0     70700      NaN
#  5     352.0     70600      NaN
#  6    1443.0     70500      NaN
#  7     332.0     70400      NaN
#  8     684.0     70300      NaN
#  9    1169.0     70200      NaN
#  10   2901.0     70100      NaN
#  11      NaN       NaN      NaN
#  12      NaN     70000    466.0
#  13      NaN     69900   2537.0
#  14      NaN     69800   5397.0
#  15      NaN     69700    842.0
#  16      NaN     69600   1518.0
#  17      NaN     69500   3223.0
#  18      NaN     69400   1093.0
#  19      NaN     69300    648.0
#  20      NaN     69200   1674.0
#  21      NaN     69100   1772.0
#  22      NaN       NaN      NaN
#  23  13457.0      잔량합계  19170.0,         업체명       거래량        전일비
#  0      삼성전자   51200.0    하향  800
#  1     남선알미늄    3330.0     상향  40
#  2        서원    1695.0    상향  235
#  3   아시아나IDT   28950.0  상향  3,250
#  4       필룩스    9590.0    하향  320
#  5       NaN       NaN        NaN
#  6       카카오  152500.0  하향  4,000
#  7      흥아해운     782.0     상향  64
#  8      셀트리온  180000.0  하향  4,500
#  9    아시아나항공    5770.0     상향  20
#  10   SK하이닉스   81200.0  하향  1,500,        업체명       거래량        전일비
#  0    에이치엘비  135300.0  하향  1,200
#  1   한류AI센터    1460.0   상한가  335
#  2      SDN    3080.0     상향  25
#  3    네오크레마   13250.0  상향  1,800
#  4     국일제지    6780.0    하향  200
#  5      NaN       NaN        NaN
#  6   루미마이크로    3050.0    하향  250
#  7    헬릭스미스   94900.0  하향  1,900
#  8      메지온  153300.0    상향  300
#  9      신라젠   17700.0    하향  450
#  10      빅텍    3645.0    상향  280]

# %%
lg = pd.read_html("http://finance.naver.com/item/main.nhn?code=066570", encoding='cp949')

# %%
type(lg)
# Out:
# list

# %%
len(lg)
# Out:
# 13

# %%
lg[0]
# Out:
#                     0                                        1  \
# 0  전일  70,900  70,900  고가  71,30071,300  (상한가  92,10092,100  )
# 1    시가  70,70070,700        저가  70,00070,000  (하한가  49,700  )
#
#                         2
# 0   거래량  121,358  121,358
# 1  거래대금  8,562  8,562  백만

# %%
type(lg[0])
# Out:
# pandas.core.frame.DataFrame

# %%
lg[1]
# Out:
#      매도상위      거래량    매수상위      거개량
# 0     NaN      NaN     NaN      NaN
# 1  미래에셋대우  17426.0     골드만  13582.0
# 2  신한금융투자   8089.0    키움증권  11911.0
# 3    키움증권   7960.0  미래에셋대우   8953.0
# 4    CS증권   6500.0      신영   6490.0
# 5  NH투자증권   5762.0   모건스탠리   5957.0
# 6  외국계추정합  13726.0  +9,903  23629.0

# %%
lg[2]
# Out:
#       날짜       종가        전일비       외국인        기관
# 0    NaN      NaN        NaN       NaN       NaN
# 1  11/20  70900.0  하향  1,000    -76662   +24,800
# 2  11/19  71900.0    상향  400   +46,610   +68,715
# 3  11/18  71500.0  상향  1,000   +30,505  +156,146
# 4  11/15  70500.0  상향  1,500  +211,119  +176,718
# 5  11/14  69000.0    상향  200   +30,682   +24,495
# 6  11/13  68800.0    하향  200   +28,674    -48942
# 7    NaN      NaN        NaN       NaN       NaN

# %%
lg[3]
# Out:
#        주요재무정보   최근 연간 실적                                    최근 분기 실적  \
#        주요재무정보    2016.12    2017.12    2018.12 2019.12(E)    2018.09
#        주요재무정보     IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
# 0         매출액  553670.00  613963.00  613417.00  626967.00  154270.00
# 1        영업이익   13378.00   24685.00   27033.00   26047.00    7488.00
# 2       당기순이익    1263.00   18695.00   14728.00   10756.00    4971.00
# 3       영업이익률       2.42       4.02       4.41       4.15       4.85
# 4        순이익률       0.23       3.05       2.40       1.72       3.22
# 5   ROE(지배주주)       0.65      13.69       9.03       6.02      10.90
# 6        부채비율     183.42     180.92     171.84        NaN     174.04
# 7        당좌비율      75.02      75.64      72.73        NaN      79.23
# 8         유보율    1344.52    1535.94    1658.84        NaN    1680.42
# 9      EPS(원)     425.00    9543.00    6858.00    4888.00    2270.00
# 10     PER(배)     121.37      11.11       9.08      14.51       8.42
# 11     BPS(원)   66571.00   73441.00   79156.00   83819.00   80378.00
# 12     PBR(배)       0.78       1.44       0.79       0.85       0.88
# 13   주당배당금(원)     400.00     400.00     750.00     799.00        NaN
# 14   시가배당률(%)       0.78       0.38       1.20        NaN        NaN
# 15    배당성향(%)      94.81       4.22      10.96        NaN        NaN
#
#
#       2018.12    2019.03    2019.06    2019.09 2019.12(E)
#        IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
# 0   157723.00  149151.00  156293.00  157006.00  164402.00
# 1      757.00    9006.00    6522.00    7815.00    2841.00
# 2     -807.00    5780.00    1060.00    3457.00    -697.00
# 3        0.48       6.04       4.17       4.98       1.73
# 4       -0.51       3.88       0.68       2.20      -0.42
# 5        9.03       7.59       6.16       4.94        NaN
# 6      171.84     171.18     168.31     170.50        NaN
# 7       72.73      75.14      76.67      76.77        NaN
# 8     1658.84    1701.01    1699.94    1722.72        NaN
# 9     -942.00    3157.00     507.00    1350.00    -569.00
# 10       9.08      12.41      15.89      16.55    -124.53
# 11   79156.00   82564.00   83454.00   84837.00   83819.00
# 12       0.79       0.91       0.95       0.79       0.85
# 13        NaN        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN        NaN

# %%
lg[4]
# Out:
#            종목명 LG전자*066570 드림어스컴퍼니060570  삼본전자111870  아남전자008700  홈캐스트064240
# 0          현재가       70400          5290        3035        2085        4520
# 1         전일대비     하향  500       하향  210     하향  125      하향  70     하향  130
# 2          등락률  하향  -0.71%    하향  -3.82%  하향  -3.96%  하향  -3.25%  하향  -2.80%
# 3      시가총액(억)      115208          2977        1681        1608        1495
# 4     외국인비율(%)       33.97          4.26         .15        2.90        4.75
# 5       매출액(억)      157006           NaN         NaN         NaN         NaN
# 6      영업이익(억)        7815           NaN         NaN         NaN         NaN
# 7    조정영업이익(억)        7815           NaN         NaN         NaN         NaN
# 8   영업이익증가율(%)       19.81           NaN         NaN         NaN         NaN
# 9     당기순이익(억)        3457           NaN         NaN         NaN         NaN
# 10    주당순이익(원)     1350.27           NaN         NaN         NaN         NaN
# 11      ROE(%)        4.94           NaN         NaN         NaN         NaN
# 12      PER(%)       10.27        -12.60       51.44      -11.52       -7.24
# 13      PBR(배)         .89          1.84        1.62        2.93        1.90

# %%
lg[5]
# Out:
#           0               1
# 0      시가총액  11조  5,208  억원
# 1    시가총액순위         코스피 27위
# 2     상장주식수       163647814
# 3  액면가l매매단위   5,000원  l  1주
